# %%
# !pip -q install torch_geometric rectools
# !pip -q install comet_ml
# !pip -q install python-dotenv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.1 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 95.9 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.1/727.1 kB 17.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 90.7 MB/s eta 0:00:00:00:01

# %%
import comet_ml
from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

from dotenv import load_dotenv
import os

# %%
load_dotenv(".env")
# Out:
# True

# %%
experiment = Experiment(
  api_key=os.getenv('API_KEY'),
  project_name="gnn-recommender",
  workspace="annanet",
  log_code=True
)

experiment.set_name('BaseGATGraphModel')
experiment.add_tags(['movielens', 'leave-n-out'])
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/annanet/gnn-recommender/1e74ff5a183140f2be3be0cc15587fff
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %%
hyperparameters = {
    'seed': 42,
    'types_of_feedback': ["explicit_positive", "expliсit_negative",
                          "implicit_positive", "implicit_negative"],
    'train_edge_type': ('item','to_feedback_explicit_positive','explicit_positive'),
    'train_num_epochs': 100,
    'train_lr': 3e-4,
    'train_batch_size': 4096,
    'train_print_every': 10,  
    'train_test_every': 10,
    'test_topk': 10,
    'test_batch_size': 2048
}

# %%
import os
os.listdir('/kaggle/input/data/leave-n-out/mvln')
# Out:
# ['train.csv', 'test.csv']

# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import HeteroData
from torch_geometric.nn import HeteroConv, SAGEConv, GATConv

from sklearn.preprocessing import LabelEncoder

from rectools import Columns
from rectools.metrics import MAP, Precision, Recall, NDCG, calc_metrics

import gc
import random

# %%
SEED = hyperparameters['seed']
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
rootpath = '/kaggle/input/data/leave-n-out/mvln/'
train = pd.read_csv(
    rootpath+'train.csv'
)
train['date'] = pd.to_datetime(train['timestamp'], unit='s')
print(train.head())
# Out:
#    user_id  movie_id  rating  timestamp                date
# 0        1      3186       4  978300019 2000-12-31 22:00:19
# 1        1      1270       5  978300055 2000-12-31 22:00:55
# 2        1      1721       4  978300055 2000-12-31 22:00:55
# 3        1      1022       5  978300055 2000-12-31 22:00:55
# 4        1      2340       3  978300103 2000-12-31 22:01:43

# %%
explicit_positive = train[(train["rating"] == 5)].index
explisit_negative = train[(train["rating"] <= 2)].index

explicit_combined_feedback = explicit_positive.union(explisit_negative)
print('Количество explicit позитивного фидбека', explicit_positive.shape[0])
print('Количество explicit негативного фидбека', explisit_negative.shape[0])
# Out:
# Количество explicit позитивного фидбека 211802
# Количество explicit негативного фидбека 153484

# %%
implicit_positive = train[(train["rating"] == 4)].index
implicit_negative = train[(train["rating"] == 3)].index

implicit_combined_feedback = implicit_positive.union(implicit_negative)
print('Количество implicit позитивного фидбека', implicit_positive.shape[0])
print('Количество implicit негативного фидбека', implicit_negative.shape[0])
# Out:
# Количество implicit позитивного фидбека 327987
# Количество implicit негативного фидбека 246536

# %%
train.loc[:, "target"] = ""
train.loc[explicit_positive, "target"] = "explicit_positive"
train.loc[explisit_negative, "target"] = "expliсit_negative"
train.loc[implicit_positive, "target"] = "implicit_positive"
train.loc[implicit_negative, "target"] = "implicit_negative"

train = train[['user_id','movie_id','target','date']]
train.head()
# Out:
#    user_id  movie_id             target                date
# 0        1      3186  implicit_positive 2000-12-31 22:00:19
# 1        1      1270  explicit_positive 2000-12-31 22:00:55
# 2        1      1721  implicit_positive 2000-12-31 22:00:55
# 3        1      1022  explicit_positive 2000-12-31 22:00:55
# 4        1      2340  implicit_negative 2000-12-31 22:01:43

# %%
train = train.sort_values(by=["user_id", "date"]).reset_index(drop=True)

# %%
test = pd.read_csv(
    rootpath+'test.csv'
)
test['date'] = pd.to_datetime(test['timestamp'], unit='s')
print(test.head())
# Out:
#    user_id  movie_id  rating  timestamp                date
# 0        1      2687       3  978824268 2001-01-06 23:37:48
# 1        1       745       3  978824268 2001-01-06 23:37:48
# 2        1       588       4  978824268 2001-01-06 23:37:48
# 3        1         1       5  978824268 2001-01-06 23:37:48
# 4        1      2355       5  978824291 2001-01-06 23:38:11

# %%
test = test[['user_id','movie_id', 'date']]
test.head()
# Out:
#    user_id  movie_id                date
# 0        1      2687 2001-01-06 23:37:48
# 1        1       745 2001-01-06 23:37:48
# 2        1       588 2001-01-06 23:37:48
# 3        1         1 2001-01-06 23:37:48
# 4        1      2355 2001-01-06 23:38:11

# %% [markdown]
# # MVP model v2

# %%
test = test[(test.user_id.isin(train.user_id)) & (test.movie_id.isin(train.movie_id))].copy()
test.shape
# Out:
# (60394, 3)

# %%
# 2. Преобразование данных - для куарека не особо нужно, но для других - напоминалка
# делаем всегда! чтобы не сломать ничего дальше и чтобы все индексы были от 0 до N без пропусков
user_encoder = LabelEncoder()
video_encoder = LabelEncoder()

train.loc[:, 'user_id'] = user_encoder.fit_transform(train['user_id'])
train.loc[:, 'movie_id'] = video_encoder.fit_transform(train['movie_id'])

test.loc[:, 'user_id'] = user_encoder.transform(test['user_id'])
test.loc[:, 'movie_id'] = video_encoder.transform(test['movie_id'])

# %%
# т.е. сразу знаем количество и в каких пределах изменяется user_id и video_id
num_videos = train['movie_id'].nunique()
num_users = train['user_id'].nunique()

print('Количество уникальных movie_id', num_videos)
print('Количество уникальных user_id', num_users)
# Out:
# Количество уникальных movie_id 3700
# Количество уникальных user_id 6040

# %%
def build_full_graph(num_nodes: int) -> torch.Tensor:
    idx = torch.arange(num_nodes)
    src = idx.repeat(num_nodes)
    dst = idx.unsqueeze(1).repeat(1, num_nodes).view(-1)
    return torch.stack([src, dst], dim=0)


def prepare_hetero_data(df) -> HeteroData:
    data = HeteroData()
    users = df['user_id'].unique()
    num_users = len(users)
    num_items = df['movie_id'].max() + 1
    feedback_types = df['target'].unique().tolist()

    # узлы
    data['user'].node_id = torch.arange(num_users)
    data['item'].node_id = torch.arange(num_items)
    for ft in feedback_types:
        data[ft].node_id = torch.arange(num_users)

    # ребра item<->feedback->user
    for ft in feedback_types:
        mask = df['target'] == ft
        items = torch.LongTensor(df.loc[mask, 'movie_id'].values)
        users_idx = torch.LongTensor(df.loc[mask, 'user_id'].values)
        # item -> fb
        data['item', f'to_feedback_{ft}', ft].edge_index = torch.stack([items, users_idx], dim=0)
        # fb -> item
        data[ft, f'feedback_to_item_{ft}', 'item'].edge_index = torch.stack([users_idx, items], dim=0)
        # fb -> user (1:1)
        idx = torch.arange(num_users)
        data[ft, f'to_user_{ft}', 'user'].edge_index = torch.stack([idx, idx], dim=0)

    # user <-> user
    # data['user', 'interacts', 'user'].edge_index = build_full_graph(num_users)
    return data

# %%
class HeteroGNN(nn.Module):
    def __init__(self,
                 num_users: int,
                 num_items: int,
                 feedback_types: list,
                 emb_dim: int = 32,
                 hidden_dim: int = 16,
                 heads: int = 2,
                 dropout: float = 0.2):
        super().__init__()
        self.feedback_types = feedback_types
        self.pos_types = ['implicit_positive', 'explicit_positive']
        self.neg_types = ['implicit_negative', 'expliсit_negative']

        self.user_emb = nn.Embedding(num_users, emb_dim)
        self.item_emb = nn.Embedding(num_items, emb_dim)
        self.fb_emb   = nn.ModuleDict({
            ft: nn.Embedding(num_users, emb_dim) for ft in feedback_types
        })

        conv1, conv2 = {}, {}
        for ft in feedback_types:
            # ft -> user
            conv1[(ft, f'to_user_{ft}', 'user')] = GATConv(emb_dim, hidden_dim,
                                                      heads=heads,
                                                      add_self_loops=False)
            conv2[(ft, f'to_user_{ft}', 'user')] = GATConv(hidden_dim*heads, emb_dim,
                                                      heads=1,
                                                      add_self_loops=False)
            # ft -> item
            conv1[(ft, f'feedback_to_item_{ft}', 'item')] = GATConv(emb_dim, hidden_dim,
                                                       heads=heads,
                                                       add_self_loops=False)
            conv2[(ft, f'feedback_to_item_{ft}', 'item')] = GATConv(hidden_dim*heads, emb_dim,
                                                       heads=1,
                                                       add_self_loops=False)

            # item -> ft
            conv1[('item', f'to_feedback_{ft}', ft)] = GATConv(emb_dim, hidden_dim,
                                                       heads=heads,
                                                       add_self_loops=False)
            conv2[('item', f'to_feedback_{ft}', ft)] = GATConv(hidden_dim*heads, emb_dim,
                                                       heads=1,
                                                       add_self_loops=False)

        self.conv1 = HeteroConv(conv1, aggr='mean')
        self.conv2 = HeteroConv(conv2, aggr='mean')

        # LayerNorm и Dropout
        types = ['user', 'item'] + feedback_types
        self.norm1 = nn.ModuleDict({t: nn.LayerNorm(hidden_dim*heads) for t in types})
        self.norm2 = nn.ModuleDict({t: nn.LayerNorm(emb_dim) for t in types})
        self.dropout = nn.Dropout(dropout)

    def forward(self, data):
        x = {
            'user': self.user_emb(data['user'].node_id),
            'item': self.item_emb(data['item'].node_id)
        }
        for ft in self.feedback_types:
            x[ft] = self.fb_emb[ft](data[ft].node_id)

        h1 = self.conv1(x, data.edge_index_dict)
        for t, h in h1.items():
            h1[t] = self.dropout(F.leaky_relu(self.norm1[t](h)))

        h2 = self.conv2(h1, data.edge_index_dict)
        out = {}
        for t, h in h2.items():
            out[t] = self.norm2[t](h)
            
        return out['user']

# %%
data = prepare_hetero_data(train)
data
# Out:
# HeteroData(
#   user={ node_id=[6040] },
#   item={ node_id=[3700] },
#   implicit_positive={ node_id=[6040] },
#   explicit_positive={ node_id=[6040] },
#   implicit_negative={ node_id=[6040] },
#   expliсit_negative={ node_id=[6040] },
#   (item, to_feedback_implicit_positive, implicit_positive)={ edge_index=[2, 327987] },
#   (implicit_positive, feedback_to_item_implicit_positive, item)={ edge_index=[2, 327987] },
#   (implicit_positive, to_user_implicit_positive, user)={ edge_index=[2, 6040] },
#   (item, to_feedback_explicit_positive, explicit_positive)={ edge_index=[2, 211802] },
#   (explicit_positive, feedback_to_item_explicit_positive, item)={ edge_index=[2, 211802] },
#   (explicit_positive, to_user_explicit_positive, user)={ edge_index=[2, 6040] },
#   (item, to_feedback_implicit_negative, implicit_negative)={ edge_index=[2, 246536] },
#   (implicit_negative, feedback_to_item_implicit_negative, item)={ edge_index=[2, 246536] },
#   (implicit_negative, to_user_implicit_negative, user)={ edge_index=[2, 6040] },
#   (item, to_feedback_expliсit_negative, expliсit_negative)={ edge_index=[2, 153484] },
#   (expliсit_negative, feedback_to_item_expliсit_negative, item)={ edge_index=[2, 153484] },
#   (expliсit_negative, to_user_expliсit_negative, user)={ edge_index=[2, 6040] }
# )

# %%
train.movie_id.nunique(), train.movie_id.min(), train.movie_id.max()
# Out:
# (3700, 0, 3699)

# %%
num_users = len(train['user_id'].unique())
num_items = train['movie_id'].max() + 1
feedback_types = train['target'].unique().tolist()
model = HeteroGNN(num_users, num_items, feedback_types)

# %%
model
# Out:
# HeteroGNN(
#   (user_emb): Embedding(6040, 32)
#   (item_emb): Embedding(3700, 32)
#   (fb_emb): ModuleDict(
#     (implicit_positive): Embedding(6040, 32)
#     (explicit_positive): Embedding(6040, 32)
#     (implicit_negative): Embedding(6040, 32)
#     (expliсit_negative): Embedding(6040, 32)
#   )
#   (conv1): HeteroConv(num_relations=12)
#   (conv2): HeteroConv(num_relations=12)
#   (norm1): ModuleDict(
#     (user): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (item): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (explicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (expliсit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (norm2): ModuleDict(
#     (user): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (item): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (explicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (expliсit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model(data)
# Out:
# tensor([[-0.5632,  0.2609, -1.3624,  ..., -2.5372, -0.5059, -1.3198],
#         [-0.4295, -1.5870,  0.0169,  ..., -1.5316, -1.1555, -1.0729],
#         [-0.0791,  0.3499,  0.4089,  ...,  2.3449, -0.8924, -1.6724],
#         ...,
#         [-0.7345, -0.9524,  0.6445,  ..., -0.1650, -0.9734, -0.6582],
#         [-1.4275, -0.9545, -0.2927,  ..., -0.6495, -0.3625, -1.6914],
#         [ 0.1451, -1.0966, -0.1414,  ..., -0.7511, -1.5610, -1.8678]],
#        grad_fn=<NativeLayerNormBackward0>)

# %%
test_df = test[['user_id', 'movie_id']]
interactions = test_df.rename(columns={
    'user_id': Columns.User,
    'movie_id': Columns.Item,
})

viewed_items = train.groupby("user_id")["movie_id"].agg(set).to_dict()

# %%
def train_model(model: HeteroGNN,
                train_data: HeteroData,
                edge_type: tuple,
                num_epochs: int = 10,
                lr: float = 1e-3,
                batch_size: int = 1024,
                device: str = None,
                print_every: int = 100,
                test_every: int = 500,
                top_k: int = 10,
                test_batch_size=2048) -> HeteroGNN:
    device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    train_data = train_data.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    src, dst = train_data[edge_type].edge_index
    num_train = src.size(0)
    test_top_k = top_k * 300
    total_steps = 0
    print(f"Num of training examples: {num_train}")
    for epoch in range(1, num_epochs + 1):
        model.train()
        perm = torch.randperm(num_train, device=device)
        total_loss = 0.0
        step = 0
        for i in range(0, num_train, batch_size):
            idx = perm[i:i + batch_size]
            users = dst[idx]
            pos_items = src[idx]
            neg_items = torch.randint(0, model.item_emb.num_embeddings,
                                      size=pos_items.size(), device=device)
            optimizer.zero_grad()
            user_embs = model(train_data)[users]
            pos_emb = model.item_emb(pos_items)
            neg_emb = model.item_emb(neg_items)
            pos_score = (user_embs * pos_emb).sum(dim=1)
            neg_score = (user_embs * neg_emb).sum(dim=1)
            loss = -torch.log(torch.sigmoid(pos_score - neg_score) + 1e-15).mean()
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * users.size(0)
            step += 1

            experiment.log_metric('Train BPR Loss vs step', loss.item(), step=total_steps)
            if step % print_every == 0 or step == 1:
                avg_loss = total_loss /  (step * batch_size)
                current_lr = optimizer.param_groups[0]['lr']
                d = (pos_score - neg_score).detach().cpu()
                print(f"Epoch {epoch}, Step {step}, LR: {current_lr:.6f}, Current Loss: {loss.item():.4f}, Avg Loss: {avg_loss:.4f}")
                print(f"Diff stats — min: {d.min():.4f}, max: {d.max():.4f}, mean: {d.mean():.4f}, std: {d.std():.4f}")
                print()

                experiment.log_metric('Diff stats (mean) vs step', d.mean(), step=total_steps)
                experiment.log_metric('Diff stats (std) vs step', d.std(), step=total_steps)

            del user_embs, pos_emb, neg_emb, pos_score, neg_score
            gc.collect()
            torch.cuda.empty_cache()
            
            if step % test_every == 0 or step == 1:
                model.eval()
                # model.to('cpu')
                with torch.no_grad():
                    user_emb = model(train_data)
                    item_emb = model.item_emb.weight
                    item_emb_t = item_emb.t().detach()
                    del item_emb
                    gc.collect()

                    scores = []
                    for i in range(0, user_emb.shape[0], test_batch_size):
                        user_e = user_emb[i:i+test_batch_size]
                        rating = torch.mm(user_e, item_emb_t)
                        _, topk_items = torch.topk(rating, k=test_top_k, dim=1)
                        scores.extend(topk_items)

                        del user_e, rating
                        gc.collect()

                    scores = torch.cat(scores, dim=0)
                    scores = scores.reshape((num_users, test_top_k))
                    topk_np = scores.cpu().numpy()

                    filtered_topk = []
                    for u_idx in range(num_users):
                        seen = viewed_items[u_idx]
                        recs = topk_np[u_idx, :]
                        mask = np.isin(recs, list(seen), invert=True)
                        filtered = recs[mask][:top_k] 
                        filtered_topk.append(filtered)
                    
                    users = []
                    items = []
                    ranks = []
                    for u_idx in range(num_users):
                        recs = filtered_topk[u_idx]
                        for rank, item in enumerate(recs[:top_k], 1):
                            users.append(u_idx)
                            items.append(item)
                            ranks.append(rank)
                    
                    reco_df = pd.DataFrame({
                        Columns.User: users,
                        Columns.Item: items,
                        Columns.Rank: ranks,
                    })

                    metrics = {
                        'map@10': MAP(k=10),
                        'precision@10': Precision(k=10),
                        'recall@10': Recall(k=10),
                        'ndcg@10': NDCG(k=10)
                    }
                    
                    results = calc_metrics(
                        metrics=metrics,
                        reco=reco_df,
                        interactions=interactions,
                    )
                print(f"Step/epoch {step}/{epoch}, Test metrics:")
                for key, value in results.items():
                    print(f"{key}: {value:.9f}")
                    experiment.log_metric(f"Test {key} vs step", value, step=total_steps)
                del scores, topk_np
                gc.collect()

                model.to(device)
                model.train()
                train_data.to(device)
            total_steps += 1
        epoch_loss = total_loss / num_train
        experiment.log_metric(f'Train Loss vs epoch', epoch_loss, epoch=epoch - 1)
        print(f"Epoch {epoch} completed, Train Loss: {epoch_loss:.4f}")
    return model

# %%
experiment.log_parameters(hyperparameters)

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
edge_type = hyperparameters['train_edge_type']
num_epochs = hyperparameters['train_num_epochs']
lr = hyperparameters['train_lr']
batch_size = hyperparameters['train_batch_size']
print_every = hyperparameters['train_print_every']
test_every = hyperparameters['train_test_every']
top_k = hyperparameters['test_topk']
test_batch_size = hyperparameters['test_batch_size']
model = train_model(model,
                    data,
                    edge_type=edge_type,
                    num_epochs=num_epochs,
                    lr=lr,
                    batch_size=batch_size,
                    print_every=print_every,
                    test_every=test_every,
                    top_k=top_k,
                    test_batch_size=test_batch_size)
# Out:
# Num of training examples: 211802
# Epoch 1, Step 1, LR: 0.000300, Current Loss: 3.1944, Avg Loss: 3.1944
# Diff stats — min: -28.7889, max: 28.8653, mean: 0.0818, std: 7.8812
#
# Step/epoch 1/1, Test metrics:
# precision@10: 0.002864238
# recall@10: 0.002866078
# ndcg@10: 0.002995891
# map@10: 0.000922238
# Epoch 1, Step 10, LR: 0.000300, Current Loss: 3.2057, Avg Loss: 3.1835
# Diff stats — min: -25.7316, max: 25.9495, mean: 0.0453, std: 7.8804
#
# Step/epoch 10/1, Test metrics:
# precision@10: 0.002913907
# recall@10: 0.002915747
# ndcg@10: 0.002922583
# map@10: 0.000867070
# Epoch 1, Step 20, LR: 0.000300, Current Loss: 3.0501, Avg Loss: 3.1449
# Diff stats — min: -28.7978, max: 32.7993, mean: 0.1262, std: 7.6568
#
# Step/epoch 20/1, Test metrics:
# precision@10: 0.002814570
# recall@10: 0.002816409
# ndcg@10: 0.002892458
# map@10: 0.000878962
# Epoch 1, Step 30, LR: 0.000300, Current Loss: 3.0533, Avg Loss: 3.1121
# Diff stats — min: -25.0935, max: 27.1920, mean: 0.1927, std: 7.7264
#
# Step/epoch 30/1, Test metrics:
# precision@10: 0.002913907
# recall@10: 0.002915747
# ndcg@10: 0.002924901
# map@10: 0.000871222
# Epoch 1, Step 40, LR: 0.000300, Current Loss: 2.8981, Avg Loss: 3.0895
# Diff stats — min: -26.9979, max: 26.8721, mean: 0.3707, std: 7.4700
#
# Step/epoch 40/1, Test metrics:
# precision@10: 0.002798013
# recall@10: 0.002799853
# ndcg@10: 0.002844840
# map@10: 0.000855323
# Epoch 1, Step 50, LR: 0.000300, Current Loss: 2.8647, Avg Loss: 3.0546
# Diff stats — min: -25.1753, max: 27.2152, mean: 0.5119, std: 7.6065
#
# Step/epoch 50/1, Test metrics:
# precision@10: 0.002996689
# recall@10: 0.002998528
# ndcg@10: 0.002938977
# map@10: 0.000858680
# Epoch 1 completed, Train Loss: 3.0504
# Epoch 2, Step 1, LR: 0.000300, Current Loss: 2.8405, Avg Loss: 2.8405
# Diff stats — min: -27.5706, max: 25.4380, mean: 0.4451, std: 7.4857
#
# Step/epoch 1/2, Test metrics:
# precision@10: 0.003079470
# recall@10: 0.003079470
# ndcg@10: 0.002999338
# map@10: 0.000872168
# Epoch 2, Step 10, LR: 0.000300, Current Loss: 2.8119, Avg Loss: 2.8416
# Diff stats — min: -26.0212, max: 26.0731, mean: 0.5636, std: 7.4887
#
# Step/epoch 10/2, Test metrics:
# precision@10: 0.003195364
# recall@10: 0.003195364
# ndcg@10: 0.003112513
# map@10: 0.000903645
# Epoch 2, Step 20, LR: 0.000300, Current Loss: 2.6539, Avg Loss: 2.7939
# Diff stats — min: -23.2063, max: 25.1154, mean: 0.7766, std: 7.3386
#
# Step/epoch 20/2, Test metrics:
# precision@10: 0.003394040
# recall@10: 0.003394040
# ndcg@10: 0.003201302
# map@10: 0.000899631
# Epoch 2, Step 30, LR: 0.000300, Current Loss: 2.6321, Avg Loss: 2.7719
# Diff stats — min: -27.9833, max: 27.5863, mean: 0.7413, std: 7.2647
#
# Step/epoch 30/2, Test metrics:
# precision@10: 0.003261589
# recall@10: 0.003261589
# ndcg@10: 0.003073286
# map@10: 0.000855224
# Epoch 2, Step 40, LR: 0.000300, Current Loss: 2.5840, Avg Loss: 2.7485
# Diff stats — min: -23.3840, max: 26.1781, mean: 0.7782, std: 7.1852
#
# Step/epoch 40/2, Test metrics:
# precision@10: 0.003294702
# recall@10: 0.003296542
# ndcg@10: 0.003144629
# map@10: 0.000884546
# Epoch 2, Step 50, LR: 0.000300, Current Loss: 2.7096, Avg Loss: 2.7261
# Diff stats — min: -30.0316, max: 27.9676, mean: 0.5419, std: 7.2738
#
# Step/epoch 50/2, Test metrics:
# precision@10: 0.003377483
# recall@10: 0.003379323
# ndcg@10: 0.003197676
# map@10: 0.000889237
# Epoch 2 completed, Train Loss: 2.7222
# Epoch 3, Step 1, LR: 0.000300, Current Loss: 2.5935, Avg Loss: 2.5935
# Diff stats — min: -23.4135, max: 29.2401, mean: 0.8279, std: 7.2977
#
# Step/epoch 1/3, Test metrics:
# precision@10: 0.003410596
# recall@10: 0.003412436
# ndcg@10: 0.003219894
# map@10: 0.000893692
# Epoch 3, Step 10, LR: 0.000300, Current Loss: 2.5457, Avg Loss: 2.5699
# Diff stats — min: -22.9750, max: 27.9525, mean: 0.7862, std: 7.1327
#
# Step/epoch 10/3, Test metrics:
# precision@10: 0.003377483
# recall@10: 0.003379323
# ndcg@10: 0.003197393
# map@10: 0.000887786
# Epoch 3, Step 20, LR: 0.000300, Current Loss: 2.5078, Avg Loss: 2.5407
# Diff stats — min: -29.8551, max: 24.2346, mean: 0.7923, std: 7.0347
#
# Step/epoch 20/3, Test metrics:
# precision@10: 0.003476821
# recall@10: 0.003478661
# ndcg@10: 0.003252787
# map@10: 0.000894763
# Epoch 3, Step 30, LR: 0.000300, Current Loss: 2.3158, Avg Loss: 2.5120
# Diff stats — min: -24.9935, max: 25.8321, mean: 1.0882, std: 6.8847
#
# Step/epoch 30/3, Test metrics:
# precision@10: 0.003559603
# recall@10: 0.003561442
# ndcg@10: 0.003254513
# map@10: 0.000869686
# Epoch 3, Step 40, LR: 0.000300, Current Loss: 2.4034, Avg Loss: 2.4860
# Diff stats — min: -22.1023, max: 28.3114, mean: 0.8966, std: 6.8355
#
# Step/epoch 40/3, Test metrics:
# precision@10: 0.003493377
# recall@10: 0.003495217
# ndcg@10: 0.003237447
# map@10: 0.000877169
# Epoch 3, Step 50, LR: 0.000300, Current Loss: 2.3694, Avg Loss: 2.4607
# Diff stats — min: -21.6413, max: 25.3845, mean: 1.0213, std: 6.9145
#
# Step/epoch 50/3, Test metrics:
# precision@10: 0.003559603
# recall@10: 0.003561442
# ndcg@10: 0.003273101
# map@10: 0.000879428
# Epoch 3 completed, Train Loss: 2.4576
# Epoch 4, Step 1, LR: 0.000300, Current Loss: 2.3310, Avg Loss: 2.3310
# Diff stats — min: -25.1678, max: 26.5192, mean: 0.9895, std: 6.7962
#
# Step/epoch 1/4, Test metrics:
# precision@10: 0.003543046
# recall@10: 0.003544886
# ndcg@10: 0.003236999
# map@10: 0.000863108
# Epoch 4, Step 10, LR: 0.000300, Current Loss: 2.2598, Avg Loss: 2.2790
# Diff stats — min: -21.9692, max: 26.6260, mean: 1.1989, std: 6.8908
#
# Step/epoch 10/4, Test metrics:
# precision@10: 0.003559603
# recall@10: 0.003561442
# ndcg@10: 0.003222259
# map@10: 0.000851125
# Epoch 4, Step 20, LR: 0.000300, Current Loss: 2.2592, Avg Loss: 2.2831
# Diff stats — min: -23.2680, max: 26.6524, mean: 1.1236, std: 6.7337
#
# Step/epoch 20/4, Test metrics:
# precision@10: 0.003559603
# recall@10: 0.003561442
# ndcg@10: 0.003216394
# map@10: 0.000846388
# Epoch 4, Step 30, LR: 0.000300, Current Loss: 2.2075, Avg Loss: 2.2666
# Diff stats — min: -20.9781, max: 25.8053, mean: 1.1167, std: 6.6326
#
# Step/epoch 30/4, Test metrics:
# precision@10: 0.003559603
# recall@10: 0.003561442
# ndcg@10: 0.003192297
# map@10: 0.000833281
# Epoch 4, Step 40, LR: 0.000300, Current Loss: 2.2021, Avg Loss: 2.2398
# Diff stats — min: -20.5660, max: 31.5014, mean: 1.0270, std: 6.5142
#
# Step/epoch 40/4, Test metrics:
# precision@10: 0.003526490
# recall@10: 0.003528330
# ndcg@10: 0.003137948
# map@10: 0.000808812
# Epoch 4, Step 50, LR: 0.000300, Current Loss: 2.2157, Avg Loss: 2.2197
# Diff stats — min: -24.2194, max: 26.1821, mean: 1.1760, std: 6.6906
#
# Step/epoch 50/4, Test metrics:
# precision@10: 0.003460265
# recall@10: 0.003462104
# ndcg@10: 0.003060988
# map@10: 0.000782848
# Epoch 4 completed, Train Loss: 2.2169
# Epoch 5, Step 1, LR: 0.000300, Current Loss: 2.1478, Avg Loss: 2.1478
# Diff stats — min: -21.5698, max: 31.2219, mean: 1.1837, std: 6.5464
#
# Step/epoch 1/5, Test metrics:
# precision@10: 0.003460265
# recall@10: 0.003462104
# ndcg@10: 0.003060014
# map@10: 0.000781888
# Epoch 5, Step 10, LR: 0.000300, Current Loss: 2.1153, Avg Loss: 2.1085
# Diff stats — min: -20.0932, max: 30.0329, mean: 1.1228, std: 6.3882
#
# Step/epoch 10/5, Test metrics:
# precision@10: 0.003410596
# recall@10: 0.003412436
# ndcg@10: 0.003030767
# map@10: 0.000778349
# Epoch 5, Step 20, LR: 0.000300, Current Loss: 1.9887, Avg Loss: 2.0714
# Diff stats — min: -18.8405, max: 24.3328, mean: 1.3523, std: 6.2923
#
# Step/epoch 20/5, Test metrics:
# precision@10: 0.003543046
# recall@10: 0.003544886
# ndcg@10: 0.003137719
# map@10: 0.000804439
# Epoch 5, Step 30, LR: 0.000300, Current Loss: 1.9643, Avg Loss: 2.0455
# Diff stats — min: -22.2254, max: 23.5245, mean: 1.3902, std: 6.3223
#
# Step/epoch 30/5, Test metrics:
# precision@10: 0.003543046
# recall@10: 0.003544886
# ndcg@10: 0.003176171
# map@10: 0.000824792
# Epoch 5, Step 40, LR: 0.000300, Current Loss: 1.8585, Avg Loss: 2.0347
# Diff stats — min: -21.0448, max: 25.5157, mean: 1.5335, std: 6.1697
#
# Step/epoch 40/5, Test metrics:
# precision@10: 0.003675497
# recall@10: 0.003677336
# ndcg@10: 0.003281756
# map@10: 0.000850895
# Epoch 5, Step 50, LR: 0.000300, Current Loss: 1.8799, Avg Loss: 2.0062
# Diff stats — min: -21.7680, max: 21.9272, mean: 1.5827, std: 6.2146
#
# Step/epoch 50/5, Test metrics:
# precision@10: 0.003658940
# recall@10: 0.003660780
# ndcg@10: 0.003264499
# map@10: 0.000845304
# Epoch 5 completed, Train Loss: 2.0055
# Epoch 6, Step 1, LR: 0.000300, Current Loss: 1.8860, Avg Loss: 1.8860
# Diff stats — min: -23.1971, max: 28.8070, mean: 1.4213, std: 6.1212
#
# Step/epoch 1/6, Test metrics:
# precision@10: 0.003708609
# recall@10: 0.003710449
# ndcg@10: 0.003295022
# map@10: 0.000848319
# Epoch 6, Step 10, LR: 0.000300, Current Loss: 1.8965, Avg Loss: 1.8851
# Diff stats — min: -22.5520, max: 24.5768, mean: 1.4066, std: 6.1129
#
# Step/epoch 10/6, Test metrics:
# precision@10: 0.003725166
# recall@10: 0.003727005
# ndcg@10: 0.003315429
# map@10: 0.000855047
# Epoch 6, Step 20, LR: 0.000300, Current Loss: 1.8288, Avg Loss: 1.8823
# Diff stats — min: -19.0759, max: 22.4129, mean: 1.5200, std: 6.0545
#
# Step/epoch 20/6, Test metrics:
# precision@10: 0.003824503
# recall@10: 0.003826343
# ndcg@10: 0.003371206
# map@10: 0.000860842
# Epoch 6, Step 30, LR: 0.000300, Current Loss: 1.7537, Avg Loss: 1.8611
# Diff stats — min: -21.3643, max: 26.7274, mean: 1.5560, std: 5.9001
#
# Step/epoch 30/6, Test metrics:
# precision@10: 0.003741722
# recall@10: 0.003743561
# ndcg@10: 0.003295293
# map@10: 0.000839148
# Epoch 6, Step 40, LR: 0.000300, Current Loss: 1.8125, Avg Loss: 1.8425
# Diff stats — min: -27.1774, max: 23.8256, mean: 1.3653, std: 5.8869
#
# Step/epoch 40/6, Test metrics:
# precision@10: 0.003774834
# recall@10: 0.003776674
# ndcg@10: 0.003319487
# map@10: 0.000844610
# Epoch 6, Step 50, LR: 0.000300, Current Loss: 1.8101, Avg Loss: 1.8247
# Diff stats — min: -17.7648, max: 26.2254, mean: 1.4882, std: 5.9895
#
# Step/epoch 50/6, Test metrics:
# precision@10: 0.003758278
# recall@10: 0.003760118
# ndcg@10: 0.003273625
# map@10: 0.000822587
# Epoch 6 completed, Train Loss: 1.8232
# Epoch 7, Step 1, LR: 0.000300, Current Loss: 1.6951, Avg Loss: 1.6951
# Diff stats — min: -19.9691, max: 24.8301, mean: 1.6633, std: 5.8614
#
# Step/epoch 1/7, Test metrics:
# precision@10: 0.003774834
# recall@10: 0.003776674
# ndcg@10: 0.003265833
# map@10: 0.000816733
# Epoch 7, Step 10, LR: 0.000300, Current Loss: 1.6639, Avg Loss: 1.7133
# Diff stats — min: -21.5021, max: 21.9636, mean: 1.6763, std: 5.7993
#
# Step/epoch 10/7, Test metrics:
# precision@10: 0.003774834
# recall@10: 0.003776674
# ndcg@10: 0.003289245
# map@10: 0.000830543
# Epoch 7, Step 20, LR: 0.000300, Current Loss: 1.6561, Avg Loss: 1.6964
# Diff stats — min: -19.6971, max: 23.1693, mean: 1.5940, std: 5.6824
#
# Step/epoch 20/7, Test metrics:
# precision@10: 0.003725166
# recall@10: 0.003727005
# ndcg@10: 0.003307091
# map@10: 0.000854195
# Epoch 7, Step 30, LR: 0.000300, Current Loss: 1.6150, Avg Loss: 1.6860
# Diff stats — min: -16.2979, max: 23.7242, mean: 1.6907, std: 5.6389
#
# Step/epoch 30/7, Test metrics:
# precision@10: 0.003725166
# recall@10: 0.003727005
# ndcg@10: 0.003328245
# map@10: 0.000865658
# Epoch 7, Step 40, LR: 0.000300, Current Loss: 1.6339, Avg Loss: 1.6686
# Diff stats — min: -19.3384, max: 23.6326, mean: 1.6330, std: 5.6683
#
# Step/epoch 40/7, Test metrics:
# precision@10: 0.003791391
# recall@10: 0.003793230
# ndcg@10: 0.003354109
# map@10: 0.000862399
# Epoch 7, Step 50, LR: 0.000300, Current Loss: 1.5382, Avg Loss: 1.6550
# Diff stats — min: -19.0950, max: 22.4809, mean: 1.7758, std: 5.5548
#
# Step/epoch 50/7, Test metrics:
# precision@10: 0.003807947
# recall@10: 0.003809787
# ndcg@10: 0.003353770
# map@10: 0.000856755
# Epoch 7 completed, Train Loss: 1.6527
# Epoch 8, Step 1, LR: 0.000300, Current Loss: 1.5650, Avg Loss: 1.5650
# Diff stats — min: -17.7844, max: 22.3216, mean: 1.7550, std: 5.6121
#
# Step/epoch 1/8, Test metrics:
# precision@10: 0.003791391
# recall@10: 0.003793230
# ndcg@10: 0.003352607
# map@10: 0.000860093
# Epoch 8, Step 10, LR: 0.000300, Current Loss: 1.4792, Avg Loss: 1.5702
# Diff stats — min: -19.3527, max: 20.2258, mean: 1.7459, std: 5.3453
#
# Step/epoch 10/8, Test metrics:
# precision@10: 0.003841060
# recall@10: 0.003842899
# ndcg@10: 0.003402782
# map@10: 0.000875361
# Epoch 8, Step 20, LR: 0.000300, Current Loss: 1.5231, Avg Loss: 1.5474
# Diff stats — min: -21.2938, max: 23.1292, mean: 1.8620, std: 5.6168
#
# Step/epoch 20/8, Test metrics:
# precision@10: 0.003841060
# recall@10: 0.003842899
# ndcg@10: 0.003397305
# map@10: 0.000870992
# Epoch 8, Step 30, LR: 0.000300, Current Loss: 1.4656, Avg Loss: 1.5266
# Diff stats — min: -17.8129, max: 21.4324, mean: 1.8578, std: 5.3965
#
# Step/epoch 30/8, Test metrics:
# precision@10: 0.003857616
# recall@10: 0.003859455
# ndcg@10: 0.003414429
# map@10: 0.000877201
# Epoch 8, Step 40, LR: 0.000300, Current Loss: 1.4643, Avg Loss: 1.5126
# Diff stats — min: -19.5401, max: 20.8189, mean: 1.6919, std: 5.2733
#
# Step/epoch 40/8, Test metrics:
# precision@10: 0.003907285
# recall@10: 0.003909124
# ndcg@10: 0.003474566
# map@10: 0.000899716
# Epoch 8, Step 50, LR: 0.000300, Current Loss: 1.4521, Avg Loss: 1.5010
# Diff stats — min: -17.9202, max: 20.8729, mean: 1.7638, std: 5.2915
#
# Step/epoch 50/8, Test metrics:
# precision@10: 0.003990066
# recall@10: 0.003991906
# ndcg@10: 0.003490208
# map@10: 0.000888626
# Epoch 8 completed, Train Loss: 1.5005
# Epoch 9, Step 1, LR: 0.000300, Current Loss: 1.4485, Avg Loss: 1.4485
# Diff stats — min: -20.0539, max: 20.6253, mean: 1.8011, std: 5.3274
#
# Step/epoch 1/9, Test metrics:
# precision@10: 0.004023179
# recall@10: 0.004025018
# ndcg@10: 0.003535689
# map@10: 0.000907423
# Epoch 9, Step 10, LR: 0.000300, Current Loss: 1.4484, Avg Loss: 1.4411
# Diff stats — min: -18.4980, max: 20.1989, mean: 1.7467, std: 5.2733
#
# Step/epoch 10/9, Test metrics:
# precision@10: 0.004006623
# recall@10: 0.004008462
# ndcg@10: 0.003520388
# map@10: 0.000903428
# Epoch 9, Step 20, LR: 0.000300, Current Loss: 1.3717, Avg Loss: 1.4208
# Diff stats — min: -18.4139, max: 23.0426, mean: 1.8693, std: 5.2143
#
# Step/epoch 20/9, Test metrics:
# precision@10: 0.004039735
# recall@10: 0.004041575
# ndcg@10: 0.003551473
# map@10: 0.000913171
# Epoch 9, Step 30, LR: 0.000300, Current Loss: 1.3735, Avg Loss: 1.4090
# Diff stats — min: -17.3653, max: 20.2164, mean: 1.7687, std: 5.1112
#
# Step/epoch 30/9, Test metrics:
# precision@10: 0.004006623
# recall@10: 0.004008462
# ndcg@10: 0.003520022
# map@10: 0.000903205
# Epoch 9, Step 40, LR: 0.000300, Current Loss: 1.3584, Avg Loss: 1.3913
# Diff stats — min: -15.1108, max: 21.1199, mean: 1.7799, std: 5.0350
#
# Step/epoch 40/9, Test metrics:
# precision@10: 0.004056291
# recall@10: 0.004058131
# ndcg@10: 0.003570716
# map@10: 0.000919485
# Epoch 9, Step 50, LR: 0.000300, Current Loss: 1.3560, Avg Loss: 1.3776
# Diff stats — min: -15.1256, max: 23.2657, mean: 1.7899, std: 5.0614
#
# Step/epoch 50/9, Test metrics:
# precision@10: 0.004238411
# recall@10: 0.004240250
# ndcg@10: 0.003705521
# map@10: 0.000947802
# Epoch 9 completed, Train Loss: 1.3743
# Epoch 10, Step 1, LR: 0.000300, Current Loss: 1.3335, Avg Loss: 1.3335
# Diff stats — min: -17.5589, max: 20.6285, mean: 1.9116, std: 5.1152
#
# Step/epoch 1/10, Test metrics:
# precision@10: 0.004238411
# recall@10: 0.004240250
# ndcg@10: 0.003710373
# map@10: 0.000950535
# Epoch 10, Step 10, LR: 0.000300, Current Loss: 1.3230, Avg Loss: 1.3256
# Diff stats — min: -20.0626, max: 20.9608, mean: 1.8875, std: 5.0784
#
# Step/epoch 10/10, Test metrics:
# precision@10: 0.004188742
# recall@10: 0.004190581
# ndcg@10: 0.003685458
# map@10: 0.000947302
# Epoch 10, Step 20, LR: 0.000300, Current Loss: 1.2869, Avg Loss: 1.3164
# Diff stats — min: -17.5199, max: 20.0056, mean: 1.9462, std: 4.9995
#
# Step/epoch 20/10, Test metrics:
# precision@10: 0.004254967
# recall@10: 0.004256806
# ndcg@10: 0.003736288
# map@10: 0.000961310
# Epoch 10, Step 30, LR: 0.000300, Current Loss: 1.2287, Avg Loss: 1.2962
# Diff stats — min: -16.6532, max: 23.7746, mean: 2.0317, std: 4.9522
#
# Step/epoch 30/10, Test metrics:
# precision@10: 0.004304636
# recall@10: 0.004306475
# ndcg@10: 0.003802393
# map@10: 0.000982439
# Epoch 10, Step 40, LR: 0.000300, Current Loss: 1.2011, Avg Loss: 1.2834
# Diff stats — min: -15.1690, max: 19.3523, mean: 2.0846, std: 4.9373
#
# Step/epoch 40/10, Test metrics:
# precision@10: 0.004321192
# recall@10: 0.004323032
# ndcg@10: 0.003813038
# map@10: 0.000984764
# Epoch 10, Step 50, LR: 0.000300, Current Loss: 1.1752, Avg Loss: 1.2697
# Diff stats — min: -15.4855, max: 18.1814, mean: 2.0751, std: 4.8281
#
# Step/epoch 50/10, Test metrics:
# precision@10: 0.004370861
# recall@10: 0.004372701
# ndcg@10: 0.003831618
# map@10: 0.000982563
# Epoch 10 completed, Train Loss: 1.2681
# Epoch 11, Step 1, LR: 0.000300, Current Loss: 1.2428, Avg Loss: 1.2428
# Diff stats — min: -14.8424, max: 18.4375, mean: 1.9124, std: 4.8002
#
# Step/epoch 1/11, Test metrics:
# precision@10: 0.004403974
# recall@10: 0.004405813
# ndcg@10: 0.003854589
# map@10: 0.000987018
# Epoch 11, Step 10, LR: 0.000300, Current Loss: 1.2427, Avg Loss: 1.2172
# Diff stats — min: -14.8754, max: 16.8803, mean: 1.9208, std: 4.8203
#
# Step/epoch 10/11, Test metrics:
# precision@10: 0.004387417
# recall@10: 0.004389257
# ndcg@10: 0.003853258
# map@10: 0.000989974
# Epoch 11, Step 20, LR: 0.000300, Current Loss: 1.2029, Avg Loss: 1.1999
# Diff stats — min: -18.7441, max: 20.7463, mean: 1.9442, std: 4.7697
#
# Step/epoch 20/11, Test metrics:
# precision@10: 0.004321192
# recall@10: 0.004323032
# ndcg@10: 0.003818088
# map@10: 0.000985750
# Epoch 11, Step 30, LR: 0.000300, Current Loss: 1.1508, Avg Loss: 1.1860
# Diff stats — min: -15.1155, max: 19.6870, mean: 2.0416, std: 4.6871
#
# Step/epoch 30/11, Test metrics:
# precision@10: 0.004437086
# recall@10: 0.004438926
# ndcg@10: 0.003878114
# map@10: 0.000990138
# Epoch 11, Step 40, LR: 0.000300, Current Loss: 1.1647, Avg Loss: 1.1717
# Diff stats — min: -14.8207, max: 18.6802, mean: 1.9405, std: 4.6511
#
# Step/epoch 40/11, Test metrics:
# precision@10: 0.004486755
# recall@10: 0.004488595
# ndcg@10: 0.003929175
# map@10: 0.001006938
# Epoch 11, Step 50, LR: 0.000300, Current Loss: 1.0994, Avg Loss: 1.1586
# Diff stats — min: -15.7628, max: 20.2279, mean: 2.1084, std: 4.6464
#
# Step/epoch 50/11, Test metrics:
# precision@10: 0.004453642
# recall@10: 0.004455482
# ndcg@10: 0.003889145
# map@10: 0.000991735
# Epoch 11 completed, Train Loss: 1.1559
# Epoch 12, Step 1, LR: 0.000300, Current Loss: 1.1023, Avg Loss: 1.1023
# Diff stats — min: -19.2287, max: 19.1366, mean: 2.0415, std: 4.5803
#
# Step/epoch 1/12, Test metrics:
# precision@10: 0.004437086
# recall@10: 0.004438926
# ndcg@10: 0.003881791
# map@10: 0.000993371
# Epoch 12, Step 10, LR: 0.000300, Current Loss: 1.1122, Avg Loss: 1.1045
# Diff stats — min: -13.8215, max: 17.6711, mean: 2.0525, std: 4.6217
#
# Step/epoch 10/12, Test metrics:
# precision@10: 0.004503311
# recall@10: 0.004505151
# ndcg@10: 0.003952450
# map@10: 0.001016221
# Epoch 12, Step 20, LR: 0.000300, Current Loss: 1.1152, Avg Loss: 1.0904
# Diff stats — min: -14.7616, max: 19.2111, mean: 1.9983, std: 4.5573
#
# Step/epoch 20/12, Test metrics:
# precision@10: 0.004536424
# recall@10: 0.004538263
# ndcg@10: 0.003984790
# map@10: 0.001024959
# Epoch 12, Step 30, LR: 0.000300, Current Loss: 1.0392, Avg Loss: 1.0781
# Diff stats — min: -14.6700, max: 17.4285, mean: 2.2050, std: 4.5163
#
# Step/epoch 30/12, Test metrics:
# precision@10: 0.004569536
# recall@10: 0.004571376
# ndcg@10: 0.004010477
# map@10: 0.001029998
# Epoch 12, Step 40, LR: 0.000300, Current Loss: 1.0342, Avg Loss: 1.0725
# Diff stats — min: -13.6201, max: 18.8255, mean: 2.0616, std: 4.3932
#
# Step/epoch 40/12, Test metrics:
# precision@10: 0.004652318
# recall@10: 0.004654157
# ndcg@10: 0.004074147
# map@10: 0.001045911
# Epoch 12, Step 50, LR: 0.000300, Current Loss: 1.0244, Avg Loss: 1.0660
# Diff stats — min: -16.9150, max: 18.2912, mean: 2.0624, std: 4.3960
#
# Step/epoch 50/12, Test metrics:
# precision@10: 0.004701987
# recall@10: 0.004703826
# ndcg@10: 0.004103876
# map@10: 0.001051173
# Epoch 12 completed, Train Loss: 1.0656
# Epoch 13, Step 1, LR: 0.000300, Current Loss: 0.9998, Avg Loss: 0.9998
# Diff stats — min: -13.7659, max: 19.3737, mean: 2.0446, std: 4.2582
#
# Step/epoch 1/13, Test metrics:
# precision@10: 0.004701987
# recall@10: 0.004703826
# ndcg@10: 0.004103523
# map@10: 0.001050805
# Epoch 13, Step 10, LR: 0.000300, Current Loss: 1.0236, Avg Loss: 1.0255
# Diff stats — min: -13.5028, max: 19.2948, mean: 2.1185, std: 4.4194
#
# Step/epoch 10/13, Test metrics:
# precision@10: 0.004718543
# recall@10: 0.004720383
# ndcg@10: 0.004156198
# map@10: 0.001076060
# Epoch 13, Step 20, LR: 0.000300, Current Loss: 0.9939, Avg Loss: 1.0146
# Diff stats — min: -12.4807, max: 20.5346, mean: 2.1322, std: 4.3349
#
# Step/epoch 20/13, Test metrics:
# precision@10: 0.004768212
# recall@10: 0.004770052
# ndcg@10: 0.004217844
# map@10: 0.001096664
# Epoch 13, Step 30, LR: 0.000300, Current Loss: 0.9568, Avg Loss: 1.0039
# Diff stats — min: -13.5129, max: 16.7146, mean: 2.2057, std: 4.3142
#
# Step/epoch 30/13, Test metrics:
# precision@10: 0.004701987
# recall@10: 0.004703826
# ndcg@10: 0.004164699
# map@10: 0.001083971
# Epoch 13, Step 40, LR: 0.000300, Current Loss: 0.9786, Avg Loss: 0.9984
# Diff stats — min: -16.0009, max: 16.1033, mean: 2.1453, std: 4.2723
#
# Step/epoch 40/13, Test metrics:
# precision@10: 0.004735099
# recall@10: 0.004736939
# ndcg@10: 0.004174837
# map@10: 0.001080850
# Epoch 13, Step 50, LR: 0.000300, Current Loss: 0.8979, Avg Loss: 0.9897
# Diff stats — min: -12.8521, max: 16.3717, mean: 2.2427, std: 4.1641
#
# Step/epoch 50/13, Test metrics:
# precision@10: 0.004668874
# recall@10: 0.004670714
# ndcg@10: 0.004136380
# map@10: 0.001074562
# Epoch 13 completed, Train Loss: 0.9877
# Epoch 14, Step 1, LR: 0.000300, Current Loss: 0.9451, Avg Loss: 0.9451
# Diff stats — min: -12.8621, max: 16.0663, mean: 2.1576, std: 4.1961
#
# Step/epoch 1/14, Test metrics:
# precision@10: 0.004668874
# recall@10: 0.004670714
# ndcg@10: 0.004139391
# map@10: 0.001076120
# Epoch 14, Step 10, LR: 0.000300, Current Loss: 0.9326, Avg Loss: 0.9460
# Diff stats — min: -12.9482, max: 19.6861, mean: 2.1528, std: 4.1645
#
# Step/epoch 10/14, Test metrics:
# precision@10: 0.004668874
# recall@10: 0.004670714
# ndcg@10: 0.004112309
# map@10: 0.001061179
# Epoch 14, Step 20, LR: 0.000300, Current Loss: 0.8954, Avg Loss: 0.9393
# Diff stats — min: -14.5472, max: 17.8809, mean: 2.2736, std: 4.1620
#
# Step/epoch 20/14, Test metrics:
# precision@10: 0.004701987
# recall@10: 0.004703826
# ndcg@10: 0.004119172
# map@10: 0.001057770
# Epoch 14, Step 30, LR: 0.000300, Current Loss: 0.9397, Avg Loss: 0.9316
# Diff stats — min: -13.4857, max: 16.0394, mean: 2.0959, std: 4.1103
#
# Step/epoch 30/14, Test metrics:
# precision@10: 0.004751656
# recall@10: 0.004753495
# ndcg@10: 0.004158373
# map@10: 0.001068203
# Epoch 14, Step 40, LR: 0.000300, Current Loss: 0.8868, Avg Loss: 0.9238
# Diff stats — min: -13.8179, max: 16.1688, mean: 2.2504, std: 4.1220
#
# Step/epoch 40/14, Test metrics:
# precision@10: 0.004817881
# recall@10: 0.004819720
# ndcg@10: 0.004209163
# map@10: 0.001077893
# Epoch 14, Step 50, LR: 0.000300, Current Loss: 0.8810, Avg Loss: 0.9155
# Diff stats — min: -12.9836, max: 17.0503, mean: 2.2107, std: 4.0612
#
# Step/epoch 50/14, Test metrics:
# precision@10: 0.004867550
# recall@10: 0.004869389
# ndcg@10: 0.004234754
# map@10: 0.001079779
# Epoch 14 completed, Train Loss: 0.9138
# Epoch 15, Step 1, LR: 0.000300, Current Loss: 0.8790, Avg Loss: 0.8790
# Diff stats — min: -13.0251, max: 15.1765, mean: 2.1846, std: 4.0663
#
# Step/epoch 1/15, Test metrics:
# precision@10: 0.004867550
# recall@10: 0.004869389
# ndcg@10: 0.004246948
# map@10: 0.001087985
# Epoch 15, Step 10, LR: 0.000300, Current Loss: 0.8411, Avg Loss: 0.8706
# Diff stats — min: -13.2786, max: 16.6796, mean: 2.2439, std: 3.9850
#
# Step/epoch 10/15, Test metrics:
# precision@10: 0.004867550
# recall@10: 0.004869389
# ndcg@10: 0.004263893
# map@10: 0.001094732
# Epoch 15, Step 20, LR: 0.000300, Current Loss: 0.8240, Avg Loss: 0.8641
# Diff stats — min: -14.5321, max: 16.6167, mean: 2.2936, std: 3.9493
#
# Step/epoch 20/15, Test metrics:
# precision@10: 0.004950331
# recall@10: 0.004952171
# ndcg@10: 0.004372371
# map@10: 0.001137240
# Epoch 15, Step 30, LR: 0.000300, Current Loss: 0.8341, Avg Loss: 0.8584
# Diff stats — min: -10.7321, max: 15.4177, mean: 2.2228, std: 3.9327
#
# Step/epoch 30/15, Test metrics:
# precision@10: 0.005066225
# recall@10: 0.005068065
# ndcg@10: 0.004463621
# map@10: 0.001162324
# Epoch 15, Step 40, LR: 0.000300, Current Loss: 0.8208, Avg Loss: 0.8535
# Diff stats — min: -12.3152, max: 18.6777, mean: 2.2069, std: 3.8731
#
# Step/epoch 40/15, Test metrics:
# precision@10: 0.005049669
# recall@10: 0.005051508
# ndcg@10: 0.004482366
# map@10: 0.001176311
# Epoch 15, Step 50, LR: 0.000300, Current Loss: 0.8237, Avg Loss: 0.8469
# Diff stats — min: -13.5879, max: 15.8623, mean: 2.2181, std: 3.8849
#
# Step/epoch 50/15, Test metrics:
# precision@10: 0.005149007
# recall@10: 0.005150846
# ndcg@10: 0.004550128
# map@10: 0.001191941
# Epoch 15 completed, Train Loss: 0.8460
# Epoch 16, Step 1, LR: 0.000300, Current Loss: 0.8029, Avg Loss: 0.8029
# Diff stats — min: -11.1226, max: 16.1286, mean: 2.1857, std: 3.7906
#
# Step/epoch 1/16, Test metrics:
# precision@10: 0.005182119
# recall@10: 0.005183959
# ndcg@10: 0.004576023
# map@10: 0.001197611
# Epoch 16, Step 10, LR: 0.000300, Current Loss: 0.8260, Avg Loss: 0.8119
# Diff stats — min: -12.9033, max: 15.5946, mean: 2.1262, std: 3.8089
#
# Step/epoch 10/16, Test metrics:
# precision@10: 0.005182119
# recall@10: 0.005183959
# ndcg@10: 0.004574738
# map@10: 0.001195837
# Epoch 16, Step 20, LR: 0.000300, Current Loss: 0.7933, Avg Loss: 0.8088
# Diff stats — min: -12.0572, max: 14.1241, mean: 2.2407, std: 3.8056
#
# Step/epoch 20/16, Test metrics:
# precision@10: 0.005132450
# recall@10: 0.005134290
# ndcg@10: 0.004551989
# map@10: 0.001191534
# Epoch 16, Step 30, LR: 0.000300, Current Loss: 0.8213, Avg Loss: 0.8079
# Diff stats — min: -12.8578, max: 16.3959, mean: 2.1782, std: 3.8528
#
# Step/epoch 30/16, Test metrics:
# precision@10: 0.005182119
# recall@10: 0.005183959
# ndcg@10: 0.004592905
# map@10: 0.001201172
# Epoch 16, Step 40, LR: 0.000300, Current Loss: 0.7376, Avg Loss: 0.8016
# Diff stats — min: -11.4503, max: 16.5737, mean: 2.3508, std: 3.7609
#
# Step/epoch 40/16, Test metrics:
# precision@10: 0.005281457
# recall@10: 0.005283297
# ndcg@10: 0.004658622
# map@10: 0.001214194
# Epoch 16, Step 50, LR: 0.000300, Current Loss: 0.7756, Avg Loss: 0.7963
# Diff stats — min: -12.5878, max: 16.1245, mean: 2.2614, std: 3.7886
#
# Step/epoch 50/16, Test metrics:
# precision@10: 0.005331126
# recall@10: 0.005332965
# ndcg@10: 0.004693447
# map@10: 0.001223911
# Epoch 16 completed, Train Loss: 0.7946
# Epoch 17, Step 1, LR: 0.000300, Current Loss: 0.7613, Avg Loss: 0.7613
# Diff stats — min: -12.5167, max: 19.3711, mean: 2.2398, std: 3.7357
#
# Step/epoch 1/17, Test metrics:
# precision@10: 0.005397351
# recall@10: 0.005399191
# ndcg@10: 0.004740407
# map@10: 0.001232767
# Epoch 17, Step 10, LR: 0.000300, Current Loss: 0.7501, Avg Loss: 0.7630
# Diff stats — min: -11.8635, max: 17.1676, mean: 2.2048, std: 3.6736
#
# Step/epoch 10/17, Test metrics:
# precision@10: 0.005562914
# recall@10: 0.005564753
# ndcg@10: 0.004879113
# map@10: 0.001268389
# Epoch 17, Step 20, LR: 0.000300, Current Loss: 0.7667, Avg Loss: 0.7553
# Diff stats — min: -11.7361, max: 16.0214, mean: 2.2318, std: 3.7235
#
# Step/epoch 20/17, Test metrics:
# precision@10: 0.005596026
# recall@10: 0.005597866
# ndcg@10: 0.004895064
# map@10: 0.001269644
# Epoch 17, Step 30, LR: 0.000300, Current Loss: 0.6980, Avg Loss: 0.7516
# Diff stats — min: -12.1460, max: 15.4945, mean: 2.3960, std: 3.6453
#
# Step/epoch 30/17, Test metrics:
# precision@10: 0.005546358
# recall@10: 0.005548197
# ndcg@10: 0.004865057
# map@10: 0.001262949
# Epoch 17, Step 40, LR: 0.000300, Current Loss: 0.7345, Avg Loss: 0.7479
# Diff stats — min: -12.7278, max: 17.0680, mean: 2.2648, std: 3.6702
#
# Step/epoch 40/17, Test metrics:
# precision@10: 0.005678808
# recall@10: 0.005680648
# ndcg@10: 0.004960188
# map@10: 0.001286621
# Epoch 17, Step 50, LR: 0.000300, Current Loss: 0.7029, Avg Loss: 0.7438
# Diff stats — min: -13.4602, max: 15.3197, mean: 2.2747, std: 3.5715
#
# Step/epoch 50/17, Test metrics:
# precision@10: 0.005695364
# recall@10: 0.005697204
# ndcg@10: 0.005024113
# map@10: 0.001317579
# Epoch 17 completed, Train Loss: 0.7424
# Epoch 18, Step 1, LR: 0.000300, Current Loss: 0.6920, Avg Loss: 0.6920
# Diff stats — min: -13.1050, max: 17.0643, mean: 2.3179, std: 3.5748
#
# Step/epoch 1/18, Test metrics:
# precision@10: 0.005728477
# recall@10: 0.005730316
# ndcg@10: 0.005066818
# map@10: 0.001334654
# Epoch 18, Step 10, LR: 0.000300, Current Loss: 0.6810, Avg Loss: 0.7086
# Diff stats — min: -9.9812, max: 14.8601, mean: 2.3092, std: 3.5138
#
# Step/epoch 10/18, Test metrics:
# precision@10: 0.005877483
# recall@10: 0.005879323
# ndcg@10: 0.005157409
# map@10: 0.001351322
# Epoch 18, Step 20, LR: 0.000300, Current Loss: 0.7181, Avg Loss: 0.7089
# Diff stats — min: -12.4700, max: 14.5228, mean: 2.2491, std: 3.5801
#
# Step/epoch 20/18, Test metrics:
# precision@10: 0.005894040
# recall@10: 0.005895879
# ndcg@10: 0.005178705
# map@10: 0.001356998
# Epoch 18, Step 30, LR: 0.000300, Current Loss: 0.7126, Avg Loss: 0.7060
# Diff stats — min: -12.7712, max: 16.8204, mean: 2.2580, std: 3.5589
#
# Step/epoch 30/18, Test metrics:
# precision@10: 0.006043046
# recall@10: 0.006044886
# ndcg@10: 0.005286135
# map@10: 0.001378180
# Epoch 18, Step 40, LR: 0.000300, Current Loss: 0.6948, Avg Loss: 0.7007
# Diff stats — min: -10.5104, max: 15.8465, mean: 2.2154, std: 3.4856
#
# Step/epoch 40/18, Test metrics:
# precision@10: 0.006142384
# recall@10: 0.006144224
# ndcg@10: 0.005390873
# map@10: 0.001413283
# Epoch 18, Step 50, LR: 0.000300, Current Loss: 0.6664, Avg Loss: 0.6951
# Diff stats — min: -9.4075, max: 17.3763, mean: 2.2887, std: 3.4327
#
# Step/epoch 50/18, Test metrics:
# precision@10: 0.006158940
# recall@10: 0.006160780
# ndcg@10: 0.005403717
# map@10: 0.001417692
# Epoch 18 completed, Train Loss: 0.6946
# Epoch 19, Step 1, LR: 0.000300, Current Loss: 0.6898, Avg Loss: 0.6898
# Diff stats — min: -11.4151, max: 15.7595, mean: 2.2206, std: 3.4657
#
# Step/epoch 1/19, Test metrics:
# precision@10: 0.006142384
# recall@10: 0.006144224
# ndcg@10: 0.005397180
# map@10: 0.001418086
# Epoch 19, Step 10, LR: 0.000300, Current Loss: 0.6563, Avg Loss: 0.6771
# Diff stats — min: -12.3941, max: 14.7901, mean: 2.2977, std: 3.4313
#
# Step/epoch 10/19, Test metrics:
# precision@10: 0.006192053
# recall@10: 0.006193893
# ndcg@10: 0.005469291
# map@10: 0.001445555
# Epoch 19, Step 20, LR: 0.000300, Current Loss: 0.6623, Avg Loss: 0.6707
# Diff stats — min: -9.6703, max: 14.4972, mean: 2.2863, std: 3.4474
#
# Step/epoch 20/19, Test metrics:
# precision@10: 0.006274834
# recall@10: 0.006276674
# ndcg@10: 0.005559338
# map@10: 0.001475455
# Epoch 19, Step 30, LR: 0.000300, Current Loss: 0.6506, Avg Loss: 0.6692
# Diff stats — min: -11.6352, max: 14.2256, mean: 2.2900, std: 3.3920
#
# Step/epoch 30/19, Test metrics:
# precision@10: 0.006258278
# recall@10: 0.006260118
# ndcg@10: 0.005550019
# map@10: 0.001474351
# Epoch 19, Step 40, LR: 0.000300, Current Loss: 0.6221, Avg Loss: 0.6627
# Diff stats — min: -11.7330, max: 15.3869, mean: 2.3585, std: 3.3779
#
# Step/epoch 40/19, Test metrics:
# precision@10: 0.006307947
# recall@10: 0.006309787
# ndcg@10: 0.005601949
# map@10: 0.001488036
# Epoch 19, Step 50, LR: 0.000300, Current Loss: 0.6717, Avg Loss: 0.6576
# Diff stats — min: -11.7870, max: 13.6263, mean: 2.2624, std: 3.4336
#
# Step/epoch 50/19, Test metrics:
# precision@10: 0.006390728
# recall@10: 0.006392568
# ndcg@10: 0.005675087
# map@10: 0.001513528
# Epoch 19 completed, Train Loss: 0.6565
# Epoch 20, Step 1, LR: 0.000300, Current Loss: 0.6132, Avg Loss: 0.6132
# Diff stats — min: -9.6437, max: 14.1606, mean: 2.3121, std: 3.2879
#
# Step/epoch 1/20, Test metrics:
# precision@10: 0.006390728
# recall@10: 0.006392568
# ndcg@10: 0.005696412
# map@10: 0.001526431
# Epoch 20, Step 10, LR: 0.000300, Current Loss: 0.6519, Avg Loss: 0.6281
# Diff stats — min: -10.6261, max: 13.6519, mean: 2.2081, std: 3.3108
#
# Step/epoch 10/20, Test metrics:
# precision@10: 0.006539735
# recall@10: 0.006541575
# ndcg@10: 0.005813168
# map@10: 0.001552389
# Epoch 20, Step 20, LR: 0.000300, Current Loss: 0.6337, Avg Loss: 0.6284
# Diff stats — min: -10.0621, max: 15.1136, mean: 2.2569, std: 3.2914
#
# Step/epoch 20/20, Test metrics:
# precision@10: 0.006639073
# recall@10: 0.006640912
# ndcg@10: 0.005876086
# map@10: 0.001563321
# Epoch 20, Step 30, LR: 0.000300, Current Loss: 0.6343, Avg Loss: 0.6241
# Diff stats — min: -8.9501, max: 16.2774, mean: 2.3131, std: 3.3829
#
# Step/epoch 30/20, Test metrics:
# precision@10: 0.006721854
# recall@10: 0.006723694
# ndcg@10: 0.005985024
# map@10: 0.001601769
# Epoch 20, Step 40, LR: 0.000300, Current Loss: 0.6149, Avg Loss: 0.6237
# Diff stats — min: -11.2393, max: 17.1933, mean: 2.3028, std: 3.2531
#
# Step/epoch 40/20, Test metrics:
# precision@10: 0.006837748
# recall@10: 0.006839588
# ndcg@10: 0.006095466
# map@10: 0.001634901
# Epoch 20, Step 50, LR: 0.000300, Current Loss: 0.5755, Avg Loss: 0.6198
# Diff stats — min: -10.9364, max: 14.5024, mean: 2.3822, std: 3.2320
#
# Step/epoch 50/20, Test metrics:
# precision@10: 0.006821192
# recall@10: 0.006823032
# ndcg@10: 0.006093689
# map@10: 0.001639178
# Epoch 20 completed, Train Loss: 0.6200
# Epoch 21, Step 1, LR: 0.000300, Current Loss: 0.5792, Avg Loss: 0.5792
# Diff stats — min: -10.2091, max: 13.2802, mean: 2.3359, std: 3.1864
#
# Step/epoch 1/21, Test metrics:
# precision@10: 0.006804636
# recall@10: 0.006806475
# ndcg@10: 0.006082164
# map@10: 0.001637016
# Epoch 21, Step 10, LR: 0.000300, Current Loss: 0.6106, Avg Loss: 0.5968
# Diff stats — min: -10.9868, max: 14.8212, mean: 2.2734, std: 3.2529
#
# Step/epoch 10/21, Test metrics:
# precision@10: 0.006920530
# recall@10: 0.006922369
# ndcg@10: 0.006184342
# map@10: 0.001662055
# Epoch 21, Step 20, LR: 0.000300, Current Loss: 0.5968, Avg Loss: 0.6023
# Diff stats — min: -10.0191, max: 12.9230, mean: 2.3120, std: 3.2310
#
# Step/epoch 20/21, Test metrics:
# precision@10: 0.007003311
# recall@10: 0.007005151
# ndcg@10: 0.006264359
# map@10: 0.001687940
# Epoch 21, Step 30, LR: 0.000300, Current Loss: 0.5658, Avg Loss: 0.5971
# Diff stats — min: -11.4714, max: 13.3680, mean: 2.3670, std: 3.1908
#
# Step/epoch 30/21, Test metrics:
# precision@10: 0.007102649
# recall@10: 0.007104489
# ndcg@10: 0.006353326
# map@10: 0.001710902
# Epoch 21, Step 40, LR: 0.000300, Current Loss: 0.5900, Avg Loss: 0.5937
# Diff stats — min: -10.2165, max: 14.7405, mean: 2.2935, std: 3.2037
#
# Step/epoch 40/21, Test metrics:
# precision@10: 0.007102649
# recall@10: 0.007104489
# ndcg@10: 0.006348636
# map@10: 0.001707230
# Epoch 21, Step 50, LR: 0.000300, Current Loss: 0.5724, Avg Loss: 0.5906
# Diff stats — min: -11.6778, max: 14.0394, mean: 2.3329, std: 3.1416
#
# Step/epoch 50/21, Test metrics:
# precision@10: 0.007218543
# recall@10: 0.007220383
# ndcg@10: 0.006472154
# map@10: 0.001744028
# Epoch 21 completed, Train Loss: 0.5895
# Epoch 22, Step 1, LR: 0.000300, Current Loss: 0.5744, Avg Loss: 0.5744
# Diff stats — min: -11.6978, max: 14.9285, mean: 2.2888, std: 3.1346
#
# Step/epoch 1/22, Test metrics:
# precision@10: 0.007334437
# recall@10: 0.007336277
# ndcg@10: 0.006573983
# map@10: 0.001774099
# Epoch 22, Step 10, LR: 0.000300, Current Loss: 0.5794, Avg Loss: 0.5676
# Diff stats — min: -9.0300, max: 15.2939, mean: 2.3166, std: 3.1854
#
# Step/epoch 10/22, Test metrics:
# precision@10: 0.007433775
# recall@10: 0.007435614
# ndcg@10: 0.006663925
# map@10: 0.001799853
# Epoch 22, Step 20, LR: 0.000300, Current Loss: 0.5611, Avg Loss: 0.5646
# Diff stats — min: -10.0456, max: 14.5548, mean: 2.3454, std: 3.1386
#
# Step/epoch 20/22, Test metrics:
# precision@10: 0.007649007
# recall@10: 0.007650846
# ndcg@10: 0.006862987
# map@10: 0.001855441
# Epoch 22, Step 30, LR: 0.000300, Current Loss: 0.5618, Avg Loss: 0.5620
# Diff stats — min: -8.5639, max: 15.8110, mean: 2.2872, std: 3.0854
#
# Step/epoch 30/22, Test metrics:
# precision@10: 0.007847682
# recall@10: 0.007849522
# ndcg@10: 0.007036086
# map@10: 0.001906023
# Epoch 22, Step 40, LR: 0.000300, Current Loss: 0.5488, Avg Loss: 0.5586
# Diff stats — min: -10.1883, max: 14.0918, mean: 2.3663, std: 3.0798
#
# Step/epoch 40/22, Test metrics:
# precision@10: 0.007880795
# recall@10: 0.007882634
# ndcg@10: 0.007064809
# map@10: 0.001912462
# Epoch 22, Step 50, LR: 0.000300, Current Loss: 0.5507, Avg Loss: 0.5564
# Diff stats — min: -8.1847, max: 12.6708, mean: 2.3263, std: 3.0636
#
# Step/epoch 50/22, Test metrics:
# precision@10: 0.007847682
# recall@10: 0.007849522
# ndcg@10: 0.007050639
# map@10: 0.001912909
# Epoch 22 completed, Train Loss: 0.5557
# Epoch 23, Step 1, LR: 0.000300, Current Loss: 0.5500, Avg Loss: 0.5500
# Diff stats — min: -8.7098, max: 14.8265, mean: 2.3436, std: 3.0854
#
# Step/epoch 1/23, Test metrics:
# precision@10: 0.007847682
# recall@10: 0.007849522
# ndcg@10: 0.007058049
# map@10: 0.001919347
# Epoch 23, Step 10, LR: 0.000300, Current Loss: 0.5358, Avg Loss: 0.5414
# Diff stats — min: -8.1901, max: 14.0965, mean: 2.3709, std: 3.0849
#
# Step/epoch 10/23, Test metrics:
# precision@10: 0.007913907
# recall@10: 0.007915747
# ndcg@10: 0.007116903
# map@10: 0.001931193
# Epoch 23, Step 20, LR: 0.000300, Current Loss: 0.5080, Avg Loss: 0.5336
# Diff stats — min: -12.0098, max: 13.0206, mean: 2.3776, std: 2.9882
#
# Step/epoch 20/23, Test metrics:
# precision@10: 0.007847682
# recall@10: 0.007849522
# ndcg@10: 0.007111738
# map@10: 0.001943643
# Epoch 23, Step 30, LR: 0.000300, Current Loss: 0.5459, Avg Loss: 0.5325
# Diff stats — min: -9.5315, max: 14.7867, mean: 2.2941, std: 3.0364
#
# Step/epoch 30/23, Test metrics:
# precision@10: 0.007996689
# recall@10: 0.007998528
# ndcg@10: 0.007213475
# map@10: 0.001960836
# Epoch 23, Step 40, LR: 0.000300, Current Loss: 0.5016, Avg Loss: 0.5311
# Diff stats — min: -11.1697, max: 12.5866, mean: 2.4225, std: 2.9739
#
# Step/epoch 40/23, Test metrics:
# precision@10: 0.008079470
# recall@10: 0.008081310
# ndcg@10: 0.007266807
# map@10: 0.001970271
# Epoch 23, Step 50, LR: 0.000300, Current Loss: 0.5264, Avg Loss: 0.5289
# Diff stats — min: -9.0816, max: 13.3195, mean: 2.2437, std: 2.9055
#
# Step/epoch 50/23, Test metrics:
# precision@10: 0.008178808
# recall@10: 0.008180648
# ndcg@10: 0.007369082
# map@10: 0.002004041
# Epoch 23 completed, Train Loss: 0.5285
# Epoch 24, Step 1, LR: 0.000300, Current Loss: 0.5385, Avg Loss: 0.5385
# Diff stats — min: -8.7970, max: 14.0330, mean: 2.2545, std: 2.9677
#
# Step/epoch 1/24, Test metrics:
# precision@10: 0.008178808
# recall@10: 0.008180648
# ndcg@10: 0.007375378
# map@10: 0.002007312
# Epoch 24, Step 10, LR: 0.000300, Current Loss: 0.5269, Avg Loss: 0.5224
# Diff stats — min: -9.6556, max: 13.5863, mean: 2.3061, std: 2.9941
#
# Step/epoch 10/24, Test metrics:
# precision@10: 0.008344371
# recall@10: 0.008346210
# ndcg@10: 0.007513797
# map@10: 0.002043296
# Epoch 24, Step 20, LR: 0.000300, Current Loss: 0.5033, Avg Loss: 0.5168
# Diff stats — min: -8.6551, max: 14.4277, mean: 2.3551, std: 2.9612
#
# Step/epoch 20/24, Test metrics:
# precision@10: 0.008509934
# recall@10: 0.008511773
# ndcg@10: 0.007666333
# map@10: 0.002083596
# Epoch 24, Step 30, LR: 0.000300, Current Loss: 0.5120, Avg Loss: 0.5175
# Diff stats — min: -9.2340, max: 13.8182, mean: 2.3679, std: 2.9712
#
# Step/epoch 30/24, Test metrics:
# precision@10: 0.008758278
# recall@10: 0.008760118
# ndcg@10: 0.007864810
# map@10: 0.002131846
# Epoch 24, Step 40, LR: 0.000300, Current Loss: 0.5201, Avg Loss: 0.5148
# Diff stats — min: -8.9856, max: 15.4719, mean: 2.2795, std: 2.9390
#
# Step/epoch 40/24, Test metrics:
# precision@10: 0.008857616
# recall@10: 0.008859455
# ndcg@10: 0.007955826
# map@10: 0.002158375
# Epoch 24, Step 50, LR: 0.000300, Current Loss: 0.4975, Avg Loss: 0.5125
# Diff stats — min: -9.9396, max: 15.1359, mean: 2.3515, std: 2.8871
#
# Step/epoch 50/24, Test metrics:
# precision@10: 0.008923841
# recall@10: 0.008925681
# ndcg@10: 0.008017049
# map@10: 0.002177185
# Epoch 24 completed, Train Loss: 0.5120
# Epoch 25, Step 1, LR: 0.000300, Current Loss: 0.5144, Avg Loss: 0.5144
# Diff stats — min: -9.2310, max: 15.2753, mean: 2.3039, std: 2.9434
#
# Step/epoch 1/25, Test metrics:
# precision@10: 0.008940397
# recall@10: 0.008942237
# ndcg@10: 0.008024024
# map@10: 0.002176213
# Epoch 25, Step 10, LR: 0.000300, Current Loss: 0.4811, Avg Loss: 0.4973
# Diff stats — min: -9.0780, max: 12.7844, mean: 2.3831, std: 2.8905
#
# Step/epoch 10/25, Test metrics:
# precision@10: 0.009155629
# recall@10: 0.009157469
# ndcg@10: 0.008213591
# map@10: 0.002224206
# Epoch 25, Step 20, LR: 0.000300, Current Loss: 0.4858, Avg Loss: 0.4897
# Diff stats — min: -7.9721, max: 13.2467, mean: 2.3546, std: 2.8661
#
# Step/epoch 20/25, Test metrics:
# precision@10: 0.009337748
# recall@10: 0.009339588
# ndcg@10: 0.008393478
# map@10: 0.002283297
# Epoch 25, Step 30, LR: 0.000300, Current Loss: 0.5004, Avg Loss: 0.4863
# Diff stats — min: -11.0497, max: 13.6515, mean: 2.3243, std: 2.8971
#
# Step/epoch 30/25, Test metrics:
# precision@10: 0.009519868
# recall@10: 0.009521707
# ndcg@10: 0.008579822
# map@10: 0.002338307
# Epoch 25, Step 40, LR: 0.000300, Current Loss: 0.4910, Avg Loss: 0.4882
# Diff stats — min: -9.2063, max: 13.6575, mean: 2.3462, std: 2.9024
#
# Step/epoch 40/25, Test metrics:
# precision@10: 0.009420530
# recall@10: 0.009422369
# ndcg@10: 0.008565395
# map@10: 0.002354055
# Epoch 25, Step 50, LR: 0.000300, Current Loss: 0.4840, Avg Loss: 0.4858
# Diff stats — min: -7.5599, max: 12.0035, mean: 2.3562, std: 2.8509
#
# Step/epoch 50/25, Test metrics:
# precision@10: 0.009437086
# recall@10: 0.009438926
# ndcg@10: 0.008601670
# map@10: 0.002367832
# Epoch 25 completed, Train Loss: 0.4856
# Epoch 26, Step 1, LR: 0.000300, Current Loss: 0.4760, Avg Loss: 0.4760
# Diff stats — min: -9.4860, max: 12.3008, mean: 2.3889, std: 2.8485
#
# Step/epoch 1/26, Test metrics:
# precision@10: 0.009453642
# recall@10: 0.009455482
# ndcg@10: 0.008634207
# map@10: 0.002380401
# Epoch 26, Step 10, LR: 0.000300, Current Loss: 0.4584, Avg Loss: 0.4763
# Diff stats — min: -7.3985, max: 18.0914, mean: 2.3609, std: 2.7604
#
# Step/epoch 10/26, Test metrics:
# precision@10: 0.009586093
# recall@10: 0.009587932
# ndcg@10: 0.008774343
# map@10: 0.002426167
# Epoch 26, Step 20, LR: 0.000300, Current Loss: 0.4720, Avg Loss: 0.4717
# Diff stats — min: -8.0690, max: 12.7152, mean: 2.3851, std: 2.8182
#
# Step/epoch 20/26, Test metrics:
# precision@10: 0.009850993
# recall@10: 0.009852833
# ndcg@10: 0.009047936
# map@10: 0.002512424
# Epoch 26, Step 30, LR: 0.000300, Current Loss: 0.4574, Avg Loss: 0.4703
# Diff stats — min: -7.7114, max: 12.1044, mean: 2.3504, std: 2.7590
#
# Step/epoch 30/26, Test metrics:
# precision@10: 0.009966887
# recall@10: 0.009970567
# ndcg@10: 0.009155561
# map@10: 0.002542606
# Epoch 26, Step 40, LR: 0.000300, Current Loss: 0.4527, Avg Loss: 0.4696
# Diff stats — min: -8.5816, max: 14.0883, mean: 2.3812, std: 2.7445
#
# Step/epoch 40/26, Test metrics:
# precision@10: 0.010198675
# recall@10: 0.010202355
# ndcg@10: 0.009331226
# map@10: 0.002584233
# Epoch 26, Step 50, LR: 0.000300, Current Loss: 0.4756, Avg Loss: 0.4687
# Diff stats — min: -7.5734, max: 12.2926, mean: 2.3275, std: 2.7733
#
# Step/epoch 50/26, Test metrics:
# precision@10: 0.010463576
# recall@10: 0.010467255
# ndcg@10: 0.009509720
# map@10: 0.002620375
# Epoch 26 completed, Train Loss: 0.4686
# Epoch 27, Step 1, LR: 0.000300, Current Loss: 0.4702, Avg Loss: 0.4702
# Diff stats — min: -8.4812, max: 12.4806, mean: 2.3273, std: 2.7829
#
# Step/epoch 1/27, Test metrics:
# precision@10: 0.010596026
# recall@10: 0.010599706
# ndcg@10: 0.009614702
# map@10: 0.002645669
# Epoch 27, Step 10, LR: 0.000300, Current Loss: 0.4524, Avg Loss: 0.4623
# Diff stats — min: -10.3850, max: 12.4116, mean: 2.3807, std: 2.7653
#
# Step/epoch 10/27, Test metrics:
# precision@10: 0.010678808
# recall@10: 0.010682487
# ndcg@10: 0.009706163
# map@10: 0.002677422
# Epoch 27, Step 20, LR: 0.000300, Current Loss: 0.4542, Avg Loss: 0.4585
# Diff stats — min: -8.9134, max: 13.2519, mean: 2.3752, std: 2.7660
#
# Step/epoch 20/27, Test metrics:
# precision@10: 0.010894040
# recall@10: 0.010897719
# ndcg@10: 0.009849424
# map@10: 0.002703393
# Epoch 27, Step 30, LR: 0.000300, Current Loss: 0.4278, Avg Loss: 0.4558
# Diff stats — min: -7.9282, max: 14.2175, mean: 2.3801, std: 2.6563
#
# Step/epoch 30/27, Test metrics:
# precision@10: 0.011009934
# recall@10: 0.011013613
# ndcg@10: 0.009966332
# map@10: 0.002738956
# Epoch 27, Step 40, LR: 0.000300, Current Loss: 0.4317, Avg Loss: 0.4533
# Diff stats — min: -9.6660, max: 11.6628, mean: 2.4171, std: 2.7211
#
# Step/epoch 40/27, Test metrics:
# precision@10: 0.011274834
# recall@10: 0.011278514
# ndcg@10: 0.010194978
# map@10: 0.002803717
# Epoch 27, Step 50, LR: 0.000300, Current Loss: 0.4508, Avg Loss: 0.4510
# Diff stats — min: -8.6631, max: 14.2859, mean: 2.3583, std: 2.7579
#
# Step/epoch 50/27, Test metrics:
# precision@10: 0.011440397
# recall@10: 0.011444077
# ndcg@10: 0.010380172
# map@10: 0.002864699
# Epoch 27 completed, Train Loss: 0.4502
# Epoch 28, Step 1, LR: 0.000300, Current Loss: 0.4379, Avg Loss: 0.4379
# Diff stats — min: -9.3347, max: 12.2091, mean: 2.3683, std: 2.6886
#
# Step/epoch 1/28, Test metrics:
# precision@10: 0.011490066
# recall@10: 0.011493745
# ndcg@10: 0.010427676
# map@10: 0.002876019
# Epoch 28, Step 10, LR: 0.000300, Current Loss: 0.4409, Avg Loss: 0.4427
# Diff stats — min: -11.1664, max: 13.0251, mean: 2.3550, std: 2.7121
#
# Step/epoch 10/28, Test metrics:
# precision@10: 0.011622517
# recall@10: 0.011626196
# ndcg@10: 0.010542923
# map@10: 0.002906174
# Epoch 28, Step 20, LR: 0.000300, Current Loss: 0.4245, Avg Loss: 0.4388
# Diff stats — min: -9.2341, max: 14.1013, mean: 2.4293, std: 2.6927
#
# Step/epoch 20/28, Test metrics:
# precision@10: 0.011837748
# recall@10: 0.011841428
# ndcg@10: 0.010755445
# map@10: 0.002973580
# Epoch 28, Step 30, LR: 0.000300, Current Loss: 0.4339, Avg Loss: 0.4348
# Diff stats — min: -7.5346, max: 12.2312, mean: 2.3097, std: 2.6157
#
# Step/epoch 30/28, Test metrics:
# precision@10: 0.011986755
# recall@10: 0.011990434
# ndcg@10: 0.010902520
# map@10: 0.003014649
# Epoch 28, Step 40, LR: 0.000300, Current Loss: 0.4353, Avg Loss: 0.4340
# Diff stats — min: -7.7009, max: 12.2244, mean: 2.3790, std: 2.6753
#
# Step/epoch 40/28, Test metrics:
# precision@10: 0.012102649
# recall@10: 0.012106328
# ndcg@10: 0.011016850
# map@10: 0.003049555
# Epoch 28, Step 50, LR: 0.000300, Current Loss: 0.4317, Avg Loss: 0.4335
# Diff stats — min: -8.2881, max: 11.3665, mean: 2.3823, std: 2.6638
#
# Step/epoch 50/28, Test metrics:
# precision@10: 0.012268212
# recall@10: 0.012271891
# ndcg@10: 0.011180725
# map@10: 0.003104145
# Epoch 28 completed, Train Loss: 0.4336
# Epoch 29, Step 1, LR: 0.000300, Current Loss: 0.4204, Avg Loss: 0.4204
# Diff stats — min: -6.7424, max: 14.2109, mean: 2.3953, std: 2.6545
#
# Step/epoch 1/29, Test metrics:
# precision@10: 0.012251656
# recall@10: 0.012255335
# ndcg@10: 0.011173937
# map@10: 0.003103212
# Epoch 29, Step 10, LR: 0.000300, Current Loss: 0.4222, Avg Loss: 0.4222
# Diff stats — min: -7.1534, max: 12.5588, mean: 2.3771, std: 2.6270
#
# Step/epoch 10/29, Test metrics:
# precision@10: 0.012317881
# recall@10: 0.012321560
# ndcg@10: 0.011273976
# map@10: 0.003145045
# Epoch 29, Step 20, LR: 0.000300, Current Loss: 0.4518, Avg Loss: 0.4210
# Diff stats — min: -8.0030, max: 11.9434, mean: 2.2671, std: 2.6504
#
# Step/epoch 20/29, Test metrics:
# precision@10: 0.012400662
# recall@10: 0.012404341
# ndcg@10: 0.011372571
# map@10: 0.003181061
# Epoch 29, Step 30, LR: 0.000300, Current Loss: 0.4233, Avg Loss: 0.4212
# Diff stats — min: -8.3837, max: 11.2367, mean: 2.3928, std: 2.6674
#
# Step/epoch 30/29, Test metrics:
# precision@10: 0.012549669
# recall@10: 0.012553348
# ndcg@10: 0.011582777
# map@10: 0.003262056
# Epoch 29, Step 40, LR: 0.000300, Current Loss: 0.4304, Avg Loss: 0.4187
# Diff stats — min: -8.5023, max: 12.4328, mean: 2.3378, std: 2.6425
#
# Step/epoch 40/29, Test metrics:
# precision@10: 0.012831126
# recall@10: 0.012834805
# ndcg@10: 0.011896124
# map@10: 0.003366466
# Epoch 29, Step 50, LR: 0.000300, Current Loss: 0.4196, Avg Loss: 0.4190
# Diff stats — min: -7.8108, max: 11.2610, mean: 2.3564, std: 2.6292
#
# Step/epoch 50/29, Test metrics:
# precision@10: 0.013145695
# recall@10: 0.013149375
# ndcg@10: 0.012159924
# map@10: 0.003432940
# Epoch 29 completed, Train Loss: 0.4187
# Epoch 30, Step 1, LR: 0.000300, Current Loss: 0.4051, Avg Loss: 0.4051
# Diff stats — min: -7.2884, max: 12.9750, mean: 2.4064, std: 2.6014
#
# Step/epoch 1/30, Test metrics:
# precision@10: 0.013261589
# recall@10: 0.013265269
# ndcg@10: 0.012256796
# map@10: 0.003457716
# Epoch 30, Step 10, LR: 0.000300, Current Loss: 0.4130, Avg Loss: 0.4116
# Diff stats — min: -8.1947, max: 13.6320, mean: 2.3551, std: 2.5929
#
# Step/epoch 10/30, Test metrics:
# precision@10: 0.013559603
# recall@10: 0.013563282
# ndcg@10: 0.012506034
# map@10: 0.003531089
# Epoch 30, Step 20, LR: 0.000300, Current Loss: 0.3979, Avg Loss: 0.4124
# Diff stats — min: -5.8130, max: 13.3222, mean: 2.4189, std: 2.5784
#
# Step/epoch 20/30, Test metrics:
# precision@10: 0.013807947
# recall@10: 0.013811626
# ndcg@10: 0.012702794
# map@10: 0.003574996
# Epoch 30, Step 30, LR: 0.000300, Current Loss: 0.4093, Avg Loss: 0.4089
# Diff stats — min: -11.2088, max: 11.7489, mean: 2.3525, std: 2.5797
#
# Step/epoch 30/30, Test metrics:
# precision@10: 0.014139073
# recall@10: 0.014142752
# ndcg@10: 0.012979516
# map@10: 0.003649867
# Epoch 30, Step 40, LR: 0.000300, Current Loss: 0.4054, Avg Loss: 0.4080
# Diff stats — min: -8.0419, max: 14.4453, mean: 2.4310, std: 2.6461
#
# Step/epoch 40/30, Test metrics:
# precision@10: 0.014238411
# recall@10: 0.014242090
# ndcg@10: 0.013099384
# ...
#
# Step/epoch 1/91, Test metrics:
# precision@10: 0.032980132
# recall@10: 0.032985651
# ndcg@10: 0.034606344
# map@10: 0.012414527
# Epoch 91, Step 10, LR: 0.000300, Current Loss: 0.2430, Avg Loss: 0.2350
# Diff stats — min: -4.8302, max: 12.8374, mean: 3.3281, std: 2.6005
#
# Step/epoch 10/91, Test metrics:
# precision@10: 0.032963576
# recall@10: 0.032969095
# ndcg@10: 0.034582152
# map@10: 0.012401037
# Epoch 91, Step 20, LR: 0.000300, Current Loss: 0.2296, Avg Loss: 0.2353
# Diff stats — min: -6.1759, max: 12.9546, mean: 3.3452, std: 2.5599
#
# Step/epoch 20/91, Test metrics:
# precision@10: 0.032748344
# recall@10: 0.032753863
# ndcg@10: 0.034346962
# map@10: 0.012310562
# Epoch 91, Step 30, LR: 0.000300, Current Loss: 0.2417, Avg Loss: 0.2357
# Diff stats — min: -5.1810, max: 12.8022, mean: 3.3112, std: 2.5860
#
# Step/epoch 30/91, Test metrics:
# precision@10: 0.032880795
# recall@10: 0.032886313
# ndcg@10: 0.034209986
# map@10: 0.012223346
# Epoch 91, Step 40, LR: 0.000300, Current Loss: 0.2371, Avg Loss: 0.2352
# Diff stats — min: -6.6934, max: 13.0178, mean: 3.3512, std: 2.5846
#
# Step/epoch 40/91, Test metrics:
# precision@10: 0.032649007
# recall@10: 0.032654525
# ndcg@10: 0.034005906
# map@10: 0.012129014
# Epoch 91, Step 50, LR: 0.000300, Current Loss: 0.2259, Avg Loss: 0.2340
# Diff stats — min: -5.4404, max: 11.8057, mean: 3.4013, std: 2.5578
#
# Step/epoch 50/91, Test metrics:
# precision@10: 0.032831126
# recall@10: 0.032836645
# ndcg@10: 0.034329034
# map@10: 0.012298322
# Epoch 91 completed, Train Loss: 0.2341
# Epoch 92, Step 1, LR: 0.000300, Current Loss: 0.2330, Avg Loss: 0.2330
# Diff stats — min: -8.4624, max: 13.3854, mean: 3.3521, std: 2.5798
#
# Step/epoch 1/92, Test metrics:
# precision@10: 0.032764901
# recall@10: 0.032770419
# ndcg@10: 0.034244750
# map@10: 0.012273093
# Epoch 92, Step 10, LR: 0.000300, Current Loss: 0.2387, Avg Loss: 0.2382
# Diff stats — min: -9.2599, max: 11.5600, mean: 3.3400, std: 2.5970
#
# Step/epoch 10/92, Test metrics:
# precision@10: 0.032731788
# recall@10: 0.032737307
# ndcg@10: 0.034353084
# map@10: 0.012331443
# Epoch 92, Step 20, LR: 0.000300, Current Loss: 0.2327, Avg Loss: 0.2339
# Diff stats — min: -4.4526, max: 12.8087, mean: 3.3689, std: 2.5851
#
# Step/epoch 20/92, Test metrics:
# precision@10: 0.032897351
# recall@10: 0.032902870
# ndcg@10: 0.034378830
# map@10: 0.012323045
# Epoch 92, Step 30, LR: 0.000300, Current Loss: 0.2480, Avg Loss: 0.2340
# Diff stats — min: -6.1152, max: 13.1563, mean: 3.2699, std: 2.5903
#
# Step/epoch 30/92, Test metrics:
# precision@10: 0.032847682
# recall@10: 0.032853201
# ndcg@10: 0.034242730
# map@10: 0.012249244
# Epoch 92, Step 40, LR: 0.000300, Current Loss: 0.2346, Avg Loss: 0.2344
# Diff stats — min: -6.1821, max: 11.8967, mean: 3.3252, std: 2.5569
#
# Step/epoch 40/92, Test metrics:
# precision@10: 0.032566225
# recall@10: 0.032571744
# ndcg@10: 0.034015438
# map@10: 0.012142332
# Epoch 92, Step 50, LR: 0.000300, Current Loss: 0.2335, Avg Loss: 0.2336
# Diff stats — min: -4.8481, max: 12.8331, mean: 3.3770, std: 2.5998
#
# Step/epoch 50/92, Test metrics:
# precision@10: 0.032533113
# recall@10: 0.032538631
# ndcg@10: 0.033927394
# map@10: 0.012115316
# Epoch 92 completed, Train Loss: 0.2338
# Epoch 93, Step 1, LR: 0.000300, Current Loss: 0.2362, Avg Loss: 0.2362
# Diff stats — min: -5.5144, max: 12.8405, mean: 3.3039, std: 2.5406
#
# Step/epoch 1/93, Test metrics:
# precision@10: 0.032433775
# recall@10: 0.032439294
# ndcg@10: 0.033865788
# map@10: 0.012115244
# Epoch 93, Step 10, LR: 0.000300, Current Loss: 0.2271, Avg Loss: 0.2312
# Diff stats — min: -6.2722, max: 13.8258, mean: 3.3297, std: 2.5452
#
# Step/epoch 10/93, Test metrics:
# precision@10: 0.032500000
# recall@10: 0.032505519
# ndcg@10: 0.033914887
# map@10: 0.012115454
# Epoch 93, Step 20, LR: 0.000300, Current Loss: 0.2496, Avg Loss: 0.2321
# Diff stats — min: -6.5865, max: 13.3755, mean: 3.2422, std: 2.5567
#
# Step/epoch 20/93, Test metrics:
# precision@10: 0.032466887
# recall@10: 0.032472406
# ndcg@10: 0.033784029
# map@10: 0.012039472
# Epoch 93, Step 30, LR: 0.000300, Current Loss: 0.2457, Avg Loss: 0.2330
# Diff stats — min: -7.2540, max: 13.8390, mean: 3.3485, std: 2.6125
#
# Step/epoch 30/93, Test metrics:
# precision@10: 0.032665563
# recall@10: 0.032671082
# ndcg@10: 0.033913992
# map@10: 0.012073965
# Epoch 93, Step 40, LR: 0.000300, Current Loss: 0.2205, Avg Loss: 0.2320
# Diff stats — min: -7.2484, max: 11.5870, mean: 3.3728, std: 2.5155
#
# Step/epoch 40/93, Test metrics:
# precision@10: 0.032682119
# recall@10: 0.032687638
# ndcg@10: 0.033948857
# map@10: 0.012091460
# Epoch 93, Step 50, LR: 0.000300, Current Loss: 0.2362, Avg Loss: 0.2313
# Diff stats — min: -5.6285, max: 13.0648, mean: 3.2693, std: 2.5517
#
# Step/epoch 50/93, Test metrics:
# precision@10: 0.032201987
# recall@10: 0.032207506
# ndcg@10: 0.033588295
# map@10: 0.011986052
# Epoch 93 completed, Train Loss: 0.2315
# Epoch 94, Step 1, LR: 0.000300, Current Loss: 0.2466, Avg Loss: 0.2466
# Diff stats — min: -5.5248, max: 13.5333, mean: 3.2643, std: 2.5740
#
# Step/epoch 1/94, Test metrics:
# precision@10: 0.032301325
# recall@10: 0.032306843
# ndcg@10: 0.033656019
# map@10: 0.012013422
# Epoch 94, Step 10, LR: 0.000300, Current Loss: 0.2348, Avg Loss: 0.2333
# Diff stats — min: -7.5404, max: 12.0972, mean: 3.3142, std: 2.5444
#
# Step/epoch 10/94, Test metrics:
# precision@10: 0.032350993
# recall@10: 0.032356512
# ndcg@10: 0.033707125
# map@10: 0.012010939
# Epoch 94, Step 20, LR: 0.000300, Current Loss: 0.2463, Avg Loss: 0.2327
# Diff stats — min: -4.4172, max: 11.9152, mean: 3.2962, std: 2.5785
#
# Step/epoch 20/94, Test metrics:
# precision@10: 0.032185430
# recall@10: 0.032190949
# ndcg@10: 0.033498572
# map@10: 0.011900820
# Epoch 94, Step 30, LR: 0.000300, Current Loss: 0.2377, Avg Loss: 0.2320
# Diff stats — min: -5.0525, max: 12.0913, mean: 3.2946, std: 2.5645
#
# Step/epoch 30/94, Test metrics:
# precision@10: 0.032086093
# recall@10: 0.032091611
# ndcg@10: 0.033339526
# map@10: 0.011827315
# Epoch 94, Step 40, LR: 0.000300, Current Loss: 0.2388, Avg Loss: 0.2326
# Diff stats — min: -4.3443, max: 13.0318, mean: 3.3310, std: 2.5915
#
# Step/epoch 40/94, Test metrics:
# precision@10: 0.032235099
# recall@10: 0.032240618
# ndcg@10: 0.033531569
# map@10: 0.011922621
# Epoch 94, Step 50, LR: 0.000300, Current Loss: 0.2346, Avg Loss: 0.2326
# Diff stats — min: -6.1830, max: 11.7740, mean: 3.3616, std: 2.5652
#
# Step/epoch 50/94, Test metrics:
# precision@10: 0.032516556
# recall@10: 0.032522075
# ndcg@10: 0.033763986
# map@10: 0.012017824
# Epoch 94 completed, Train Loss: 0.2324
# Epoch 95, Step 1, LR: 0.000300, Current Loss: 0.2234, Avg Loss: 0.2234
# Diff stats — min: -5.4815, max: 12.0721, mean: 3.3717, std: 2.5450
#
# Step/epoch 1/95, Test metrics:
# precision@10: 0.032417219
# recall@10: 0.032422737
# ndcg@10: 0.033698895
# map@10: 0.012004027
# Epoch 95, Step 10, LR: 0.000300, Current Loss: 0.2468, Avg Loss: 0.2332
# Diff stats — min: -6.0973, max: 12.5743, mean: 3.3273, std: 2.6186
#
# Step/epoch 10/95, Test metrics:
# precision@10: 0.032500000
# recall@10: 0.032505519
# ndcg@10: 0.033829043
# map@10: 0.012061094
# Epoch 95, Step 20, LR: 0.000300, Current Loss: 0.2429, Avg Loss: 0.2346
# Diff stats — min: -5.1125, max: 14.0811, mean: 3.3221, std: 2.6030
#
# Step/epoch 20/95, Test metrics:
# precision@10: 0.032003311
# recall@10: 0.032008830
# ndcg@10: 0.033632273
# map@10: 0.012047166
# Epoch 95, Step 30, LR: 0.000300, Current Loss: 0.2376, Avg Loss: 0.2339
# Diff stats — min: -6.4280, max: 12.8677, mean: 3.3568, std: 2.5981
#
# Step/epoch 30/95, Test metrics:
# precision@10: 0.032334437
# recall@10: 0.032339956
# ndcg@10: 0.033919321
# map@10: 0.012145938
# Epoch 95, Step 40, LR: 0.000300, Current Loss: 0.2319, Avg Loss: 0.2332
# Diff stats — min: -6.8494, max: 12.3634, mean: 3.3725, std: 2.5940
#
# Step/epoch 40/95, Test metrics:
# precision@10: 0.032450331
# recall@10: 0.032455850
# ndcg@10: 0.033948971
# map@10: 0.012153481
# Epoch 95, Step 50, LR: 0.000300, Current Loss: 0.2366, Avg Loss: 0.2335
# Diff stats — min: -6.3659, max: 12.6001, mean: 3.3732, std: 2.6127
#
# Step/epoch 50/95, Test metrics:
# precision@10: 0.032665563
# recall@10: 0.032671082
# ndcg@10: 0.034062860
# map@10: 0.012167403
# Epoch 95 completed, Train Loss: 0.2338
# Epoch 96, Step 1, LR: 0.000300, Current Loss: 0.2266, Avg Loss: 0.2266
# Diff stats — min: -5.7367, max: 15.0854, mean: 3.3316, std: 2.5595
#
# Step/epoch 1/96, Test metrics:
# precision@10: 0.032715232
# recall@10: 0.032720751
# ndcg@10: 0.034085773
# map@10: 0.012193176
# Epoch 96, Step 10, LR: 0.000300, Current Loss: 0.2320, Avg Loss: 0.2341
# Diff stats — min: -6.0701, max: 13.6422, mean: 3.4162, std: 2.5815
#
# Step/epoch 10/96, Test metrics:
# precision@10: 0.032649007
# recall@10: 0.032654525
# ndcg@10: 0.034018667
# map@10: 0.012160478
# Epoch 96, Step 20, LR: 0.000300, Current Loss: 0.2215, Avg Loss: 0.2327
# Diff stats — min: -4.9867, max: 13.6804, mean: 3.3789, std: 2.5496
#
# Step/epoch 20/96, Test metrics:
# precision@10: 0.032549669
# recall@10: 0.032555188
# ndcg@10: 0.033991895
# map@10: 0.012163040
# Epoch 96, Step 30, LR: 0.000300, Current Loss: 0.2241, Avg Loss: 0.2330
# Diff stats — min: -5.5787, max: 12.5907, mean: 3.3519, std: 2.5301
#
# Step/epoch 30/96, Test metrics:
# precision@10: 0.032367550
# recall@10: 0.032373068
# ndcg@10: 0.033873369
# map@10: 0.012149223
# Epoch 96, Step 40, LR: 0.000300, Current Loss: 0.2334, Avg Loss: 0.2326
# Diff stats — min: -5.5414, max: 15.9270, mean: 3.3752, std: 2.6091
#
# Step/epoch 40/96, Test metrics:
# precision@10: 0.032433775
# recall@10: 0.032439294
# ndcg@10: 0.033799622
# map@10: 0.012104981
# Epoch 96, Step 50, LR: 0.000300, Current Loss: 0.2360, Avg Loss: 0.2323
# Diff stats — min: -5.9928, max: 12.8795, mean: 3.3616, std: 2.5779
#
# Step/epoch 50/96, Test metrics:
# precision@10: 0.032268212
# recall@10: 0.032273731
# ndcg@10: 0.033700128
# map@10: 0.012070824
# Epoch 96 completed, Train Loss: 0.2321
# Epoch 97, Step 1, LR: 0.000300, Current Loss: 0.2191, Avg Loss: 0.2191
# Diff stats — min: -6.0449, max: 12.9075, mean: 3.3888, std: 2.5325
#
# Step/epoch 1/97, Test metrics:
# precision@10: 0.032301325
# recall@10: 0.032306843
# ndcg@10: 0.033701669
# map@10: 0.012050845
# Epoch 97, Step 10, LR: 0.000300, Current Loss: 0.2412, Avg Loss: 0.2299
# Diff stats — min: -5.1979, max: 13.9466, mean: 3.3285, std: 2.5965
#
# Step/epoch 10/97, Test metrics:
# precision@10: 0.032566225
# recall@10: 0.032571744
# ndcg@10: 0.033920988
# map@10: 0.012109718
# Epoch 97, Step 20, LR: 0.000300, Current Loss: 0.2428, Avg Loss: 0.2299
# Diff stats — min: -6.5073, max: 12.9235, mean: 3.3391, std: 2.6227
#
# Step/epoch 20/97, Test metrics:
# precision@10: 0.032483444
# recall@10: 0.032488962
# ndcg@10: 0.033977320
# map@10: 0.012173532
# Epoch 97, Step 30, LR: 0.000300, Current Loss: 0.2296, Avg Loss: 0.2297
# Diff stats — min: -6.2624, max: 13.4316, mean: 3.3847, std: 2.5707
#
# Step/epoch 30/97, Test metrics:
# precision@10: 0.032665563
# recall@10: 0.032671082
# ndcg@10: 0.034095012
# map@10: 0.012195818
# Epoch 97, Step 40, LR: 0.000300, Current Loss: 0.2304, Avg Loss: 0.2297
# Diff stats — min: -6.3239, max: 12.8461, mean: 3.4316, std: 2.6154
#
# Step/epoch 40/97, Test metrics:
# precision@10: 0.032533113
# recall@10: 0.032538631
# ndcg@10: 0.033863139
# map@10: 0.012073196
# Epoch 97, Step 50, LR: 0.000300, Current Loss: 0.2288, Avg Loss: 0.2303
# Diff stats — min: -7.1275, max: 13.5704, mean: 3.3898, std: 2.5921
#
# Step/epoch 50/97, Test metrics:
# precision@10: 0.032384106
# recall@10: 0.032389625
# ndcg@10: 0.033671464
# map@10: 0.011991735
# Epoch 97 completed, Train Loss: 0.2302
# Epoch 98, Step 1, LR: 0.000300, Current Loss: 0.2169, Avg Loss: 0.2169
# Diff stats — min: -5.4255, max: 13.5756, mean: 3.4093, std: 2.5428
#
# Step/epoch 1/98, Test metrics:
# precision@10: 0.032367550
# recall@10: 0.032373068
# ndcg@10: 0.033684490
# map@10: 0.012013107
# Epoch 98, Step 10, LR: 0.000300, Current Loss: 0.2355, Avg Loss: 0.2310
# Diff stats — min: -5.6601, max: 13.6157, mean: 3.3646, std: 2.5915
#
# Step/epoch 10/98, Test metrics:
# precision@10: 0.032218543
# recall@10: 0.032224062
# ndcg@10: 0.033633945
# map@10: 0.012009480
# Epoch 98, Step 20, LR: 0.000300, Current Loss: 0.2076, Avg Loss: 0.2295
# Diff stats — min: -4.7481, max: 12.0769, mean: 3.4804, std: 2.5591
#
# Step/epoch 20/98, Test metrics:
# precision@10: 0.032533113
# recall@10: 0.032538631
# ndcg@10: 0.033882128
# map@10: 0.012053723
# Epoch 98, Step 30, LR: 0.000300, Current Loss: 0.2325, Avg Loss: 0.2315
# Diff stats — min: -5.7064, max: 11.6111, mean: 3.3615, std: 2.5903
#
# Step/epoch 30/98, Test metrics:
# precision@10: 0.032334437
# recall@10: 0.032339956
# ndcg@10: 0.033799822
# map@10: 0.012044525
# Epoch 98, Step 40, LR: 0.000300, Current Loss: 0.2246, Avg Loss: 0.2314
# Diff stats — min: -4.7665, max: 13.6219, mean: 3.3731, std: 2.5543
#
# Step/epoch 40/98, Test metrics:
# precision@10: 0.032334437
# recall@10: 0.032339956
# ndcg@10: 0.033893618
# map@10: 0.012140196
# Epoch 98, Step 50, LR: 0.000300, Current Loss: 0.2282, Avg Loss: 0.2306
# Diff stats — min: -5.7149, max: 13.7369, mean: 3.4647, std: 2.6276
#
# Step/epoch 50/98, Test metrics:
# precision@10: 0.032317881
# recall@10: 0.032323400
# ndcg@10: 0.034006730
# map@10: 0.012228878
# Epoch 98 completed, Train Loss: 0.2308
# Epoch 99, Step 1, LR: 0.000300, Current Loss: 0.2305, Avg Loss: 0.2305
# Diff stats — min: -5.5026, max: 13.6271, mean: 3.4131, std: 2.6155
#
# Step/epoch 1/99, Test metrics:
# precision@10: 0.032483444
# recall@10: 0.032488962
# ndcg@10: 0.034127221
# map@10: 0.012271182
# Epoch 99, Step 10, LR: 0.000300, Current Loss: 0.2257, Avg Loss: 0.2329
# Diff stats — min: -5.6836, max: 12.7865, mean: 3.3870, std: 2.5671
#
# Step/epoch 10/99, Test metrics:
# precision@10: 0.032235099
# recall@10: 0.032240618
# ndcg@10: 0.033953342
# map@10: 0.012194444
# Epoch 99, Step 20, LR: 0.000300, Current Loss: 0.2162, Avg Loss: 0.2324
# Diff stats — min: -5.4139, max: 13.7276, mean: 3.4409, std: 2.5517
#
# Step/epoch 20/99, Test metrics:
# precision@10: 0.032268212
# recall@10: 0.032273731
# ndcg@10: 0.033907633
# map@10: 0.012161890
# Epoch 99, Step 30, LR: 0.000300, Current Loss: 0.2324, Avg Loss: 0.2304
# Diff stats — min: -5.0848, max: 12.6529, mean: 3.4144, std: 2.6035
#
# Step/epoch 30/99, Test metrics:
# precision@10: 0.032400662
# recall@10: 0.032406181
# ndcg@10: 0.033944652
# map@10: 0.012170924
# Epoch 99, Step 40, LR: 0.000300, Current Loss: 0.2157, Avg Loss: 0.2299
# Diff stats — min: -5.5658, max: 12.6020, mean: 3.4444, std: 2.5687
#
# Step/epoch 40/99, Test metrics:
# precision@10: 0.032400662
# recall@10: 0.032406181
# ndcg@10: 0.033964026
# map@10: 0.012188032
# Epoch 99, Step 50, LR: 0.000300, Current Loss: 0.2384, Avg Loss: 0.2309
# Diff stats — min: -5.5179, max: 12.4610, mean: 3.4284, std: 2.6508
#
# Step/epoch 50/99, Test metrics:
# precision@10: 0.032152318
# recall@10: 0.032157837
# ndcg@10: 0.033865698
# map@10: 0.012154289
# Epoch 99 completed, Train Loss: 0.2311
# Epoch 100, Step 1, LR: 0.000300, Current Loss: 0.2364, Avg Loss: 0.2364
# Diff stats — min: -6.9482, max: 12.6930, mean: 3.3844, std: 2.6123
#
# Step/epoch 1/100, Test metrics:
# precision@10: 0.031953642
# recall@10: 0.031959161
# ndcg@10: 0.033811429
# map@10: 0.012175681
# Epoch 100, Step 10, LR: 0.000300, Current Loss: 0.2235, Avg Loss: 0.2300
# Diff stats — min: -5.7021, max: 13.5165, mean: 3.4549, std: 2.5970
#
# Step/epoch 10/100, Test metrics:
# precision@10: 0.031953642
# recall@10: 0.031959161
# ndcg@10: 0.033703024
# map@10: 0.012098076
# Epoch 100, Step 20, LR: 0.000300, Current Loss: 0.2197, Avg Loss: 0.2285
# Diff stats — min: -5.0788, max: 12.1590, mean: 3.4514, std: 2.5862
#
# Step/epoch 20/100, Test metrics:
# precision@10: 0.032135762
# recall@10: 0.032141280
# ndcg@10: 0.033757290
# map@10: 0.012112648
# Epoch 100, Step 30, LR: 0.000300, Current Loss: 0.2341, Avg Loss: 0.2303
# Diff stats — min: -5.4268, max: 13.3324, mean: 3.3965, std: 2.6194
#
# Step/epoch 30/100, Test metrics:
# precision@10: 0.032135762
# recall@10: 0.032141280
# ndcg@10: 0.033686525
# map@10: 0.012054104
# Epoch 100, Step 40, LR: 0.000300, Current Loss: 0.2280, Avg Loss: 0.2314
# Diff stats — min: -5.5533, max: 14.2474, mean: 3.4032, std: 2.6226
#
# Step/epoch 40/100, Test metrics:
# precision@10: 0.032268212
# recall@10: 0.032273731
# ndcg@10: 0.033794357
# map@10: 0.012111183
# Epoch 100, Step 50, LR: 0.000300, Current Loss: 0.2427, Avg Loss: 0.2313
# Diff stats — min: -5.8799, max: 12.9776, mean: 3.3909, std: 2.6562
#
# Step/epoch 50/100, Test metrics:
# precision@10: 0.032582781
# recall@10: 0.032588300
# ndcg@10: 0.034075332
# map@10: 0.012181357
# Epoch 100 completed, Train Loss: 0.2313

# %%
torch.save(model, "gnn_model_mvl.model")
from IPython.display import FileLink

FileLink('gnn_model_mvl.model')
# Out:
# /kaggle/working/gnn_model_mvl.model

# %%
# del model
gc.collect()
torch.cuda.empty_cache()

# %%
log_model(
    experiment=experiment,
    model=model,
    model_name="GNN",
)

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : BaseGATGraphModel
# COMET INFO:     url                   : https://www.comet.com/annanet/gnn-recommender/1e74ff5a183140f2be3be0cc15587fff
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Diff stats (mean) vs step [600] : (0.04525217413902283, 3.480424642562866)
# COMET INFO:     Diff stats (std) vs step [600]  : (2.2659318447113037, 7.881175518035889)
# COMET INFO:     Test map@10 vs step [600]       : (0.000778349364028172, 0.012498083762570517)
# COMET INFO:     Test ndcg@10 vs step [600]      : (0.0028448401385444367, 0.034820011766281876)
# COMET INFO:     Test precision@10 vs step [600] : (0.002798013245033113, 0.03327814569536424)
# COMET INFO:     Test recall@10 vs step [600]    : (0.0027998528329654156, 0.033283664459161144)
# COMET INFO:     Train BPR Loss vs step [5200]   : (0.20757821202278137, 3.3016886711120605)
# COMET INFO:     Train Loss vs epoch [100]       : (0.23024829701621277, 3.050410253355642)
# COMET INFO:     loss [520]                      : (0.21309107542037964, 3.1943769454956055)
# COMET INFO:   Others:
# COMET INFO:     Name : BaseGATGraphModel
# COMET INFO:   Parameters:
# COMET INFO:     seed              : 42
# COMET INFO:     test_batch_size   : 2048
# COMET INFO:     test_topk         : 10
# COMET INFO:     train_batch_size  : 4096
# COMET INFO:     train_edge_type   : ('item', 'to_feedback_explicit_positive', 'explicit_positive')
# COMET INFO:     train_lr          : 0.0003
# COMET INFO:     train_num_epochs  : 100
# COMET INFO:     train_print_every : 10
# COMET INFO:     train_test_every  : 10
# COMET INFO:     types_of_feedback : ['explicit_positive', 'expliсit_negative', 'implicit_positive', 'implicit_negative']
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     model-element       : 2 (4.29 MB)
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
