# %%
# !pip -q install torch_geometric rectools
# !pip -q install comet_ml
# !pip -q install python-dotenv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.9 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 102.5 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.1/727.1 kB 18.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 79.4 MB/s eta 0:00:00:00:01

# %%
import comet_ml
from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

from dotenv import load_dotenv
import os

# %%
load_dotenv(".env")
# Out:
# True

# %%
experiment = Experiment(
  api_key=os.getenv('API_KEY'),
  project_name="gnn-recommender",
  workspace="annanet",
  log_code=True
)

experiment.set_name('diffGATGraphModel-movielens')
experiment.add_tags(['movielens', 'leave-n-out'])
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/annanet/gnn-recommender/527798220a1140c5b8dfc2d8f2ce1335
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %%
hyperparameters = {
    'seed': 42,
    'types_of_feedback': ["explicit_positive", "expliсit_negative",
                          "implicit_positive", "implicit_negative"],
    'train_edge_type': ('item','to_feedback_explicit_positive','explicit_positive'),
    'train_num_epochs': 100,
    'train_lr': 8e-5,
    'train_batch_size': 4096,
    'train_print_every': 10,  
    'train_test_every': 10,
    'test_topk': 10,
    'test_batch_size': 2048
}

# %%
import os
os.listdir('/kaggle/input/data/leave-n-out/mvln')
# Out:
# ['train.csv', 'test.csv']

# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import HeteroData
from torch_geometric.nn import HeteroConv, SAGEConv, GATConv

from sklearn.preprocessing import LabelEncoder

from rectools import Columns
from rectools.metrics import MAP, Precision, Recall, NDCG, calc_metrics

import gc
import random

# %%
SEED = hyperparameters['seed']
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
rootpath = '/kaggle/input/data/leave-n-out/mvln/'
train = pd.read_csv(
    rootpath+'train.csv'
)
train['date'] = pd.to_datetime(train['timestamp'], unit='s')
print(train.head())
# Out:
#    user_id  movie_id  rating  timestamp                date
# 0        1      3186       4  978300019 2000-12-31 22:00:19
# 1        1      1270       5  978300055 2000-12-31 22:00:55
# 2        1      1721       4  978300055 2000-12-31 22:00:55
# 3        1      1022       5  978300055 2000-12-31 22:00:55
# 4        1      2340       3  978300103 2000-12-31 22:01:43

# %%
explicit_positive = train[(train["rating"] == 5)].index
explisit_negative = train[(train["rating"] <= 2)].index

explicit_combined_feedback = explicit_positive.union(explisit_negative)
print('Количество explicit позитивного фидбека', explicit_positive.shape[0])
print('Количество explicit негативного фидбека', explisit_negative.shape[0])
# Out:
# Количество explicit позитивного фидбека 211802
# Количество explicit негативного фидбека 153484

# %%
implicit_positive = train[(train["rating"] == 4)].index
implicit_negative = train[(train["rating"] == 3)].index

implicit_combined_feedback = implicit_positive.union(implicit_negative)
print('Количество implicit позитивного фидбека', implicit_positive.shape[0])
print('Количество implicit негативного фидбека', implicit_negative.shape[0])
# Out:
# Количество implicit позитивного фидбека 327987
# Количество implicit негативного фидбека 246536

# %%
train.loc[:, "target"] = ""
train.loc[explicit_positive, "target"] = "explicit_positive"
train.loc[explisit_negative, "target"] = "expliсit_negative"
train.loc[implicit_positive, "target"] = "implicit_positive"
train.loc[implicit_negative, "target"] = "implicit_negative"

train = train[['user_id','movie_id','target','date']]
train.head()
# Out:
#    user_id  movie_id             target                date
# 0        1      3186  implicit_positive 2000-12-31 22:00:19
# 1        1      1270  explicit_positive 2000-12-31 22:00:55
# 2        1      1721  implicit_positive 2000-12-31 22:00:55
# 3        1      1022  explicit_positive 2000-12-31 22:00:55
# 4        1      2340  implicit_negative 2000-12-31 22:01:43

# %%
train = train.sort_values(by=["user_id", "date"]).reset_index(drop=True)
train.columns = ['user_id', 'item_id', 'target', 'date']

# %%
test = pd.read_csv(
    rootpath+'test.csv'
)
test['date'] = pd.to_datetime(test['timestamp'], unit='s')
print(test.head())
# Out:
#    user_id  movie_id  rating  timestamp                date
# 0        1      2687       3  978824268 2001-01-06 23:37:48
# 1        1       745       3  978824268 2001-01-06 23:37:48
# 2        1       588       4  978824268 2001-01-06 23:37:48
# 3        1         1       5  978824268 2001-01-06 23:37:48
# 4        1      2355       5  978824291 2001-01-06 23:38:11

# %%
test = test[['user_id','movie_id', 'date']]
test.columns = ['user_id', 'item_id', 'date']
test.head()
# Out:
#    user_id  item_id                date
# 0        1     2687 2001-01-06 23:37:48
# 1        1      745 2001-01-06 23:37:48
# 2        1      588 2001-01-06 23:37:48
# 3        1        1 2001-01-06 23:37:48
# 4        1     2355 2001-01-06 23:38:11

# %% [markdown]
# # MVP model v2

# %%
test = test[(test.user_id.isin(train.user_id)) & (test.item_id.isin(train.item_id))].copy()
test.shape
# Out:
# (60394, 3)

# %%
# 2. Преобразование данных - для куарека не особо нужно, но для других - напоминалка
# делаем всегда! чтобы не сломать ничего дальше и чтобы все индексы были от 0 до N без пропусков
user_encoder = LabelEncoder()
video_encoder = LabelEncoder()

train.loc[:, 'user_id'] = user_encoder.fit_transform(train['user_id'])
train.loc[:, 'item_id'] = video_encoder.fit_transform(train['item_id'])

test.loc[:, 'user_id'] = user_encoder.transform(test['user_id'])
test.loc[:, 'item_id'] = video_encoder.transform(test['item_id'])

train['user_id'] = train['user_id'].astype(int)
train['item_id'] = train['item_id'].astype(int)
test['user_id'] = test['user_id'].astype(int)
test['item_id'] = test['item_id'].astype(int)

# %%
# т.е. сразу знаем количество и в каких пределах изменяется user_id и video_id
num_videos = train['item_id'].nunique()
num_users = train['user_id'].nunique()

print('Количество уникальных item_id', num_videos)
print('Количество уникальных user_id', num_users)
# Out:
# Количество уникальных item_id 3700
# Количество уникальных user_id 6040

# %%
def prepare_hetero_data(df) -> HeteroData:
    data = HeteroData()
    users = df['user_id'].unique()
    num_users = len(users)
    num_items = df['item_id'].max() + 1
    feedback_types = df['target'].unique().tolist()

    # узлы
    data['user'].node_id = torch.arange(num_users)
    data['item'].node_id = torch.arange(num_items)
    for ft in feedback_types:
        data[ft].node_id = torch.arange(num_users)

    # ребра item<->feedback->user
    for ft in feedback_types:
        mask = df['target'] == ft
        items = torch.LongTensor(df.loc[mask, 'item_id'].values)
        users_idx = torch.LongTensor(df.loc[mask, 'user_id'].values)
        # item -> fb
        data['item', f'to_feedback_{ft}', ft].edge_index = torch.stack([items, users_idx], dim=0)
        # fb -> item
        data[ft, f'feedback_to_item_{ft}', 'item'].edge_index = torch.stack([users_idx, items], dim=0)
        # fb -> user (1:1)
        idx = torch.arange(num_users)
        data[ft, f'to_user_{ft}', 'user'].edge_index = torch.stack([idx, idx], dim=0)

    return data

# %%
class SignedHeteroGNN(nn.Module):
    def __init__(self,
                 num_users: int,
                 num_items: int,
                 feedback_types: list,
                 emb_dim: int = 32,
                 hidden_dim: int = 16,
                 heads: int = 2,
                 dropout: float = 0.2):
        super().__init__()
        self.feedback_types = feedback_types
        self.pos_types = ['implicit_positive', 'explicit_positive']
        self.neg_types = ['implicit_negative', 'expliсit_negative']

        self.user_emb = nn.Embedding(num_users, emb_dim)
        self.item_emb = nn.Embedding(num_items, emb_dim)
        self.fb_emb   = nn.ModuleDict({
            ft: nn.Embedding(num_users, emb_dim) for ft in feedback_types
        })

        conv1, conv2 = {}, {}
        for ft in feedback_types:
            # ft -> user
            conv1[(ft, f'to_user_{ft}', 'user')] = GATConv(emb_dim, hidden_dim,
                                                      heads=heads,
                                                      add_self_loops=False)
            conv2[(ft, f'to_user_{ft}', 'user')] = GATConv(hidden_dim*heads, emb_dim,
                                                      heads=1,
                                                      add_self_loops=False)
            # ft -> item
            conv1[(ft, f'feedback_to_item_{ft}', 'item')] = GATConv(emb_dim, hidden_dim,
                                                       heads=heads,
                                                       add_self_loops=False)
            conv2[(ft, f'feedback_to_item_{ft}', 'item')] = GATConv(hidden_dim*heads, emb_dim,
                                                       heads=1,
                                                       add_self_loops=False)

            # item -> ft
            conv1[('item', f'to_feedback_{ft}', ft)] = GATConv(emb_dim, hidden_dim,
                                                       heads=heads,
                                                       add_self_loops=False)
            conv2[('item', f'to_feedback_{ft}', ft)] = GATConv(hidden_dim*heads, emb_dim,
                                                       heads=1,
                                                       add_self_loops=False)

        self.conv1 = HeteroConv(conv1, aggr='mean')
        self.conv2 = HeteroConv(conv2, aggr='mean')

        # LayerNorm и Dropout
        types = ['user', 'item'] + feedback_types
        self.norm1 = nn.ModuleDict({t: nn.LayerNorm(hidden_dim*heads) for t in types})
        self.norm2 = nn.ModuleDict({t: nn.LayerNorm(emb_dim) for t in types})
        self.dropout = nn.Dropout(dropout)

    def forward(self, data):
        x = {
            'user': self.user_emb(data['user'].node_id),
            'item': self.item_emb(data['item'].node_id)
        }
        for ft in self.feedback_types:
            x[ft] = self.fb_emb[ft](data[ft].node_id)

        h1 = self.conv1(x, data.edge_index_dict)
        # print(h1.keys())
        # Собираем позитивный и негативный вклад для user
        pos_msgs = torch.zeros_like(h1['user'])
        neg_msgs = torch.zeros_like(h1['user'])
        for ft in self.pos_types:
            pos_msgs += h1[ft]  
        for ft in self.neg_types:
            neg_msgs += h1[ft]

        # signed-aggregation: attraction от pos, repulsion от neg
        user_h1 = pos_msgs - neg_msgs
        user_h1 = F.leaky_relu(self.norm1['user'](user_h1))
        user_h1 = self.dropout(user_h1)

        h1['user'] = user_h1

        h2 = self.conv2(h1, data.edge_index_dict)
        # print(h2.keys())
        pos_msgs2, neg_msgs2 = 0, 0
        for ft in self.pos_types:
            pos_msgs2 += h2[ft]
        for ft in self.neg_types:
            neg_msgs2 += h2[ft]

        user_h2 = pos_msgs2 - neg_msgs2
        user_h2 = F.leaky_relu(self.norm2['user'](user_h2))

        return user_h2

# %%
data = prepare_hetero_data(train)
data
# Out:
# HeteroData(
#   user={ node_id=[6040] },
#   item={ node_id=[3700] },
#   implicit_positive={ node_id=[6040] },
#   explicit_positive={ node_id=[6040] },
#   implicit_negative={ node_id=[6040] },
#   expliсit_negative={ node_id=[6040] },
#   (item, to_feedback_implicit_positive, implicit_positive)={ edge_index=[2, 327987] },
#   (implicit_positive, feedback_to_item_implicit_positive, item)={ edge_index=[2, 327987] },
#   (implicit_positive, to_user_implicit_positive, user)={ edge_index=[2, 6040] },
#   (item, to_feedback_explicit_positive, explicit_positive)={ edge_index=[2, 211802] },
#   (explicit_positive, feedback_to_item_explicit_positive, item)={ edge_index=[2, 211802] },
#   (explicit_positive, to_user_explicit_positive, user)={ edge_index=[2, 6040] },
#   (item, to_feedback_implicit_negative, implicit_negative)={ edge_index=[2, 246536] },
#   (implicit_negative, feedback_to_item_implicit_negative, item)={ edge_index=[2, 246536] },
#   (implicit_negative, to_user_implicit_negative, user)={ edge_index=[2, 6040] },
#   (item, to_feedback_expliсit_negative, expliсit_negative)={ edge_index=[2, 153484] },
#   (expliсit_negative, feedback_to_item_expliсit_negative, item)={ edge_index=[2, 153484] },
#   (expliсit_negative, to_user_expliсit_negative, user)={ edge_index=[2, 6040] }
# )

# %%
train.item_id.nunique(), train.item_id.min(), train.item_id.max()
# Out:
# (3700, 0, 3699)

# %%
num_users = len(train['user_id'].unique())
num_items = train['item_id'].max() + 1
feedback_types = train['target'].unique().tolist()
model = SignedHeteroGNN(num_users, num_items, feedback_types)

# %%
model
# Out:
# SignedHeteroGNN(
#   (user_emb): Embedding(6040, 32)
#   (item_emb): Embedding(3700, 32)
#   (fb_emb): ModuleDict(
#     (implicit_positive): Embedding(6040, 32)
#     (explicit_positive): Embedding(6040, 32)
#     (implicit_negative): Embedding(6040, 32)
#     (expliсit_negative): Embedding(6040, 32)
#   )
#   (conv1): HeteroConv(num_relations=12)
#   (conv2): HeteroConv(num_relations=12)
#   (norm1): ModuleDict(
#     (user): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (item): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (explicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (expliсit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (norm2): ModuleDict(
#     (user): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (item): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (explicit_positive): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (implicit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (expliсit_negative): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model(data)
# Out:
# tensor([[ 1.8883e+00,  2.1260e+00, -5.6116e-03,  ...,  2.5069e-01,
#           1.7280e-01, -7.0265e-03],
#         [ 2.0908e+00,  1.8636e+00, -1.0640e-03,  ..., -3.5415e-03,
#           8.6922e-01, -6.3107e-03],
#         [ 1.8606e+00,  2.2887e+00, -1.9882e-03,  ..., -4.7144e-03,
#           1.1525e+00, -7.1537e-03],
#         ...,
#         [ 1.0849e+00,  1.0376e+00,  4.5011e-01,  ..., -2.7861e-03,
#           6.9082e-02, -2.2795e-03],
#         [ 1.7740e+00,  2.1240e+00,  1.6758e-01,  ..., -4.9274e-03,
#           5.5816e-01, -1.0044e-02],
#         [ 1.8437e+00,  2.1750e+00, -1.9571e-03,  ...,  2.5669e-02,
#           1.0347e+00, -7.2765e-03]], grad_fn=<LeakyReluBackward0>)

# %%
test_df = test[['user_id', 'item_id']]
interactions = test_df.rename(columns={
    'user_id': Columns.User,
    'item_id': Columns.Item,
})

viewed_items = train.groupby("user_id")["item_id"].agg(set).to_dict()

# %%
def evaluate(model, train_data,
             test_batch_size, top_k,
             viewed_items, interactions,
             device, test_step):
    """
    Оцениваем модель по всем пользователям:
    - строим топ-K рекомендации
    - фильтруем уже просмотренные
    - считаем recall@K, precision@K, map@K
    """
    model.eval()
    model.to(device)
    num_users = train_data['user'].node_id.shape[0]
    test_top_k = top_k * 150

    item_emb = model.item_emb.weight
    item_emb_t = item_emb.t().detach()
    del item_emb
    gc.collect()

    all_scores = []
    with torch.no_grad():
        for i in range(0, num_users, test_batch_size):
            end = min(i + test_batch_size, num_users)
            batch_users = torch.arange(i, end).to(device)
            user_e = model(
                data=train_data.to(device)
            )
            rating = torch.mm(user_e[batch_users].detach(), item_emb_t)
            _, topk = torch.topk(rating, k=test_top_k, dim=1)
            all_scores.append(topk)

            del user_e, rating
            gc.collect()
    all_scores = torch.cat(all_scores, dim=0).cpu().numpy()

    users_list, items, ranks = [], [], []
    for u in range(num_users):
        seen = viewed_items.get(u, set())
        recs = all_scores[u]
        mask = ~np.isin(recs, list(seen))
        filtered = recs[mask][:top_k]
        for rank, it in enumerate(filtered, 1):
            users_list.append(u)
            items.append(int(it))
            ranks.append(rank)
    reco_df = pd.DataFrame({
        'user_id': users_list,
        'item_id': items,
        'rank': ranks
    })

    metrics = {
        f'map@{top_k}': MAP(k=top_k),
        f'precision@{top_k}': Precision(k=top_k),
        f'recall@{top_k}': Recall(k=top_k),
        f'ndcg@{top_k}': NDCG(k=top_k)
    }
    results = calc_metrics(metrics=metrics,
                           reco=reco_df,
                           interactions=interactions)
    print(f"Step {test_step} — Test metrics:")
    for name, val in results.items():
        print(f"  {name}: {val:.9f}")
        experiment.log_metric(f"Test {name} vs step", val, step=test_step)
    del all_scores
    gc.collect()

    model.to(device)
    train_data.to(device)
    model.train()
    return results

# %%
def train_model(model,
                train_data: HeteroData,
                edge_type: tuple,
                num_epochs: int = 10,
                lr: float = 1e-3,
                batch_size: int = 1024,
                device: str = None,
                print_every: int = 100,
                test_every: int = 500,
                top_k: int = 10,
                test_batch_size=2048):
    device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    train_data = train_data.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    src, dst = train_data[edge_type].edge_index
    num_train = src.size(0)
    test_top_k = top_k * 300
    total_steps = 0
    print(f"Num of training examples: {num_train}")
    for epoch in range(1, num_epochs + 1):
        model.train()
        perm = torch.randperm(num_train, device=device)
        total_loss = 0.0
        step = 0
        for i in range(0, num_train, batch_size):
            idx = perm[i:i + batch_size]
            users = dst[idx]
            pos_items = src[idx]
            neg_items = torch.randint(0, model.item_emb.num_embeddings,
                                      size=pos_items.size(), device=device)
            optimizer.zero_grad()
            user_embs = model(train_data)[users]
            pos_emb = model.item_emb(pos_items)
            neg_emb = model.item_emb(neg_items)
            pos_score = (user_embs * pos_emb).sum(dim=1)
            neg_score = (user_embs * neg_emb).sum(dim=1)
            loss = -torch.log(torch.sigmoid(pos_score - neg_score) + 1e-15).mean()
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * users.size(0)
            step += 1

            experiment.log_metric('Train BPR Loss vs step', loss.item(), step=total_steps)
            if step % print_every == 0 or step == 1:
                avg_loss = total_loss /  (step * batch_size)
                current_lr = optimizer.param_groups[0]['lr']
                d = (pos_score - neg_score).detach().cpu()
                print(f"Epoch {epoch}, Step {step}, LR: {current_lr:.6f}, Current Loss: {loss.item():.4f}, Avg Loss: {avg_loss:.4f}")
                print(f"Diff stats — min: {d.min():.4f}, max: {d.max():.4f}, mean: {d.mean():.4f}, std: {d.std():.4f}")
                print()

                experiment.log_metric('Diff stats (mean) vs step', d.mean(), step=total_steps)
                experiment.log_metric('Diff stats (std) vs step', d.std(), step=total_steps)

            del user_embs, pos_emb, neg_emb, pos_score, neg_score
            gc.collect()
            torch.cuda.empty_cache()
            
            if step % test_every == 0 or step == 1:
                evaluate(model, train_data,
                         test_batch_size, top_k,
                         viewed_items, interactions,
                         device, test_step=total_steps)
            total_steps += 1
        epoch_loss = total_loss / num_train
        experiment.log_metric(f'Train Loss vs epoch', epoch_loss, epoch=epoch - 1)
        print(f"Epoch {epoch} completed, Train Loss: {epoch_loss:.4f}")
    return model

# %%
experiment.log_parameters(hyperparameters)

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
edge_type = hyperparameters['train_edge_type']
num_epochs = hyperparameters['train_num_epochs']
lr = hyperparameters['train_lr']
batch_size = hyperparameters['train_batch_size']
print_every = hyperparameters['train_print_every']
test_every = hyperparameters['train_test_every']
top_k = hyperparameters['test_topk']
test_batch_size = hyperparameters['test_batch_size']
model = train_model(model,
                    data,
                    edge_type=edge_type,
                    num_epochs=num_epochs,
                    lr=lr,
                    batch_size=batch_size,
                    print_every=print_every,
                    test_every=test_every,
                    top_k=top_k,
                    test_batch_size=test_batch_size)
# Out:
# Num of training examples: 211802
# Epoch 1, Step 1, LR: 0.000080, Current Loss: 2.6263, Avg Loss: 2.6263
# Diff stats — min: -23.1286, max: 19.9993, mean: -0.2984, std: 5.9134
#
# Step 0 — Test metrics:
#   precision@10: 0.004668874
#   recall@10: 0.004668874
#   ndcg@10: 0.005354564
#   map@10: 0.001778638
# Epoch 1, Step 10, LR: 0.000080, Current Loss: 2.4733, Avg Loss: 2.5438
# Diff stats — min: -20.2335, max: 20.1637, mean: -0.1932, std: 5.6803
#
# Step 9 — Test metrics:
#   precision@10: 0.004983444
#   recall@10: 0.004983444
#   ndcg@10: 0.005696341
#   map@10: 0.001884553
# Epoch 1, Step 20, LR: 0.000080, Current Loss: 2.3095, Avg Loss: 2.4559
# Diff stats — min: -22.8362, max: 20.9054, mean: -0.1682, std: 5.3234
#
# Step 19 — Test metrics:
#   precision@10: 0.005182119
#   recall@10: 0.005182119
#   ndcg@10: 0.005974567
#   map@10: 0.001987057
# Epoch 1, Step 30, LR: 0.000080, Current Loss: 2.1287, Avg Loss: 2.3776
# Diff stats — min: -17.9582, max: 18.0628, mean: -0.0276, std: 4.9972
#
# Step 29 — Test metrics:
#   precision@10: 0.005314570
#   recall@10: 0.005314570
#   ndcg@10: 0.006091720
#   map@10: 0.002015420
# Epoch 1, Step 40, LR: 0.000080, Current Loss: 2.0051, Avg Loss: 2.2943
# Diff stats — min: -16.8289, max: 17.3747, mean: -0.1228, std: 4.5478
#
# Step 39 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005778146
#   ndcg@10: 0.006679293
#   map@10: 0.002250289
# Epoch 1, Step 50, LR: 0.000080, Current Loss: 1.9060, Avg Loss: 2.2191
# Diff stats — min: -16.7920, max: 15.5254, mean: -0.0768, std: 4.3379
#
# Step 49 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005779985
#   ndcg@10: 0.006770838
#   map@10: 0.002304432
# Epoch 1 completed, Train Loss: 2.2076
# Epoch 2, Step 1, LR: 0.000080, Current Loss: 1.8757, Avg Loss: 1.8757
# Diff stats — min: -14.8612, max: 16.3996, mean: -0.0597, std: 4.2731
#
# Step 52 — Test metrics:
#   precision@10: 0.005711921
#   recall@10: 0.005713760
#   ndcg@10: 0.006707631
#   map@10: 0.002290175
# Epoch 2, Step 10, LR: 0.000080, Current Loss: 1.7206, Avg Loss: 1.7979
# Diff stats — min: -13.6490, max: 14.3482, mean: 0.1289, std: 4.0908
#
# Step 61 — Test metrics:
#   precision@10: 0.005529801
#   recall@10: 0.005531641
#   ndcg@10: 0.006654290
#   map@10: 0.002320005
# Epoch 2, Step 20, LR: 0.000080, Current Loss: 1.6773, Avg Loss: 1.7591
# Diff stats — min: -12.6547, max: 12.4394, mean: 0.0738, std: 3.8981
#
# Step 71 — Test metrics:
#   precision@10: 0.005347682
#   recall@10: 0.005349522
#   ndcg@10: 0.006540296
#   map@10: 0.002304815
# Epoch 2, Step 30, LR: 0.000080, Current Loss: 1.6281, Avg Loss: 1.7320
# Diff stats — min: -15.5858, max: 15.5068, mean: 0.1063, std: 3.8197
#
# Step 81 — Test metrics:
#   precision@10: 0.005182119
#   recall@10: 0.005183959
#   ndcg@10: 0.006368730
#   map@10: 0.002253305
# Epoch 2, Step 40, LR: 0.000080, Current Loss: 1.5966, Avg Loss: 1.6999
# Diff stats — min: -12.7119, max: 12.9024, mean: 0.0540, std: 3.6414
#
# Step 91 — Test metrics:
#   precision@10: 0.005198675
#   recall@10: 0.005200515
#   ndcg@10: 0.006389081
#   map@10: 0.002257726
# Epoch 2, Step 50, LR: 0.000080, Current Loss: 1.6062, Avg Loss: 1.6777
# Diff stats — min: -16.6194, max: 15.1912, mean: -0.0034, std: 3.6318
#
# Step 101 — Test metrics:
#   precision@10: 0.005264901
#   recall@10: 0.005266740
#   ndcg@10: 0.006412424
#   map@10: 0.002250618
# Epoch 2 completed, Train Loss: 1.6741
# Epoch 3, Step 1, LR: 0.000080, Current Loss: 1.5589, Avg Loss: 1.5589
# Diff stats — min: -12.5283, max: 14.9786, mean: 0.0949, std: 3.6128
#
# Step 104 — Test metrics:
#   precision@10: 0.005215232
#   recall@10: 0.005217071
#   ndcg@10: 0.006439138
#   map@10: 0.002280977
# Epoch 3, Step 10, LR: 0.000080, Current Loss: 1.5253, Avg Loss: 1.5391
# Diff stats — min: -13.1770, max: 12.5570, mean: 0.0592, std: 3.4700
#
# Step 113 — Test metrics:
#   precision@10: 0.005215232
#   recall@10: 0.005217071
#   ndcg@10: 0.006475500
#   map@10: 0.002305372
# Epoch 3, Step 20, LR: 0.000080, Current Loss: 1.5327, Avg Loss: 1.5221
# Diff stats — min: -13.4318, max: 11.8670, mean: -0.0199, std: 3.3774
#
# Step 123 — Test metrics:
#   precision@10: 0.005082781
#   recall@10: 0.005086461
#   ndcg@10: 0.006350173
#   map@10: 0.002267799
# Epoch 3, Step 30, LR: 0.000080, Current Loss: 1.5148, Avg Loss: 1.4993
# Diff stats — min: -14.2052, max: 11.6548, mean: -0.0118, std: 3.3347
#
# Step 133 — Test metrics:
#   precision@10: 0.005165563
#   recall@10: 0.005169242
#   ndcg@10: 0.006278095
#   map@10: 0.002200128
# Epoch 3, Step 40, LR: 0.000080, Current Loss: 1.4156, Avg Loss: 1.4820
# Diff stats — min: -14.5450, max: 12.4601, mean: 0.0536, std: 3.1510
#
# Step 143 — Test metrics:
#   precision@10: 0.005182119
#   recall@10: 0.005185798
#   ndcg@10: 0.006247693
#   map@10: 0.002178979
# Epoch 3, Step 50, LR: 0.000080, Current Loss: 1.4298, Avg Loss: 1.4659
# Diff stats — min: -11.4947, max: 11.3876, mean: 0.0167, std: 3.1502
#
# Step 153 — Test metrics:
#   precision@10: 0.005182119
#   recall@10: 0.005185798
#   ndcg@10: 0.006157676
#   map@10: 0.002124317
# Epoch 3 completed, Train Loss: 1.4627
# Epoch 4, Step 1, LR: 0.000080, Current Loss: 1.3169, Avg Loss: 1.3169
# Diff stats — min: -12.6693, max: 14.3809, mean: 0.2079, std: 3.0882
#
# Step 156 — Test metrics:
#   precision@10: 0.005215232
#   recall@10: 0.005218911
#   ndcg@10: 0.006161231
#   map@10: 0.002117636
# Epoch 4, Step 10, LR: 0.000080, Current Loss: 1.3293, Avg Loss: 1.3477
# Diff stats — min: -10.7138, max: 11.7191, mean: 0.1013, std: 2.9888
#
# Step 165 — Test metrics:
#   precision@10: 0.005066225
#   recall@10: 0.005069904
#   ndcg@10: 0.005994636
#   map@10: 0.002060017
# Epoch 4, Step 20, LR: 0.000080, Current Loss: 1.3401, Avg Loss: 1.3426
# Diff stats — min: -11.9094, max: 10.8579, mean: 0.0738, std: 2.9676
#
# Step 175 — Test metrics:
#   precision@10: 0.005066225
#   recall@10: 0.005069904
#   ndcg@10: 0.005932472
#   map@10: 0.002024953
# Epoch 4, Step 30, LR: 0.000080, Current Loss: 1.3120, Avg Loss: 1.3293
# Diff stats — min: -10.8362, max: 12.0212, mean: 0.0703, std: 2.8872
#
# Step 185 — Test metrics:
#   precision@10: 0.004983444
#   recall@10: 0.004985283
#   ndcg@10: 0.005860215
#   map@10: 0.002011977
# Epoch 4, Step 40, LR: 0.000080, Current Loss: 1.2714, Avg Loss: 1.3161
# Diff stats — min: -14.9542, max: 13.5929, mean: 0.0897, std: 2.7964
#
# Step 195 — Test metrics:
#   precision@10: 0.004983444
#   recall@10: 0.004985283
#   ndcg@10: 0.005861098
#   map@10: 0.001996163
# Epoch 4, Step 50, LR: 0.000080, Current Loss: 1.2769, Avg Loss: 1.3031
# Diff stats — min: -13.4017, max: 12.4994, mean: 0.0842, std: 2.8047
#
# Step 205 — Test metrics:
#   precision@10: 0.005000000
#   recall@10: 0.005001840
#   ndcg@10: 0.005782550
#   map@10: 0.001953616
# Epoch 4 completed, Train Loss: 1.3014
# Epoch 5, Step 1, LR: 0.000080, Current Loss: 1.2364, Avg Loss: 1.2364
# Diff stats — min: -10.2415, max: 11.7487, mean: 0.0978, std: 2.7015
#
# Step 208 — Test metrics:
#   precision@10: 0.004950331
#   recall@10: 0.004952171
#   ndcg@10: 0.005801490
#   map@10: 0.001980119
# Epoch 5, Step 10, LR: 0.000080, Current Loss: 1.2202, Avg Loss: 1.2385
# Diff stats — min: -10.6602, max: 11.1234, mean: 0.1119, std: 2.6767
#
# Step 217 — Test metrics:
#   precision@10: 0.004966887
#   recall@10: 0.004968727
#   ndcg@10: 0.005795605
#   map@10: 0.001968964
# Epoch 5, Step 20, LR: 0.000080, Current Loss: 1.1979, Avg Loss: 1.2314
# Diff stats — min: -11.9651, max: 10.0869, mean: 0.1469, std: 2.6687
#
# Step 227 — Test metrics:
#   precision@10: 0.005049669
#   recall@10: 0.005051508
#   ndcg@10: 0.005943957
#   map@10: 0.002032403
# Epoch 5, Step 30, LR: 0.000080, Current Loss: 1.1928, Avg Loss: 1.2257
# Diff stats — min: -12.8393, max: 11.1386, mean: 0.1488, std: 2.6423
#
# Step 237 — Test metrics:
#   precision@10: 0.005165563
#   recall@10: 0.005167403
#   ndcg@10: 0.006026367
#   map@10: 0.002049774
# Epoch 5, Step 40, LR: 0.000080, Current Loss: 1.1675, Avg Loss: 1.2188
# Diff stats — min: -10.8616, max: 11.9645, mean: 0.1892, std: 2.6308
#
# Step 247 — Test metrics:
#   precision@10: 0.005198675
#   recall@10: 0.005200515
#   ndcg@10: 0.006085033
#   map@10: 0.002077158
# Epoch 5, Step 50, LR: 0.000080, Current Loss: 1.1777, Avg Loss: 1.2145
# Diff stats — min: -9.2956, max: 9.7672, mean: 0.1558, std: 2.5974
#
# Step 257 — Test metrics:
#   precision@10: 0.005480132
#   recall@10: 0.005481972
#   ndcg@10: 0.006353691
#   map@10: 0.002157712
# Epoch 5 completed, Train Loss: 1.2140
# Epoch 6, Step 1, LR: 0.000080, Current Loss: 1.2060, Avg Loss: 1.2060
# Diff stats — min: -11.3820, max: 11.0594, mean: 0.0814, std: 2.5835
#
# Step 260 — Test metrics:
#   precision@10: 0.005430464
#   recall@10: 0.005432303
#   ndcg@10: 0.006360329
#   map@10: 0.002176193
# Epoch 6, Step 10, LR: 0.000080, Current Loss: 1.1811, Avg Loss: 1.1872
# Diff stats — min: -10.3893, max: 12.7104, mean: 0.1689, std: 2.6463
#
# Step 269 — Test metrics:
#   precision@10: 0.005447020
#   recall@10: 0.005448859
#   ndcg@10: 0.006351715
#   map@10: 0.002164354
# Epoch 6, Step 20, LR: 0.000080, Current Loss: 1.1905, Avg Loss: 1.1880
# Diff stats — min: -10.0577, max: 8.8676, mean: 0.0994, std: 2.5515
#
# Step 279 — Test metrics:
#   precision@10: 0.005380795
#   recall@10: 0.005382634
#   ndcg@10: 0.006270790
#   map@10: 0.002134388
# Epoch 6, Step 30, LR: 0.000080, Current Loss: 1.1672, Avg Loss: 1.1829
# Diff stats — min: -10.6685, max: 11.7598, mean: 0.1921, std: 2.6304
#
# Step 289 — Test metrics:
#   precision@10: 0.005397351
#   recall@10: 0.005399191
#   ndcg@10: 0.006308133
#   map@10: 0.002154598
# Epoch 6, Step 40, LR: 0.000080, Current Loss: 1.1652, Avg Loss: 1.1752
# Diff stats — min: -10.7404, max: 12.2693, mean: 0.1526, std: 2.5647
#
# Step 299 — Test metrics:
#   precision@10: 0.005447020
#   recall@10: 0.005448859
#   ndcg@10: 0.006389385
#   map@10: 0.002190325
# Epoch 6, Step 50, LR: 0.000080, Current Loss: 1.1510, Avg Loss: 1.1731
# Diff stats — min: -9.0932, max: 9.9844, mean: 0.1563, std: 2.5130
#
# Step 309 — Test metrics:
#   precision@10: 0.005463576
#   recall@10: 0.005465416
#   ndcg@10: 0.006464132
#   map@10: 0.002228175
# Epoch 6 completed, Train Loss: 1.1724
# Epoch 7, Step 1, LR: 0.000080, Current Loss: 1.1642, Avg Loss: 1.1642
# Diff stats — min: -10.2417, max: 9.5909, mean: 0.1579, std: 2.5585
#
# Step 312 — Test metrics:
#   precision@10: 0.005513245
#   recall@10: 0.005515085
#   ndcg@10: 0.006533566
#   map@10: 0.002257831
# Epoch 7, Step 10, LR: 0.000080, Current Loss: 1.1378, Avg Loss: 1.1573
# Diff stats — min: -12.1594, max: 9.2001, mean: 0.1468, std: 2.4683
#
# Step 321 — Test metrics:
#   precision@10: 0.005397351
#   recall@10: 0.005399191
#   ndcg@10: 0.006435915
#   map@10: 0.002229922
# Epoch 7, Step 20, LR: 0.000080, Current Loss: 1.1586, Avg Loss: 1.1471
# Diff stats — min: -9.3775, max: 9.8184, mean: 0.0940, std: 2.4593
#
# Step 331 — Test metrics:
#   precision@10: 0.005347682
#   recall@10: 0.005349522
#   ndcg@10: 0.006436729
#   map@10: 0.002243286
# Epoch 7, Step 30, LR: 0.000080, Current Loss: 1.1378, Avg Loss: 1.1396
# Diff stats — min: -8.8668, max: 20.4728, mean: 0.1498, std: 2.4848
#
# Step 341 — Test metrics:
#   precision@10: 0.005430464
#   recall@10: 0.005432303
#   ndcg@10: 0.006508322
#   map@10: 0.002264598
# Epoch 7, Step 40, LR: 0.000080, Current Loss: 1.1562, Avg Loss: 1.1356
# Diff stats — min: -10.8636, max: 9.2920, mean: 0.1100, std: 2.4633
#
# Step 351 — Test metrics:
#   precision@10: 0.005430464
#   recall@10: 0.005432303
#   ndcg@10: 0.006470468
#   map@10: 0.002237747
# Epoch 7, Step 50, LR: 0.000080, Current Loss: 1.1231, Avg Loss: 1.1327
# Diff stats — min: -7.9736, max: 8.7138, mean: 0.1568, std: 2.4309
#
# Step 361 — Test metrics:
#   precision@10: 0.005430464
#   recall@10: 0.005432303
#   ndcg@10: 0.006409124
#   map@10: 0.002200555
# Epoch 7 completed, Train Loss: 1.1318
# Epoch 8, Step 1, LR: 0.000080, Current Loss: 1.1175, Avg Loss: 1.1175
# Diff stats — min: -9.9675, max: 12.0037, mean: 0.1672, std: 2.4323
#
# Step 364 — Test metrics:
#   precision@10: 0.005413907
#   recall@10: 0.005415747
#   ndcg@10: 0.006403669
#   map@10: 0.002203872
# Epoch 8, Step 10, LR: 0.000080, Current Loss: 1.0842, Avg Loss: 1.0992
# Diff stats — min: -10.8998, max: 9.9155, mean: 0.1935, std: 2.3713
#
# Step 373 — Test metrics:
#   precision@10: 0.005546358
#   recall@10: 0.005548197
#   ndcg@10: 0.006535606
#   map@10: 0.002244264
# Epoch 8, Step 20, LR: 0.000080, Current Loss: 1.0884, Avg Loss: 1.1034
# Diff stats — min: -9.4264, max: 10.6527, mean: 0.2106, std: 2.4206
#
# Step 383 — Test metrics:
#   precision@10: 0.005397351
#   recall@10: 0.005399191
#   ndcg@10: 0.006388292
#   map@10: 0.002196435
# Epoch 8, Step 30, LR: 0.000080, Current Loss: 1.0974, Avg Loss: 1.1008
# Diff stats — min: -10.0086, max: 9.8436, mean: 0.1535, std: 2.3539
#
# Step 393 — Test metrics:
#   precision@10: 0.005397351
#   recall@10: 0.005399191
#   ndcg@10: 0.006418336
#   map@10: 0.002217794
# Epoch 8, Step 40, LR: 0.000080, Current Loss: 1.0933, Avg Loss: 1.0985
# Diff stats — min: -12.2277, max: 8.2090, mean: 0.1771, std: 2.3889
#
# Step 403 — Test metrics:
#   precision@10: 0.005480132
#   recall@10: 0.005481972
#   ndcg@10: 0.006484880
#   map@10: 0.002235986
# Epoch 8, Step 50, LR: 0.000080, Current Loss: 1.0847, Avg Loss: 1.0956
# Diff stats — min: -7.8816, max: 9.7939, mean: 0.1855, std: 2.3521
#
# Step 413 — Test metrics:
#   precision@10: 0.005480132
#   recall@10: 0.005481972
#   ndcg@10: 0.006443294
#   map@10: 0.002208688
# Epoch 8 completed, Train Loss: 1.0943
# Epoch 9, Step 1, LR: 0.000080, Current Loss: 1.1014, Avg Loss: 1.1014
# Diff stats — min: -9.2205, max: 9.0846, mean: 0.1345, std: 2.3245
#
# Step 416 — Test metrics:
#   precision@10: 0.005480132
#   recall@10: 0.005481972
#   ndcg@10: 0.006438493
#   map@10: 0.002205778
# Epoch 9, Step 10, LR: 0.000080, Current Loss: 1.0780, Avg Loss: 1.0794
# Diff stats — min: -8.8913, max: 10.5963, mean: 0.1879, std: 2.3500
#
# Step 425 — Test metrics:
#   precision@10: 0.005430464
#   recall@10: 0.005432303
#   ndcg@10: 0.006442961
#   map@10: 0.002221178
# Epoch 9, Step 20, LR: 0.000080, Current Loss: 1.0385, Avg Loss: 1.0756
# Diff stats — min: -7.9902, max: 12.2822, mean: 0.2440, std: 2.3032
#
# Step 435 — Test metrics:
#   precision@10: 0.005413907
#   recall@10: 0.005415747
#   ndcg@10: 0.006446531
#   map@10: 0.002228963
# Epoch 9, Step 30, LR: 0.000080, Current Loss: 1.0786, Avg Loss: 1.0723
# Diff stats — min: -9.2339, max: 9.1500, mean: 0.1636, std: 2.3061
#
# Step 445 — Test metrics:
#   precision@10: 0.005463576
#   recall@10: 0.005465416
#   ndcg@10: 0.006503193
#   map@10: 0.002248371
# Epoch 9, Step 40, LR: 0.000080, Current Loss: 1.0628, Avg Loss: 1.0697
# Diff stats — min: -8.1308, max: 12.4262, mean: 0.2265, std: 2.3559
#
# Step 455 — Test metrics:
#   precision@10: 0.005596026
#   recall@10: 0.005597866
#   ndcg@10: 0.006543167
#   map@10: 0.002234843
# Epoch 9, Step 50, LR: 0.000080, Current Loss: 1.0312, Avg Loss: 1.0660
# Diff stats — min: -9.5539, max: 8.3650, mean: 0.2264, std: 2.2477
#
# Step 465 — Test metrics:
#   precision@10: 0.005579470
#   recall@10: 0.005581310
#   ndcg@10: 0.006536300
#   map@10: 0.002233746
# Epoch 9 completed, Train Loss: 1.0651
# Epoch 10, Step 1, LR: 0.000080, Current Loss: 1.0525, Avg Loss: 1.0525
# Diff stats — min: -11.5074, max: 11.4799, mean: 0.2144, std: 2.3016
#
# Step 468 — Test metrics:
#   precision@10: 0.005546358
#   recall@10: 0.005548197
#   ndcg@10: 0.006537336
#   map@10: 0.002240487
# Epoch 10, Step 10, LR: 0.000080, Current Loss: 1.0231, Avg Loss: 1.0531
# Diff stats — min: -7.5339, max: 8.3439, mean: 0.2539, std: 2.2610
#
# Step 477 — Test metrics:
#   precision@10: 0.005596026
#   recall@10: 0.005597866
#   ndcg@10: 0.006571974
#   map@10: 0.002246005
# Epoch 10, Step 20, LR: 0.000080, Current Loss: 1.0520, Avg Loss: 1.0517
# Diff stats — min: -8.8401, max: 9.7406, mean: 0.1697, std: 2.2282
#
# Step 487 — Test metrics:
#   precision@10: 0.005529801
#   recall@10: 0.005531641
#   ndcg@10: 0.006537322
#   map@10: 0.002242182
# Epoch 10, Step 30, LR: 0.000080, Current Loss: 1.0458, Avg Loss: 1.0449
# Diff stats — min: -7.9463, max: 7.8631, mean: 0.1712, std: 2.2082
#
# Step 497 — Test metrics:
#   precision@10: 0.005546358
#   recall@10: 0.005548197
#   ndcg@10: 0.006526301
#   map@10: 0.002234101
# Epoch 10, Step 40, LR: 0.000080, Current Loss: 1.0306, Avg Loss: 1.0408
# Diff stats — min: -8.1796, max: 11.6907, mean: 0.2147, std: 2.2415
#
# Step 507 — Test metrics:
#   precision@10: 0.005596026
#   recall@10: 0.005597866
#   ndcg@10: 0.006607290
#   map@10: 0.002266274
# Epoch 10, Step 50, LR: 0.000080, Current Loss: 1.0373, Avg Loss: 1.0379
# Diff stats — min: -10.6524, max: 8.8329, mean: 0.2269, std: 2.2586
#
# Step 517 — Test metrics:
#   precision@10: 0.005728477
#   recall@10: 0.005730316
#   ndcg@10: 0.006783669
#   map@10: 0.002335475
# Epoch 10 completed, Train Loss: 1.0370
# Epoch 11, Step 1, LR: 0.000080, Current Loss: 1.0375, Avg Loss: 1.0375
# Diff stats — min: -12.5924, max: 10.7544, mean: 0.2209, std: 2.2544
#
# Step 520 — Test metrics:
#   precision@10: 0.005745033
#   recall@10: 0.005746873
#   ndcg@10: 0.006793660
#   map@10: 0.002336513
# Epoch 11, Step 10, LR: 0.000080, Current Loss: 1.0061, Avg Loss: 1.0181
# Diff stats — min: -7.8738, max: 9.3205, mean: 0.2454, std: 2.2010
#
# Step 529 — Test metrics:
#   precision@10: 0.005596026
#   recall@10: 0.005597866
#   ndcg@10: 0.006730235
#   map@10: 0.002340330
# Epoch 11, Step 20, LR: 0.000080, Current Loss: 1.0195, Avg Loss: 1.0106
# Diff stats — min: -7.9060, max: 8.2978, mean: 0.2239, std: 2.2018
#
# Step 539 — Test metrics:
#   precision@10: 0.005662252
#   recall@10: 0.005664091
#   ndcg@10: 0.006676909
#   map@10: 0.002287626
# Epoch 11, Step 30, LR: 0.000080, Current Loss: 0.9921, Avg Loss: 1.0120
# Diff stats — min: -11.6517, max: 7.9506, mean: 0.2606, std: 2.1733
#
# Step 549 — Test metrics:
#   precision@10: 0.005546358
#   recall@10: 0.005548197
#   ndcg@10: 0.006515011
#   map@10: 0.002224377
# Epoch 11, Step 40, LR: 0.000080, Current Loss: 1.0307, Avg Loss: 1.0113
# Diff stats — min: -8.5230, max: 9.8697, mean: 0.2020, std: 2.2116
#
# Step 559 — Test metrics:
#   precision@10: 0.005612583
#   recall@10: 0.005614422
#   ndcg@10: 0.006603206
#   map@10: 0.002258823
# Epoch 11, Step 50, LR: 0.000080, Current Loss: 0.9865, Avg Loss: 1.0097
# Diff stats — min: -7.9116, max: 8.4908, mean: 0.2588, std: 2.1501
#
# Step 569 — Test metrics:
#   precision@10: 0.005711921
#   recall@10: 0.005713760
#   ndcg@10: 0.006804488
#   map@10: 0.002350619
# Epoch 11 completed, Train Loss: 1.0095
# Epoch 12, Step 1, LR: 0.000080, Current Loss: 1.0002, Avg Loss: 1.0002
# Diff stats — min: -8.0807, max: 9.6990, mean: 0.2216, std: 2.1421
#
# Step 572 — Test metrics:
#   precision@10: 0.005645695
#   recall@10: 0.005647535
#   ndcg@10: 0.006798631
#   map@10: 0.002365467
# Epoch 12, Step 10, LR: 0.000080, Current Loss: 0.9931, Avg Loss: 0.9946
# Diff stats — min: -9.0651, max: 8.0568, mean: 0.2408, std: 2.1510
#
# Step 581 — Test metrics:
#   precision@10: 0.005745033
#   recall@10: 0.005746873
#   ndcg@10: 0.006846547
#   map@10: 0.002362550
# Epoch 12, Step 20, LR: 0.000080, Current Loss: 0.9944, Avg Loss: 0.9879
# Diff stats — min: -8.3753, max: 9.2381, mean: 0.2423, std: 2.1555
#
# Step 591 — Test metrics:
#   precision@10: 0.005728477
#   recall@10: 0.005730316
#   ndcg@10: 0.006757489
#   map@10: 0.002319116
# Epoch 12, Step 30, LR: 0.000080, Current Loss: 0.9468, Avg Loss: 0.9862
# Diff stats — min: -8.5547, max: 8.2091, mean: 0.3135, std: 2.0965
#
# Step 601 — Test metrics:
#   precision@10: 0.005761589
#   recall@10: 0.005763429
#   ndcg@10: 0.006742564
#   map@10: 0.002297238
# Epoch 12, Step 40, LR: 0.000080, Current Loss: 0.9850, Avg Loss: 0.9843
# Diff stats — min: -8.4220, max: 9.6689, mean: 0.2627, std: 2.1600
#
# Step 611 — Test metrics:
#   precision@10: 0.005695364
#   recall@10: 0.005697204
#   ndcg@10: 0.006724000
#   map@10: 0.002304767
# Epoch 12, Step 50, LR: 0.000080, Current Loss: 0.9941, Avg Loss: 0.9819
# Diff stats — min: -8.2052, max: 9.1511, mean: 0.2325, std: 2.1393
#
# Step 621 — Test metrics:
#   precision@10: 0.005662252
#   recall@10: 0.005664091
#   ndcg@10: 0.006741131
#   map@10: 0.002322986
# Epoch 12 completed, Train Loss: 0.9813
# Epoch 13, Step 1, LR: 0.000080, Current Loss: 0.9508, Avg Loss: 0.9508
# Diff stats — min: -7.1199, max: 10.3199, mean: 0.2940, std: 2.0960
#
# Step 624 — Test metrics:
#   precision@10: 0.005695364
#   recall@10: 0.005697204
#   ndcg@10: 0.006780922
#   map@10: 0.002337807
# Epoch 13, Step 10, LR: 0.000080, Current Loss: 0.9734, Avg Loss: 0.9575
# Diff stats — min: -8.5922, max: 8.4768, mean: 0.2509, std: 2.0867
#
# Step 633 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005779985
#   ndcg@10: 0.006833799
#   map@10: 0.002346322
# Epoch 13, Step 20, LR: 0.000080, Current Loss: 0.9519, Avg Loss: 0.9603
# Diff stats — min: -8.0386, max: 8.8803, mean: 0.3116, std: 2.1135
#
# Step 643 — Test metrics:
#   precision@10: 0.005761589
#   recall@10: 0.005763429
#   ndcg@10: 0.006724480
#   map@10: 0.002286161
# Epoch 13, Step 30, LR: 0.000080, Current Loss: 0.9436, Avg Loss: 0.9609
# Diff stats — min: -8.2828, max: 8.2925, mean: 0.2919, std: 2.0610
#
# Step 653 — Test metrics:
#   precision@10: 0.005711921
#   recall@10: 0.005713760
#   ndcg@10: 0.006731232
#   map@10: 0.002305634
# Epoch 13, Step 40, LR: 0.000080, Current Loss: 0.9450, Avg Loss: 0.9593
# Diff stats — min: -6.4293, max: 8.1198, mean: 0.2743, std: 2.0294
#
# Step 663 — Test metrics:
#   precision@10: 0.005695364
#   recall@10: 0.005697204
#   ndcg@10: 0.006746157
#   map@10: 0.002315805
# Epoch 13, Step 50, LR: 0.000080, Current Loss: 0.9614, Avg Loss: 0.9588
# Diff stats — min: -9.5089, max: 9.4156, mean: 0.2526, std: 2.0573
#
# Step 673 — Test metrics:
#   precision@10: 0.005860927
#   recall@10: 0.005862767
#   ndcg@10: 0.006931209
#   map@10: 0.002383594
# Epoch 13 completed, Train Loss: 0.9578
# Epoch 14, Step 1, LR: 0.000080, Current Loss: 0.9713, Avg Loss: 0.9713
# Diff stats — min: -6.7733, max: 8.0698, mean: 0.2171, std: 2.0308
#
# Step 676 — Test metrics:
#   precision@10: 0.005894040
#   recall@10: 0.005895879
#   ndcg@10: 0.006941617
#   map@10: 0.002378239
# Epoch 14, Step 10, LR: 0.000080, Current Loss: 0.9078, Avg Loss: 0.9470
# Diff stats — min: -9.2056, max: 11.5014, mean: 0.3453, std: 2.0199
#
# Step 685 — Test metrics:
#   precision@10: 0.005811258
#   recall@10: 0.005813098
#   ndcg@10: 0.006912907
#   map@10: 0.002383278
# Epoch 14, Step 20, LR: 0.000080, Current Loss: 0.9413, Avg Loss: 0.9421
# Diff stats — min: -7.9956, max: 7.3844, mean: 0.2933, std: 2.0501
#
# Step 695 — Test metrics:
#   precision@10: 0.005844371
#   recall@10: 0.005846210
#   ndcg@10: 0.006946019
#   map@10: 0.002394309
# Epoch 14, Step 30, LR: 0.000080, Current Loss: 0.9389, Avg Loss: 0.9422
# Diff stats — min: -8.5489, max: 7.1035, mean: 0.2453, std: 1.9780
#
# Step 705 — Test metrics:
#   precision@10: 0.005927152
#   recall@10: 0.005928992
#   ndcg@10: 0.006923422
#   map@10: 0.002354403
# Epoch 14, Step 40, LR: 0.000080, Current Loss: 0.9091, Avg Loss: 0.9403
# Diff stats — min: -7.6938, max: 7.8679, mean: 0.3247, std: 1.9991
#
# Step 715 — Test metrics:
#   precision@10: 0.005927152
#   recall@10: 0.005928992
#   ndcg@10: 0.007053435
#   map@10: 0.002431081
# Epoch 14, Step 50, LR: 0.000080, Current Loss: 0.9337, Avg Loss: 0.9381
# Diff stats — min: -7.2408, max: 8.2157, mean: 0.2852, std: 2.0274
#
# Step 725 — Test metrics:
#   precision@10: 0.005860927
#   recall@10: 0.005862767
#   ndcg@10: 0.007074184
#   map@10: 0.002466184
# Epoch 14 completed, Train Loss: 0.9369
# Epoch 15, Step 1, LR: 0.000080, Current Loss: 0.9045, Avg Loss: 0.9045
# Diff stats — min: -10.0217, max: 7.6087, mean: 0.3546, std: 2.0257
#
# Step 728 — Test metrics:
#   precision@10: 0.005794702
#   recall@10: 0.005796542
#   ndcg@10: 0.007009815
#   map@10: 0.002446376
# Epoch 15, Step 10, LR: 0.000080, Current Loss: 0.9232, Avg Loss: 0.9282
# Diff stats — min: -7.7614, max: 8.6969, mean: 0.3013, std: 2.0058
#
# Step 737 — Test metrics:
#   precision@10: 0.005678808
#   recall@10: 0.005680648
#   ndcg@10: 0.006907865
#   map@10: 0.002415970
# Epoch 15, Step 20, LR: 0.000080, Current Loss: 0.9103, Avg Loss: 0.9287
# Diff stats — min: -9.3194, max: 9.0368, mean: 0.3286, std: 2.0014
#
# Step 747 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005779985
#   ndcg@10: 0.006875430
#   map@10: 0.002369100
# Epoch 15, Step 30, LR: 0.000080, Current Loss: 0.9026, Avg Loss: 0.9244
# Diff stats — min: -7.9830, max: 6.8878, mean: 0.3301, std: 1.9799
#
# Step 757 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005779985
#   ndcg@10: 0.006835498
#   map@10: 0.002345514
# Epoch 15, Step 40, LR: 0.000080, Current Loss: 0.9256, Avg Loss: 0.9214
# Diff stats — min: -6.6304, max: 9.8699, mean: 0.2676, std: 1.9613
#
# Step 767 — Test metrics:
#   precision@10: 0.005728477
#   recall@10: 0.005730316
#   ndcg@10: 0.006814584
#   map@10: 0.002345974
# Epoch 15, Step 50, LR: 0.000080, Current Loss: 0.9134, Avg Loss: 0.9189
# Diff stats — min: -7.3077, max: 8.3431, mean: 0.2754, std: 1.9336
#
# Step 777 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005779985
#   ndcg@10: 0.006825279
#   map@10: 0.002340225
# Epoch 15 completed, Train Loss: 0.9180
# Epoch 16, Step 1, LR: 0.000080, Current Loss: 0.9201, Avg Loss: 0.9201
# Diff stats — min: -7.7685, max: 7.2204, mean: 0.2493, std: 1.9127
#
# Step 780 — Test metrics:
#   precision@10: 0.005794702
#   recall@10: 0.005796542
#   ndcg@10: 0.006834371
#   map@10: 0.002340849
# Epoch 16, Step 10, LR: 0.000080, Current Loss: 0.9020, Avg Loss: 0.9033
# Diff stats — min: -7.9881, max: 6.8782, mean: 0.3054, std: 1.9407
#
# Step 789 — Test metrics:
#   precision@10: 0.005877483
#   recall@10: 0.005879323
#   ndcg@10: 0.006825590
#   map@10: 0.002312454
# Epoch 16, Step 20, LR: 0.000080, Current Loss: 0.9071, Avg Loss: 0.9029
# Diff stats — min: -8.0518, max: 9.3160, mean: 0.2960, std: 1.9525
#
# Step 799 — Test metrics:
#   precision@10: 0.005943709
#   recall@10: 0.005945548
#   ndcg@10: 0.006865809
#   map@10: 0.002318827
# Epoch 16, Step 30, LR: 0.000080, Current Loss: 0.9097, Avg Loss: 0.9004
# Diff stats — min: -7.6670, max: 11.6632, mean: 0.2834, std: 1.9348
#
# Step 809 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.006915932
#   map@10: 0.002318288
# Epoch 16, Step 40, LR: 0.000080, Current Loss: 0.8913, Avg Loss: 0.9005
# Diff stats — min: -7.0920, max: 7.8487, mean: 0.3156, std: 1.9208
#
# Step 819 — Test metrics:
#   precision@10: 0.006026490
#   recall@10: 0.006028330
#   ndcg@10: 0.007027491
#   map@10: 0.002388757
# Epoch 16, Step 50, LR: 0.000080, Current Loss: 0.8844, Avg Loss: 0.8990
# Diff stats — min: -12.5651, max: 8.4019, mean: 0.3066, std: 1.8850
#
# Step 829 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.007063923
#   map@10: 0.002408967
# Epoch 16 completed, Train Loss: 0.8985
# Epoch 17, Step 1, LR: 0.000080, Current Loss: 0.8797, Avg Loss: 0.8797
# Diff stats — min: -6.4993, max: 8.1616, mean: 0.3268, std: 1.8929
#
# Step 832 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.007059070
#   map@10: 0.002406897
# Epoch 17, Step 10, LR: 0.000080, Current Loss: 0.8905, Avg Loss: 0.8809
# Diff stats — min: -6.5112, max: 8.4658, mean: 0.2961, std: 1.8875
#
# Step 841 — Test metrics:
#   precision@10: 0.006009934
#   recall@10: 0.006011773
#   ndcg@10: 0.007019541
#   map@10: 0.002390518
# Epoch 17, Step 20, LR: 0.000080, Current Loss: 0.8898, Avg Loss: 0.8797
# Diff stats — min: -6.6954, max: 7.4352, mean: 0.2767, std: 1.8565
#
# Step 851 — Test metrics:
#   precision@10: 0.005844371
#   recall@10: 0.005846210
#   ndcg@10: 0.006905414
#   map@10: 0.002368548
# Epoch 17, Step 30, LR: 0.000080, Current Loss: 0.8693, Avg Loss: 0.8763
# Diff stats — min: -7.6350, max: 7.8065, mean: 0.3257, std: 1.8534
#
# Step 861 — Test metrics:
#   precision@10: 0.005860927
#   recall@10: 0.005862767
#   ndcg@10: 0.006902346
#   map@10: 0.002360020
# Epoch 17, Step 40, LR: 0.000080, Current Loss: 0.8592, Avg Loss: 0.8742
# Diff stats — min: -6.1062, max: 6.8397, mean: 0.3232, std: 1.8184
#
# Step 871 — Test metrics:
#   precision@10: 0.006175497
#   recall@10: 0.006177336
#   ndcg@10: 0.007131032
#   map@10: 0.002407436
# Epoch 17, Step 50, LR: 0.000080, Current Loss: 0.8416, Avg Loss: 0.8711
# Diff stats — min: -6.2599, max: 7.8137, mean: 0.3662, std: 1.8236
#
# Step 881 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006898780
#   map@10: 0.002298578
# Epoch 17 completed, Train Loss: 0.8709
# Epoch 18, Step 1, LR: 0.000080, Current Loss: 0.8320, Avg Loss: 0.8320
# Diff stats — min: -7.7845, max: 7.6247, mean: 0.3706, std: 1.7981
#
# Step 884 — Test metrics:
#   precision@10: 0.006009934
#   recall@10: 0.006011773
#   ndcg@10: 0.006838791
#   map@10: 0.002277081
# Epoch 18, Step 10, LR: 0.000080, Current Loss: 0.8613, Avg Loss: 0.8579
# Diff stats — min: -7.0468, max: 7.6784, mean: 0.2970, std: 1.7901
#
# Step 893 — Test metrics:
#   precision@10: 0.005910596
#   recall@10: 0.005912436
#   ndcg@10: 0.006692838
#   map@10: 0.002220074
# Epoch 18, Step 20, LR: 0.000080, Current Loss: 0.8487, Avg Loss: 0.8596
# Diff stats — min: -6.1545, max: 7.5259, mean: 0.3536, std: 1.8341
#
# Step 903 — Test metrics:
#   precision@10: 0.005943709
#   recall@10: 0.005945548
#   ndcg@10: 0.006765865
#   map@10: 0.002251544
# Epoch 18, Step 30, LR: 0.000080, Current Loss: 0.8441, Avg Loss: 0.8578
# Diff stats — min: -7.1731, max: 9.0062, mean: 0.3363, std: 1.7937
#
# Step 913 — Test metrics:
#   precision@10: 0.006076159
#   recall@10: 0.006077999
#   ndcg@10: 0.007145127
#   map@10: 0.002444195
# Epoch 18, Step 40, LR: 0.000080, Current Loss: 0.8524, Avg Loss: 0.8567
# Diff stats — min: -6.1005, max: 7.3274, mean: 0.3224, std: 1.7960
#
# Step 923 — Test metrics:
#   precision@10: 0.006109272
#   recall@10: 0.006111111
#   ndcg@10: 0.007201166
#   map@10: 0.002471769
# Epoch 18, Step 50, LR: 0.000080, Current Loss: 0.8489, Avg Loss: 0.8556
# Diff stats — min: -8.5422, max: 7.4625, mean: 0.3294, std: 1.7999
#
# Step 933 — Test metrics:
#   precision@10: 0.005960265
#   recall@10: 0.005962104
#   ndcg@10: 0.007030192
#   map@10: 0.002408691
# Epoch 18 completed, Train Loss: 0.8548
# Epoch 19, Step 1, LR: 0.000080, Current Loss: 0.8361, Avg Loss: 0.8361
# Diff stats — min: -8.9632, max: 6.8694, mean: 0.3463, std: 1.7736
#
# Step 936 — Test metrics:
#   precision@10: 0.005993377
#   recall@10: 0.005995217
#   ndcg@10: 0.007000918
#   map@10: 0.002381544
# Epoch 19, Step 10, LR: 0.000080, Current Loss: 0.8345, Avg Loss: 0.8401
# Diff stats — min: -6.4097, max: 7.7593, mean: 0.3394, std: 1.7640
#
# Step 945 — Test metrics:
#   precision@10: 0.006026490
#   recall@10: 0.006028330
#   ndcg@10: 0.006857290
#   map@10: 0.002287324
# Epoch 19, Step 20, LR: 0.000080, Current Loss: 0.8215, Avg Loss: 0.8404
# Diff stats — min: -5.5190, max: 7.3170, mean: 0.3303, std: 1.6989
#
# Step 955 — Test metrics:
#   precision@10: 0.006026490
#   recall@10: 0.006028330
#   ndcg@10: 0.006810757
#   map@10: 0.002259257
# Epoch 19, Step 30, LR: 0.000080, Current Loss: 0.8371, Avg Loss: 0.8364
# Diff stats — min: -5.9857, max: 6.7294, mean: 0.3233, std: 1.7384
#
# Step 965 — Test metrics:
#   precision@10: 0.006092715
#   recall@10: 0.006094555
#   ndcg@10: 0.006954374
#   map@10: 0.002327834
# Epoch 19, Step 40, LR: 0.000080, Current Loss: 0.8362, Avg Loss: 0.8343
# Diff stats — min: -6.2113, max: 5.7862, mean: 0.3014, std: 1.7002
#
# Step 975 — Test metrics:
#   precision@10: 0.005943709
#   recall@10: 0.005945548
#   ndcg@10: 0.006952867
#   map@10: 0.002366998
# Epoch 19, Step 50, LR: 0.000080, Current Loss: 0.8229, Avg Loss: 0.8328
# Diff stats — min: -5.7962, max: 7.2006, mean: 0.3088, std: 1.6701
#
# Step 985 — Test metrics:
#   precision@10: 0.005960265
#   recall@10: 0.005962104
#   ndcg@10: 0.006881690
#   map@10: 0.002321816
# Epoch 19 completed, Train Loss: 0.8320
# Epoch 20, Step 1, LR: 0.000080, Current Loss: 0.8246, Avg Loss: 0.8246
# Diff stats — min: -7.0962, max: 7.8147, mean: 0.3129, std: 1.6874
#
# Step 988 — Test metrics:
#   precision@10: 0.005960265
#   recall@10: 0.005962104
#   ndcg@10: 0.006889659
#   map@10: 0.002326908
# Epoch 20, Step 10, LR: 0.000080, Current Loss: 0.8324, Avg Loss: 0.8226
# Diff stats — min: -5.9601, max: 8.7356, mean: 0.3032, std: 1.6976
#
# Step 997 — Test metrics:
#   precision@10: 0.005993377
#   recall@10: 0.005995217
#   ndcg@10: 0.006877393
#   map@10: 0.002309609
# Epoch 20, Step 20, LR: 0.000080, Current Loss: 0.8012, Avg Loss: 0.8203
# Diff stats — min: -5.2985, max: 6.8728, mean: 0.3363, std: 1.6290
#
# Step 1007 — Test metrics:
#   precision@10: 0.005960265
#   recall@10: 0.005962104
#   ndcg@10: 0.006848185
#   map@10: 0.002301206
# Epoch 20, Step 30, LR: 0.000080, Current Loss: 0.7925, Avg Loss: 0.8153
# Diff stats — min: -6.4405, max: 6.6081, mean: 0.3233, std: 1.5800
#
# Step 1017 — Test metrics:
#   precision@10: 0.005976821
#   recall@10: 0.005978661
#   ndcg@10: 0.006874965
#   map@10: 0.002313091
# Epoch 20, Step 40, LR: 0.000080, Current Loss: 0.7984, Avg Loss: 0.8131
# Diff stats — min: -5.4674, max: 8.6820, mean: 0.3148, std: 1.5924
#
# Step 1027 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006957185
#   map@10: 0.002332781
# Epoch 20, Step 50, LR: 0.000080, Current Loss: 0.8015, Avg Loss: 0.8103
# Diff stats — min: -6.1877, max: 6.3238, mean: 0.3219, std: 1.6114
#
# Step 1037 — Test metrics:
#   precision@10: 0.005927152
#   recall@10: 0.005928992
#   ndcg@10: 0.006878039
#   map@10: 0.002325870
# Epoch 20 completed, Train Loss: 0.8098
# Epoch 21, Step 1, LR: 0.000080, Current Loss: 0.8035, Avg Loss: 0.8035
# Diff stats — min: -9.2547, max: 6.0542, mean: 0.3193, std: 1.6116
#
# Step 1040 — Test metrics:
#   precision@10: 0.005910596
#   recall@10: 0.005912436
#   ndcg@10: 0.006836154
#   map@10: 0.002305010
# Epoch 21, Step 10, LR: 0.000080, Current Loss: 0.8069, Avg Loss: 0.8003
# Diff stats — min: -8.8567, max: 6.7687, mean: 0.2925, std: 1.5836
#
# Step 1049 — Test metrics:
#   precision@10: 0.006092715
#   recall@10: 0.006094555
#   ndcg@10: 0.006925388
#   map@10: 0.002313847
# Epoch 21, Step 20, LR: 0.000080, Current Loss: 0.7928, Avg Loss: 0.7953
# Diff stats — min: -6.6833, max: 6.5341, mean: 0.3101, std: 1.5612
#
# Step 1059 — Test metrics:
#   precision@10: 0.006009934
#   recall@10: 0.006011773
#   ndcg@10: 0.006844686
#   map@10: 0.002284965
# Epoch 21, Step 30, LR: 0.000080, Current Loss: 0.7786, Avg Loss: 0.7921
# Diff stats — min: -7.7656, max: 6.4781, mean: 0.3352, std: 1.5566
#
# Step 1069 — Test metrics:
#   precision@10: 0.006158940
#   recall@10: 0.006160780
#   ndcg@10: 0.006905775
#   map@10: 0.002274158
# Epoch 21, Step 40, LR: 0.000080, Current Loss: 0.7729, Avg Loss: 0.7912
# Diff stats — min: -6.6302, max: 6.4040, mean: 0.3408, std: 1.5345
#
# Step 1079 — Test metrics:
#   precision@10: 0.006158940
#   recall@10: 0.006160780
#   ndcg@10: 0.006968236
#   map@10: 0.002310858
# Epoch 21, Step 50, LR: 0.000080, Current Loss: 0.7991, Avg Loss: 0.7900
# Diff stats — min: -6.9346, max: 8.3004, mean: 0.2676, std: 1.5112
#
# Step 1089 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006855327
#   map@10: 0.002273001
# Epoch 21 completed, Train Loss: 0.7900
# Epoch 22, Step 1, LR: 0.000080, Current Loss: 0.7766, Avg Loss: 0.7766
# Diff stats — min: -5.7436, max: 6.8569, mean: 0.3138, std: 1.5055
#
# Step 1092 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006880559
#   map@10: 0.002289124
# Epoch 22, Step 10, LR: 0.000080, Current Loss: 0.7639, Avg Loss: 0.7689
# Diff stats — min: -6.2317, max: 7.3168, mean: 0.3408, std: 1.5040
#
# Step 1101 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006789157
#   map@10: 0.002234797
# Epoch 22, Step 20, LR: 0.000080, Current Loss: 0.7724, Avg Loss: 0.7709
# Diff stats — min: -7.5545, max: 6.0660, mean: 0.3049, std: 1.4781
#
# Step 1111 — Test metrics:
#   precision@10: 0.005976821
#   recall@10: 0.005978661
#   ndcg@10: 0.006767073
#   map@10: 0.002246505
# Epoch 22, Step 30, LR: 0.000080, Current Loss: 0.7823, Avg Loss: 0.7713
# Diff stats — min: -6.2976, max: 6.9533, mean: 0.2896, std: 1.4849
#
# Step 1121 — Test metrics:
#   precision@10: 0.006175497
#   recall@10: 0.006177336
#   ndcg@10: 0.006909044
#   map@10: 0.002275176
# Epoch 22, Step 40, LR: 0.000080, Current Loss: 0.7663, Avg Loss: 0.7706
# Diff stats — min: -5.2735, max: 7.1147, mean: 0.3053, std: 1.4505
#
# Step 1131 — Test metrics:
#   precision@10: 0.005993377
#   recall@10: 0.005995217
#   ndcg@10: 0.006752708
#   map@10: 0.002226414
# Epoch 22, Step 50, LR: 0.000080, Current Loss: 0.7696, Avg Loss: 0.7686
# Diff stats — min: -7.8683, max: 7.2717, mean: 0.3044, std: 1.4634
#
# Step 1141 — Test metrics:
#   precision@10: 0.006125828
#   recall@10: 0.006127667
#   ndcg@10: 0.006851753
#   map@10: 0.002245881
# Epoch 22 completed, Train Loss: 0.7685
# Epoch 23, Step 1, LR: 0.000080, Current Loss: 0.7551, Avg Loss: 0.7551
# Diff stats — min: -6.5281, max: 6.0999, mean: 0.3042, std: 1.4095
#
# Step 1144 — Test metrics:
#   precision@10: 0.006125828
#   recall@10: 0.006127667
#   ndcg@10: 0.006848896
#   map@10: 0.002244067
# Epoch 23, Step 10, LR: 0.000080, Current Loss: 0.7705, Avg Loss: 0.7598
# Diff stats — min: -4.8318, max: 7.3626, mean: 0.2788, std: 1.4229
#
# Step 1153 — Test metrics:
#   precision@10: 0.006225166
#   recall@10: 0.006227005
#   ndcg@10: 0.006902429
#   map@10: 0.002249231
# Epoch 23, Step 20, LR: 0.000080, Current Loss: 0.7557, Avg Loss: 0.7558
# Diff stats — min: -5.3725, max: 5.7837, mean: 0.2989, std: 1.3975
#
# Step 1163 — Test metrics:
#   precision@10: 0.006192053
#   recall@10: 0.006193893
#   ndcg@10: 0.006912311
#   map@10: 0.002269585
# Epoch 23, Step 30, LR: 0.000080, Current Loss: 0.7515, Avg Loss: 0.7538
# Diff stats — min: -7.1161, max: 7.2924, mean: 0.2887, std: 1.3644
#
# Step 1173 — Test metrics:
#   precision@10: 0.005993377
#   recall@10: 0.005995217
#   ndcg@10: 0.006763956
#   map@10: 0.002232728
# Epoch 23, Step 40, LR: 0.000080, Current Loss: 0.7552, Avg Loss: 0.7516
# Diff stats — min: -5.8491, max: 5.8566, mean: 0.2690, std: 1.3420
#
# Step 1183 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.006719409
#   map@10: 0.002194569
# Epoch 23, Step 50, LR: 0.000080, Current Loss: 0.7100, Avg Loss: 0.7481
# Diff stats — min: -5.2597, max: 5.9579, mean: 0.3472, std: 1.2993
#
# Step 1193 — Test metrics:
#   precision@10: 0.006076159
#   recall@10: 0.006077999
#   ndcg@10: 0.006707607
#   map@10: 0.002179235
# Epoch 23 completed, Train Loss: 0.7478
# Epoch 24, Step 1, LR: 0.000080, Current Loss: 0.7338, Avg Loss: 0.7338
# Diff stats — min: -4.6767, max: 5.4456, mean: 0.3067, std: 1.3276
#
# Step 1196 — Test metrics:
#   precision@10: 0.006092715
#   recall@10: 0.006094555
#   ndcg@10: 0.006627792
#   map@10: 0.002125907
# Epoch 24, Step 10, LR: 0.000080, Current Loss: 0.7375, Avg Loss: 0.7370
# Diff stats — min: -5.7514, max: 6.2791, mean: 0.2706, std: 1.2723
#
# Step 1205 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.006689282
#   map@10: 0.002179196
# Epoch 24, Step 20, LR: 0.000080, Current Loss: 0.7244, Avg Loss: 0.7327
# Diff stats — min: -4.7580, max: 5.1013, mean: 0.2941, std: 1.2621
#
# Step 1215 — Test metrics:
#   precision@10: 0.006092715
#   recall@10: 0.006094555
#   ndcg@10: 0.006699025
#   map@10: 0.002170425
# Epoch 24, Step 30, LR: 0.000080, Current Loss: 0.7348, Avg Loss: 0.7315
# Diff stats — min: -6.4124, max: 5.1655, mean: 0.2670, std: 1.2550
#
# Step 1225 — Test metrics:
#   precision@10: 0.006026490
#   recall@10: 0.006028330
#   ndcg@10: 0.006665349
#   map@10: 0.002172455
# Epoch 24, Step 40, LR: 0.000080, Current Loss: 0.7136, Avg Loss: 0.7312
# Diff stats — min: -6.7540, max: 6.5162, mean: 0.3019, std: 1.2351
#
# Step 1235 — Test metrics:
#   precision@10: 0.005827815
#   recall@10: 0.005829654
#   ndcg@10: 0.006505773
#   map@10: 0.002132569
# Epoch 24, Step 50, LR: 0.000080, Current Loss: 0.7215, Avg Loss: 0.7286
# Diff stats — min: -4.6486, max: 6.3440, mean: 0.2698, std: 1.2047
#
# Step 1245 — Test metrics:
#   precision@10: 0.005844371
#   recall@10: 0.005846210
#   ndcg@10: 0.006554930
#   map@10: 0.002156411
# Epoch 24 completed, Train Loss: 0.7284
# Epoch 25, Step 1, LR: 0.000080, Current Loss: 0.7370, Avg Loss: 0.7370
# Diff stats — min: -5.1972, max: 6.3971, mean: 0.2450, std: 1.2229
#
# Step 1248 — Test metrics:
#   precision@10: 0.005811258
#   recall@10: 0.005813098
#   ndcg@10: 0.006538688
#   map@10: 0.002155465
# Epoch 25, Step 10, LR: 0.000080, Current Loss: 0.7246, Avg Loss: 0.7199
# Diff stats — min: -5.5558, max: 6.1688, mean: 0.2576, std: 1.1928
#
# Step 1257 — Test metrics:
#   precision@10: 0.005910596
#   recall@10: 0.005912436
#   ndcg@10: 0.006545802
#   map@10: 0.002136103
# Epoch 25, Step 20, LR: 0.000080, Current Loss: 0.7070, Avg Loss: 0.7174
# Diff stats — min: -7.1912, max: 8.2358, mean: 0.2785, std: 1.1586
#
# Step 1267 — Test metrics:
#   precision@10: 0.005894040
#   recall@10: 0.005895879
#   ndcg@10: 0.006395949
#   map@10: 0.002045234
# Epoch 25, Step 30, LR: 0.000080, Current Loss: 0.7036, Avg Loss: 0.7159
# Diff stats — min: -6.7645, max: 7.4457, mean: 0.2842, std: 1.1603
#
# Step 1277 — Test metrics:
#   precision@10: 0.005778146
#   recall@10: 0.005779985
#   ndcg@10: 0.006408380
#   map@10: 0.002086474
# Epoch 25, Step 40, LR: 0.000080, Current Loss: 0.7032, Avg Loss: 0.7143
# Diff stats — min: -5.5157, max: 5.0350, mean: 0.2827, std: 1.1501
#
# Step 1287 — Test metrics:
#   precision@10: 0.005910596
#   recall@10: 0.005912436
#   ndcg@10: 0.006519368
#   map@10: 0.002115986
# Epoch 25, Step 50, LR: 0.000080, Current Loss: 0.6913, Avg Loss: 0.7122
# Diff stats — min: -6.0247, max: 4.9473, mean: 0.2824, std: 1.0931
#
# Step 1297 — Test metrics:
#   precision@10: 0.005894040
#   recall@10: 0.005895879
#   ndcg@10: 0.006511127
#   map@10: 0.002118325
# Epoch 25 completed, Train Loss: 0.7114
# Epoch 26, Step 1, LR: 0.000080, Current Loss: 0.7152, Avg Loss: 0.7152
# Diff stats — min: -7.1361, max: 4.3586, mean: 0.2373, std: 1.1143
#
# Step 1300 — Test metrics:
#   precision@10: 0.005927152
#   recall@10: 0.005928992
#   ndcg@10: 0.006539546
#   map@10: 0.002124915
# Epoch 26, Step 10, LR: 0.000080, Current Loss: 0.6874, Avg Loss: 0.7029
# Diff stats — min: -4.3952, max: 6.8772, mean: 0.2741, std: 1.0583
#
# Step 1309 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006664897
#   map@10: 0.002158625
# Epoch 26, Step 20, LR: 0.000080, Current Loss: 0.6863, Avg Loss: 0.7029
# Diff stats — min: -5.1843, max: 5.3240, mean: 0.2852, std: 1.0767
#
# Step 1319 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.006588371
#   map@10: 0.002117431
# Epoch 26, Step 30, LR: 0.000080, Current Loss: 0.6789, Avg Loss: 0.7006
# Diff stats — min: -5.8731, max: 6.0667, mean: 0.2978, std: 1.0735
#
# Step 1329 — Test metrics:
#   precision@10: 0.006125828
#   recall@10: 0.006127667
#   ndcg@10: 0.006530567
#   map@10: 0.002060943
# Epoch 26, Step 40, LR: 0.000080, Current Loss: 0.6834, Avg Loss: 0.6996
# Diff stats — min: -4.3240, max: 5.1426, mean: 0.2720, std: 1.0353
#
# Step 1339 — Test metrics:
#   precision@10: 0.006109272
#   recall@10: 0.006111111
#   ndcg@10: 0.006509740
#   map@10: 0.002052750
# Epoch 26, Step 50, LR: 0.000080, Current Loss: 0.6945, Avg Loss: 0.6988
# Diff stats — min: -4.3059, max: 4.1917, mean: 0.2376, std: 1.0121
#
# Step 1349 — Test metrics:
#   precision@10: 0.006142384
#   recall@10: 0.006144224
#   ndcg@10: 0.006455686
#   map@10: 0.002011964
# Epoch 26 completed, Train Loss: 0.6985
# Epoch 27, Step 1, LR: 0.000080, Current Loss: 0.6902, Avg Loss: 0.6902
# Diff stats — min: -3.8855, max: 6.0976, mean: 0.2461, std: 1.0136
#
# Step 1352 — Test metrics:
#   precision@10: 0.006142384
#   recall@10: 0.006144224
#   ndcg@10: 0.006473481
#   map@10: 0.002022423
# Epoch 27, Step 10, LR: 0.000080, Current Loss: 0.6864, Avg Loss: 0.6961
# Diff stats — min: -4.7374, max: 4.7390, mean: 0.2476, std: 0.9974
#
# Step 1361 — Test metrics:
#   precision@10: 0.006125828
#   recall@10: 0.006127667
#   ndcg@10: 0.006504839
#   map@10: 0.002048329
# Epoch 27, Step 20, LR: 0.000080, Current Loss: 0.6923, Avg Loss: 0.6933
# Diff stats — min: -5.0963, max: 5.4930, mean: 0.2329, std: 0.9939
#
# Step 1371 — Test metrics:
#   precision@10: 0.006009934
#   recall@10: 0.006011773
#   ndcg@10: 0.006435816
#   map@10: 0.002041765
# Epoch 27, Step 30, LR: 0.000080, Current Loss: 0.6905, Avg Loss: 0.6927
# Diff stats — min: -5.7095, max: 4.9442, mean: 0.2265, std: 0.9710
#
# Step 1381 — Test metrics:
#   precision@10: 0.006125828
#   recall@10: 0.006127667
#   ndcg@10: 0.006533221
#   map@10: 0.002062625
# Epoch 27, Step 40, LR: 0.000080, Current Loss: 0.6968, Avg Loss: 0.6912
# Diff stats — min: -4.6059, max: 4.9614, mean: 0.2082, std: 0.9598
#
# Step 1391 — Test metrics:
#   precision@10: 0.006142384
#   recall@10: 0.006144224
#   ndcg@10: 0.006527898
#   map@10: 0.002060503
# Epoch 27, Step 50, LR: 0.000080, Current Loss: 0.6925, Avg Loss: 0.6906
# Diff stats — min: -4.5680, max: 5.9293, mean: 0.2218, std: 0.9746
#
# Step 1401 — Test metrics:
#   precision@10: 0.006109272
#   recall@10: 0.006111111
#   ndcg@10: 0.006512579
#   map@10: 0.002064188
# Epoch 27 completed, Train Loss: 0.6907
# Epoch 28, Step 1, LR: 0.000080, Current Loss: 0.6811, Avg Loss: 0.6811
# Diff stats — min: -4.8541, max: 3.9977, mean: 0.2395, std: 0.9510
#
# Step 1404 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006499681
#   map@10: 0.002069412
# Epoch 28, Step 10, LR: 0.000080, Current Loss: 0.6921, Avg Loss: 0.6856
# Diff stats — min: -5.7815, max: 5.6391, mean: 0.2210, std: 0.9712
#
# Step 1413 — Test metrics:
#   precision@10: 0.005910596
#   recall@10: 0.005912436
#   ndcg@10: 0.006366702
#   map@10: 0.002028520
# Epoch 28, Step 20, LR: 0.000080, Current Loss: 0.6828, Avg Loss: 0.6863
# Diff stats — min: -7.6225, max: 4.4984, mean: 0.2253, std: 0.9307
#
# Step 1423 — Test metrics:
#   precision@10: 0.005860927
#   recall@10: 0.005862767
#   ndcg@10: 0.006178044
#   map@10: 0.001928348
# Epoch 28, Step 30, LR: 0.000080, Current Loss: 0.6758, Avg Loss: 0.6854
# Diff stats — min: -5.1617, max: 5.6113, mean: 0.2469, std: 0.9430
#
# Step 1433 — Test metrics:
#   precision@10: 0.005993377
#   recall@10: 0.005995217
#   ndcg@10: 0.006213219
#   map@10: 0.001910609
# Epoch 28, Step 40, LR: 0.000080, Current Loss: 0.6692, Avg Loss: 0.6845
# Diff stats — min: -4.2046, max: 6.1670, mean: 0.2572, std: 0.9325
#
# Step 1443 — Test metrics:
#   precision@10: 0.005860927
#   recall@10: 0.005862767
#   ndcg@10: 0.006161557
#   map@10: 0.001920333
# Epoch 28, Step 50, LR: 0.000080, Current Loss: 0.6762, Avg Loss: 0.6834
# Diff stats — min: -3.3712, max: 4.4370, mean: 0.2468, std: 0.9419
#
# Step 1453 — Test metrics:
#   precision@10: 0.006059603
#   recall@10: 0.006061442
#   ndcg@10: 0.006364192
#   map@10: 0.001986078
# Epoch 28 completed, Train Loss: 0.6831
# Epoch 29, Step 1, LR: 0.000080, Current Loss: 0.6782, Avg Loss: 0.6782
# Diff stats — min: -4.3583, max: 7.9756, mean: 0.2317, std: 0.9253
#
# Step 1456 — Test metrics:
#   precision@10: 0.005943709
#   recall@10: 0.005945548
#   ndcg@10: 0.006302409
#   map@10: 0.001981591
# Epoch 29, Step 10, LR: 0.000080, Current Loss: 0.6765, Avg Loss: 0.6797
# Diff stats — min: -3.4908, max: 4.2009, mean: 0.2332, std: 0.9125
#
# Step 1465 — Test metrics:
#   precision@10: 0.006092715
#   recall@10: 0.006094555
#   ndcg@10: 0.006333925
#   map@10: 0.001958320
# Epoch 29, Step 20, LR: 0.000080, Current Loss: 0.6842, Avg Loss: 0.6809
# Diff stats — min: -4.5189, max: 4.5082, mean: 0.2153, std: 0.9143
#
# Step 1475 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.006274851
#   map@10: 0.001936219
# Epoch 29, Step 30, LR: 0.000080, Current Loss: 0.6762, Avg Loss: 0.6792
# Diff stats — min: -3.8421, max: 4.0235, mean: 0.2256, std: 0.8928
#
# Step 1485 — Test metrics:
#   precision@10: 0.005976821
#   recall@10: 0.005978661
#   ndcg@10: 0.006180653
#   map@10: 0.001896957
# Epoch 29, Step 40, LR: 0.000080, Current Loss: 0.6785, Avg Loss: 0.6788
# Diff stats — min: -7.8903, max: 7.1333, mean: 0.2235, std: 0.9092
#
# Step 1495 — Test metrics:
#   precision@10: 0.006258278
#   recall@10: 0.006260118
#   ndcg@10: 0.006470532
#   map@10: 0.001985756
# Epoch 29, Step 50, LR: 0.000080, Current Loss: 0.6759, Avg Loss: 0.6785
# Diff stats — min: -6.5658, max: 8.5451, mean: 0.2409, std: 0.9402
#
# Step 1505 — Test metrics:
#   precision@10: 0.006125828
#   recall@10: 0.006127667
#   ndcg@10: 0.006394725
#   map@10: 0.001977905
# Epoch 29 completed, Train Loss: 0.6781
# Epoch 30, Step 1, LR: 0.000080, Current Loss: 0.6670, Avg Loss: 0.6670
# Diff stats — min: -4.2395, max: 5.8814, mean: 0.2417, std: 0.8853
#
# Step 1508 — Test metrics:
#   precision@10: 0.006109272
#   recall@10: 0.006111111
#   ndcg@10: 0.006358392
#   map@10: 0.001962584
# Epoch 30, Step 10, LR: 0.000080, Current Loss: 0.6838, Avg Loss: 0.6716
# Diff stats — min: -4.9041, max: 6.9303, mean: 0.2191, std: 0.9219
#
# Step 1517 — Test metrics:
#   precision@10: 0.006109272
#   recall@10: 0.006111111
#   ndcg@10: 0.006243290
#   map@10: 0.001896050
# Epoch 30, Step 20, LR: 0.000080, Current Loss: 0.6675, Avg Loss: 0.6750
# Diff stats — min: -3.8727, max: 4.7747, mean: 0.2423, std: 0.8872
#
# Step 1527 — Test metrics:
#   precision@10: 0.006043046
#   recall@10: 0.006044886
#   ndcg@10: 0.006155565
#   map@10: 0.001864363
# Epoch 30, Step 30, LR: 0.000080, Current Loss: 0.6719, Avg Loss: 0.6745
# Diff stats — min: -3.8901, max: 4.6591, mean: 0.2238, std: 0.8649
#
# Step 1537 — Test metrics:
#   precision@10: 0.006241722
#   recall@10: 0.006243561
#   ndcg@10: 0.006325999
#   map@10: 0.001909611
# Epoch 30, Step 40, LR: 0.000080, Current Loss: 0.6695, Avg Loss: 0.6739
# Diff stats — min: -3.6026, max: 4.2796, mean: 0.2367, std: 0.8849
#
# ...
#   precision@10: 0.019668874
#   recall@10: 0.019670714
#   ndcg@10: 0.021015021
#   map@10: 0.006854075
# Epoch 85 completed, Train Loss: 0.4619
# Epoch 86, Step 1, LR: 0.000080, Current Loss: 0.4613, Avg Loss: 0.4613
# Diff stats — min: -4.3688, max: 5.8121, mean: 1.1657, std: 1.5047
#
# Step 4420 — Test metrics:
#   precision@10: 0.019801325
#   recall@10: 0.019803164
#   ndcg@10: 0.021116641
#   map@10: 0.006883160
# Epoch 86, Step 10, LR: 0.000080, Current Loss: 0.4489, Avg Loss: 0.4588
# Diff stats — min: -3.8763, max: 6.2014, mean: 1.2038, std: 1.4970
#
# Step 4429 — Test metrics:
#   precision@10: 0.019917219
#   recall@10: 0.019919058
#   ndcg@10: 0.021162780
#   map@10: 0.006883646
# Epoch 86, Step 20, LR: 0.000080, Current Loss: 0.4647, Avg Loss: 0.4585
# Diff stats — min: -4.7059, max: 5.8577, mean: 1.1748, std: 1.5280
#
# Step 4439 — Test metrics:
#   precision@10: 0.019619205
#   recall@10: 0.019621045
#   ndcg@10: 0.021055662
#   map@10: 0.006908428
# Epoch 86, Step 30, LR: 0.000080, Current Loss: 0.4553, Avg Loss: 0.4582
# Diff stats — min: -3.5255, max: 6.7392, mean: 1.2036, std: 1.5218
#
# Step 4449 — Test metrics:
#   precision@10: 0.019370861
#   recall@10: 0.019372701
#   ndcg@10: 0.020868659
#   map@10: 0.006860894
# Epoch 86, Step 40, LR: 0.000080, Current Loss: 0.4464, Avg Loss: 0.4580
# Diff stats — min: -4.2913, max: 6.3182, mean: 1.2032, std: 1.4854
#
# Step 4459 — Test metrics:
#   precision@10: 0.019304636
#   recall@10: 0.019306475
#   ndcg@10: 0.020863827
#   map@10: 0.006863588
# Epoch 86, Step 50, LR: 0.000080, Current Loss: 0.4626, Avg Loss: 0.4575
# Diff stats — min: -3.9600, max: 6.8094, mean: 1.1702, std: 1.5153
#
# Step 4469 — Test metrics:
#   precision@10: 0.019801325
#   recall@10: 0.019803164
#   ndcg@10: 0.021233852
#   map@10: 0.006951402
# Epoch 86 completed, Train Loss: 0.4575
# Epoch 87, Step 1, LR: 0.000080, Current Loss: 0.4653, Avg Loss: 0.4653
# Diff stats — min: -4.8381, max: 6.1242, mean: 1.1737, std: 1.5287
#
# Step 4472 — Test metrics:
#   precision@10: 0.019933775
#   recall@10: 0.019935614
#   ndcg@10: 0.021314466
#   map@10: 0.006968523
# Epoch 87, Step 10, LR: 0.000080, Current Loss: 0.4430, Avg Loss: 0.4549
# Diff stats — min: -4.3548, max: 5.9908, mean: 1.2303, std: 1.5048
#
# Step 4481 — Test metrics:
#   precision@10: 0.019867550
#   recall@10: 0.019869389
#   ndcg@10: 0.021268686
#   map@10: 0.006971749
# Epoch 87, Step 20, LR: 0.000080, Current Loss: 0.4519, Avg Loss: 0.4538
# Diff stats — min: -5.4368, max: 6.1182, mean: 1.2065, std: 1.5106
#
# Step 4491 — Test metrics:
#   precision@10: 0.020082781
#   recall@10: 0.020084621
#   ndcg@10: 0.021439115
#   map@10: 0.007027745
# Epoch 87, Step 30, LR: 0.000080, Current Loss: 0.4585, Avg Loss: 0.4557
# Diff stats — min: -3.8367, max: 6.2501, mean: 1.1967, std: 1.5327
#
# Step 4501 — Test metrics:
#   precision@10: 0.020198675
#   recall@10: 0.020200515
#   ndcg@10: 0.021486749
#   map@10: 0.007006806
# Epoch 87, Step 40, LR: 0.000080, Current Loss: 0.4379, Avg Loss: 0.4559
# Diff stats — min: -4.0394, max: 6.2380, mean: 1.2591, std: 1.5216
#
# Step 4511 — Test metrics:
#   precision@10: 0.019586093
#   recall@10: 0.019587932
#   ndcg@10: 0.021056816
#   map@10: 0.006903566
# Epoch 87, Step 50, LR: 0.000080, Current Loss: 0.4525, Avg Loss: 0.4544
# Diff stats — min: -4.7320, max: 6.9356, mean: 1.2224, std: 1.5368
#
# Step 4521 — Test metrics:
#   precision@10: 0.019701987
#   recall@10: 0.019703826
#   ndcg@10: 0.021205489
#   map@10: 0.006966868
# Epoch 87 completed, Train Loss: 0.4542
# Epoch 88, Step 1, LR: 0.000080, Current Loss: 0.4389, Avg Loss: 0.4389
# Diff stats — min: -4.5622, max: 5.6205, mean: 1.2554, std: 1.5131
#
# Step 4524 — Test metrics:
#   precision@10: 0.019718543
#   recall@10: 0.019720383
#   ndcg@10: 0.021162928
#   map@10: 0.006932855
# Epoch 88, Step 10, LR: 0.000080, Current Loss: 0.4487, Avg Loss: 0.4479
# Diff stats — min: -3.8820, max: 6.6264, mean: 1.2134, std: 1.5108
#
# Step 4533 — Test metrics:
#   precision@10: 0.020066225
#   recall@10: 0.020068065
#   ndcg@10: 0.021432546
#   map@10: 0.007016569
# Epoch 88, Step 20, LR: 0.000080, Current Loss: 0.4653, Avg Loss: 0.4513
# Diff stats — min: -4.1523, max: 6.4229, mean: 1.1881, std: 1.5532
#
# Step 4543 — Test metrics:
#   precision@10: 0.020281457
#   recall@10: 0.020283297
#   ndcg@10: 0.021607159
#   map@10: 0.007061416
# Epoch 88, Step 30, LR: 0.000080, Current Loss: 0.4501, Avg Loss: 0.4501
# Diff stats — min: -3.6218, max: 6.4089, mean: 1.2380, std: 1.5443
#
# Step 4553 — Test metrics:
#   precision@10: 0.020347682
#   recall@10: 0.020349522
#   ndcg@10: 0.021641249
#   map@10: 0.007071849
# Epoch 88, Step 40, LR: 0.000080, Current Loss: 0.4584, Avg Loss: 0.4505
# Diff stats — min: -4.4119, max: 6.5354, mean: 1.2257, std: 1.5621
#
# Step 4563 — Test metrics:
#   precision@10: 0.020513245
#   recall@10: 0.020515085
#   ndcg@10: 0.021755583
#   map@10: 0.007098234
# Epoch 88, Step 50, LR: 0.000080, Current Loss: 0.4539, Avg Loss: 0.4508
# Diff stats — min: -4.1515, max: 6.9750, mean: 1.2470, std: 1.5708
#
# Step 4573 — Test metrics:
#   precision@10: 0.020662252
#   recall@10: 0.020664091
#   ndcg@10: 0.021995819
#   map@10: 0.007201369
# Epoch 88 completed, Train Loss: 0.4508
# Epoch 89, Step 1, LR: 0.000080, Current Loss: 0.4474, Avg Loss: 0.4474
# Diff stats — min: -4.9770, max: 6.8967, mean: 1.2669, std: 1.5699
#
# Step 4576 — Test metrics:
#   precision@10: 0.020612583
#   recall@10: 0.020614422
#   ndcg@10: 0.021972496
#   map@10: 0.007209568
# Epoch 89, Step 10, LR: 0.000080, Current Loss: 0.4381, Avg Loss: 0.4463
# Diff stats — min: -4.2023, max: 6.4231, mean: 1.2592, std: 1.5208
#
# Step 4585 — Test metrics:
#   precision@10: 0.020629139
#   recall@10: 0.020630979
#   ndcg@10: 0.021992751
#   map@10: 0.007220593
# Epoch 89, Step 20, LR: 0.000080, Current Loss: 0.4416, Avg Loss: 0.4457
# Diff stats — min: -4.1959, max: 5.8772, mean: 1.2669, std: 1.5457
#
# Step 4595 — Test metrics:
#   precision@10: 0.020629139
#   recall@10: 0.020630979
#   ndcg@10: 0.022065654
#   map@10: 0.007259067
# Epoch 89, Step 30, LR: 0.000080, Current Loss: 0.4442, Avg Loss: 0.4470
# Diff stats — min: -4.1108, max: 6.9755, mean: 1.2551, std: 1.5420
#
# Step 4605 — Test metrics:
#   precision@10: 0.020993377
#   recall@10: 0.020995217
#   ndcg@10: 0.022335530
#   map@10: 0.007334095
# Epoch 89, Step 40, LR: 0.000080, Current Loss: 0.4427, Avg Loss: 0.4455
# Diff stats — min: -4.6703, max: 6.2857, mean: 1.2809, std: 1.5702
#
# Step 4615 — Test metrics:
#   precision@10: 0.021158940
#   recall@10: 0.021160780
#   ndcg@10: 0.022494906
#   map@10: 0.007375361
# Epoch 89, Step 50, LR: 0.000080, Current Loss: 0.4352, Avg Loss: 0.4444
# Diff stats — min: -4.1534, max: 7.9505, mean: 1.3089, std: 1.5658
#
# Step 4625 — Test metrics:
#   precision@10: 0.021109272
#   recall@10: 0.021111111
#   ndcg@10: 0.022336547
#   map@10: 0.007287501
# Epoch 89 completed, Train Loss: 0.4443
# Epoch 90, Step 1, LR: 0.000080, Current Loss: 0.4460, Avg Loss: 0.4460
# Diff stats — min: -3.6677, max: 6.0618, mean: 1.2635, std: 1.5613
#
# Step 4628 — Test metrics:
#   precision@10: 0.020976821
#   recall@10: 0.020978661
#   ndcg@10: 0.022281156
#   map@10: 0.007291975
# Epoch 90, Step 10, LR: 0.000080, Current Loss: 0.4336, Avg Loss: 0.4418
# Diff stats — min: -5.1363, max: 6.7426, mean: 1.3106, std: 1.5653
#
# Step 4637 — Test metrics:
#   precision@10: 0.021076159
#   recall@10: 0.021077999
#   ndcg@10: 0.022315065
#   map@10: 0.007294222
# Epoch 90, Step 20, LR: 0.000080, Current Loss: 0.4414, Avg Loss: 0.4415
# Diff stats — min: -4.8157, max: 6.8468, mean: 1.2976, std: 1.5844
#
# Step 4647 — Test metrics:
#   precision@10: 0.021274834
#   recall@10: 0.021276674
#   ndcg@10: 0.022421166
#   map@10: 0.007309392
# Epoch 90, Step 30, LR: 0.000080, Current Loss: 0.4565, Avg Loss: 0.4418
# Diff stats — min: -4.2693, max: 6.6157, mean: 1.2499, std: 1.5881
#
# Step 4657 — Test metrics:
#   precision@10: 0.020860927
#   recall@10: 0.020862767
#   ndcg@10: 0.022213668
#   map@10: 0.007276615
# Epoch 90, Step 40, LR: 0.000080, Current Loss: 0.4302, Avg Loss: 0.4413
# Diff stats — min: -4.2704, max: 5.7247, mean: 1.3319, std: 1.5669
#
# Step 4667 — Test metrics:
#   precision@10: 0.021142384
#   recall@10: 0.021144224
#   ndcg@10: 0.022445016
#   map@10: 0.007349627
# Epoch 90, Step 50, LR: 0.000080, Current Loss: 0.4505, Avg Loss: 0.4412
# Diff stats — min: -5.0378, max: 6.6173, mean: 1.2817, std: 1.6021
#
# Step 4677 — Test metrics:
#   precision@10: 0.021705298
#   recall@10: 0.021707138
#   ndcg@10: 0.022806455
#   map@10: 0.007424268
# Epoch 90 completed, Train Loss: 0.4409
# Epoch 91, Step 1, LR: 0.000080, Current Loss: 0.4185, Avg Loss: 0.4185
# Diff stats — min: -3.9196, max: 6.1412, mean: 1.3626, std: 1.5615
#
# Step 4680 — Test metrics:
#   precision@10: 0.021771523
#   recall@10: 0.021773363
#   ndcg@10: 0.022847194
#   map@10: 0.007435818
# Epoch 91, Step 10, LR: 0.000080, Current Loss: 0.4566, Avg Loss: 0.4394
# Diff stats — min: -4.6504, max: 7.8896, mean: 1.2645, std: 1.6068
#
# Step 4689 — Test metrics:
#   precision@10: 0.021655629
#   recall@10: 0.021657469
#   ndcg@10: 0.022843958
#   map@10: 0.007461185
# Epoch 91, Step 20, LR: 0.000080, Current Loss: 0.4432, Avg Loss: 0.4379
# Diff stats — min: -4.3803, max: 6.8979, mean: 1.2779, std: 1.5720
#
# Step 4699 — Test metrics:
#   precision@10: 0.021854305
#   recall@10: 0.021856144
#   ndcg@10: 0.023033647
#   map@10: 0.007514007
# Epoch 91, Step 30, LR: 0.000080, Current Loss: 0.4439, Avg Loss: 0.4377
# Diff stats — min: -4.1966, max: 6.2470, mean: 1.3076, std: 1.5960
#
# Step 4709 — Test metrics:
#   precision@10: 0.021854305
#   recall@10: 0.021856144
#   ndcg@10: 0.022996010
#   map@10: 0.007503857
# Epoch 91, Step 40, LR: 0.000080, Current Loss: 0.4331, Avg Loss: 0.4381
# Diff stats — min: -5.3436, max: 6.5364, mean: 1.3363, std: 1.5968
#
# Step 4719 — Test metrics:
#   precision@10: 0.021754967
#   recall@10: 0.021756806
#   ndcg@10: 0.023018472
#   map@10: 0.007546115
# Epoch 91, Step 50, LR: 0.000080, Current Loss: 0.4344, Avg Loss: 0.4369
# Diff stats — min: -4.5707, max: 7.1846, mean: 1.3506, std: 1.6157
#
# Step 4729 — Test metrics:
#   precision@10: 0.021804636
#   recall@10: 0.021806475
#   ndcg@10: 0.023027073
#   map@10: 0.007536969
# Epoch 91 completed, Train Loss: 0.4369
# Epoch 92, Step 1, LR: 0.000080, Current Loss: 0.4394, Avg Loss: 0.4394
# Diff stats — min: -4.0338, max: 7.1120, mean: 1.3303, std: 1.6061
#
# Step 4732 — Test metrics:
#   precision@10: 0.021589404
#   recall@10: 0.021591244
#   ndcg@10: 0.022852167
#   map@10: 0.007486486
# Epoch 92, Step 10, LR: 0.000080, Current Loss: 0.4296, Avg Loss: 0.4352
# Diff stats — min: -4.6160, max: 6.6233, mean: 1.3580, std: 1.5982
#
# Step 4741 — Test metrics:
#   precision@10: 0.021655629
#   recall@10: 0.021657469
#   ndcg@10: 0.022909997
#   map@10: 0.007503042
# Epoch 92, Step 20, LR: 0.000080, Current Loss: 0.4288, Avg Loss: 0.4345
# Diff stats — min: -5.1998, max: 6.6268, mean: 1.3424, std: 1.5939
#
# Step 4751 — Test metrics:
#   precision@10: 0.021705298
#   recall@10: 0.021707138
#   ndcg@10: 0.023010965
#   map@10: 0.007549452
# Epoch 92, Step 30, LR: 0.000080, Current Loss: 0.4245, Avg Loss: 0.4352
# Diff stats — min: -4.5918, max: 7.4777, mean: 1.4031, std: 1.6327
#
# Step 4761 — Test metrics:
#   precision@10: 0.022135762
#   recall@10: 0.022137601
#   ndcg@10: 0.023421661
#   map@10: 0.007686409
# Epoch 92, Step 40, LR: 0.000080, Current Loss: 0.4293, Avg Loss: 0.4353
# Diff stats — min: -4.1581, max: 6.0603, mean: 1.3876, std: 1.6277
#
# Step 4771 — Test metrics:
#   precision@10: 0.022566225
#   recall@10: 0.022568065
#   ndcg@10: 0.023695043
#   map@10: 0.007743036
# Epoch 92, Step 50, LR: 0.000080, Current Loss: 0.4216, Avg Loss: 0.4336
# Diff stats — min: -4.0124, max: 6.9167, mean: 1.3923, std: 1.6046
#
# Step 4781 — Test metrics:
#   precision@10: 0.022417219
#   recall@10: 0.022419058
#   ndcg@10: 0.023582490
#   map@10: 0.007703885
# Epoch 92 completed, Train Loss: 0.4333
# Epoch 93, Step 1, LR: 0.000080, Current Loss: 0.4313, Avg Loss: 0.4313
# Diff stats — min: -5.0116, max: 7.1232, mean: 1.3627, std: 1.6195
#
# Step 4784 — Test metrics:
#   precision@10: 0.022350993
#   recall@10: 0.022352833
#   ndcg@10: 0.023463917
#   map@10: 0.007654867
# Epoch 93, Step 10, LR: 0.000080, Current Loss: 0.4266, Avg Loss: 0.4297
# Diff stats — min: -5.4511, max: 6.5113, mean: 1.3941, std: 1.6388
#
# Step 4793 — Test metrics:
#   precision@10: 0.022168874
#   recall@10: 0.022170714
#   ndcg@10: 0.023399248
#   map@10: 0.007656398
# Epoch 93, Step 20, LR: 0.000080, Current Loss: 0.4241, Avg Loss: 0.4288
# Diff stats — min: -4.4254, max: 6.5018, mean: 1.3840, std: 1.6052
#
# Step 4803 — Test metrics:
#   precision@10: 0.022317881
#   recall@10: 0.022319720
#   ndcg@10: 0.023403275
#   map@10: 0.007623844
# Epoch 93, Step 30, LR: 0.000080, Current Loss: 0.4337, Avg Loss: 0.4293
# Diff stats — min: -4.1515, max: 7.0856, mean: 1.3769, std: 1.6445
#
# Step 4813 — Test metrics:
#   precision@10: 0.022417219
#   recall@10: 0.022419058
#   ndcg@10: 0.023533955
#   map@10: 0.007689747
# Epoch 93, Step 40, LR: 0.000080, Current Loss: 0.4077, Avg Loss: 0.4278
# Diff stats — min: -4.5745, max: 7.0199, mean: 1.4345, std: 1.6003
#
# Step 4823 — Test metrics:
#   precision@10: 0.022649007
#   recall@10: 0.022650846
#   ndcg@10: 0.023765150
#   map@10: 0.007777364
# Epoch 93, Step 50, LR: 0.000080, Current Loss: 0.4355, Avg Loss: 0.4281
# Diff stats — min: -4.3141, max: 7.3444, mean: 1.3607, std: 1.6376
#
# Step 4833 — Test metrics:
#   precision@10: 0.022533113
#   recall@10: 0.022534952
#   ndcg@10: 0.023784945
#   map@10: 0.007823400
# Epoch 93 completed, Train Loss: 0.4283
# Epoch 94, Step 1, LR: 0.000080, Current Loss: 0.4407, Avg Loss: 0.4407
# Diff stats — min: -4.0855, max: 7.5050, mean: 1.3554, std: 1.6427
#
# Step 4836 — Test metrics:
#   precision@10: 0.022682119
#   recall@10: 0.022683959
#   ndcg@10: 0.023875777
#   map@10: 0.007840817
# Epoch 94, Step 10, LR: 0.000080, Current Loss: 0.4299, Avg Loss: 0.4275
# Diff stats — min: -5.7436, max: 7.6646, mean: 1.3939, std: 1.6453
#
# Step 4845 — Test metrics:
#   precision@10: 0.022698675
#   recall@10: 0.022700515
#   ndcg@10: 0.023955251
#   map@10: 0.007895347
# Epoch 94, Step 20, LR: 0.000080, Current Loss: 0.4288, Avg Loss: 0.4272
# Diff stats — min: -4.9028, max: 7.3264, mean: 1.4098, std: 1.6622
#
# Step 4855 — Test metrics:
#   precision@10: 0.023046358
#   recall@10: 0.023048197
#   ndcg@10: 0.024234670
#   map@10: 0.007951717
# Epoch 94, Step 30, LR: 0.000080, Current Loss: 0.4189, Avg Loss: 0.4256
# Diff stats — min: -4.7829, max: 7.2360, mean: 1.4207, std: 1.6335
#
# Step 4865 — Test metrics:
#   precision@10: 0.023112583
#   recall@10: 0.023114422
#   ndcg@10: 0.024293502
#   map@10: 0.007962939
# Epoch 94, Step 40, LR: 0.000080, Current Loss: 0.4181, Avg Loss: 0.4251
# Diff stats — min: -3.9156, max: 7.1336, mean: 1.4209, std: 1.6337
#
# Step 4875 — Test metrics:
#   precision@10: 0.023377483
#   recall@10: 0.023379323
#   ndcg@10: 0.024486025
#   map@10: 0.008021300
# Epoch 94, Step 50, LR: 0.000080, Current Loss: 0.4080, Avg Loss: 0.4254
# Diff stats — min: -5.0942, max: 6.7840, mean: 1.4782, std: 1.6485
#
# Step 4885 — Test metrics:
#   precision@10: 0.023377483
#   recall@10: 0.023379323
#   ndcg@10: 0.024370144
#   map@10: 0.007942533
# Epoch 94 completed, Train Loss: 0.4255
# Epoch 95, Step 1, LR: 0.000080, Current Loss: 0.4183, Avg Loss: 0.4183
# Diff stats — min: -4.0938, max: 6.5861, mean: 1.4392, std: 1.6496
#
# Step 4888 — Test metrics:
#   precision@10: 0.023211921
#   recall@10: 0.023213760
#   ndcg@10: 0.024224886
#   map@10: 0.007891024
# Epoch 95, Step 10, LR: 0.000080, Current Loss: 0.4131, Avg Loss: 0.4195
# Diff stats — min: -6.9805, max: 7.2198, mean: 1.4635, std: 1.6636
#
# Step 4897 — Test metrics:
#   precision@10: 0.023261589
#   recall@10: 0.023263429
#   ndcg@10: 0.024207043
#   map@10: 0.007867766
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_35/1632553529.py in <cell line: 0>()
#       7 top_k = hyperparameters['test_topk']
#       8 test_batch_size = hyperparameters['test_batch_size']
# ----> 9 model = train_model(model,
#      10                     data,
#      11                     edge_type=edge_type,
#
# /tmp/ipykernel_35/631116414.py in train_model(model, train_data, edge_type, num_epochs, lr, batch_size, device, print_every, test_every, top_k, test_batch_size)
#      55
#      56             del user_embs, pos_emb, neg_emb, pos_score, neg_score
# ---> 57             gc.collect()
#      58             torch.cuda.empty_cache()
#      59
#
# KeyboardInterrupt:

# %%
model = train_model(model,
                    data,
                    edge_type=edge_type,
                    num_epochs=num_epochs,
                    lr=lr,
                    batch_size=batch_size,
                    print_every=print_every,
                    test_every=test_every,
                    top_k=top_k,
                    test_batch_size=test_batch_size)
# Out:
# Num of training examples: 211802
# Epoch 1, Step 1, LR: 0.000080, Current Loss: 0.4331, Avg Loss: 0.4331
# Diff stats — min: -5.4665, max: 7.1258, mean: 1.3849, std: 1.6552
#
# Step 0 — Test metrics:
#   precision@10: 0.023377483
#   recall@10: 0.023379323
#   ndcg@10: 0.024330058
#   map@10: 0.007909873
# Epoch 1, Step 10, LR: 0.000080, Current Loss: 0.4191, Avg Loss: 0.4189
# Diff stats — min: -4.3928, max: 7.4443, mean: 1.4475, std: 1.6609
#
# Step 9 — Test metrics:
#   precision@10: 0.023476821
#   recall@10: 0.023478661
#   ndcg@10: 0.024375896
#   map@10: 0.007915018
# Epoch 1, Step 20, LR: 0.000080, Current Loss: 0.4127, Avg Loss: 0.4187
# Diff stats — min: -4.3412, max: 7.4131, mean: 1.4724, std: 1.6670
#
# Step 19 — Test metrics:
#   precision@10: 0.023625828
#   recall@10: 0.023629507
#   ndcg@10: 0.024537407
#   map@10: 0.007985986
# Epoch 1, Step 30, LR: 0.000080, Current Loss: 0.4165, Avg Loss: 0.4190
# Diff stats — min: -4.7664, max: 7.5080, mean: 1.4725, std: 1.6879
#
# Step 29 — Test metrics:
#   precision@10: 0.023774834
#   recall@10: 0.023778514
#   ndcg@10: 0.024715411
#   map@10: 0.008059379
# Epoch 1, Step 40, LR: 0.000080, Current Loss: 0.4349, Avg Loss: 0.4194
# Diff stats — min: -4.0924, max: 6.9811, mean: 1.3984, std: 1.6718
#
# Step 39 — Test metrics:
#   precision@10: 0.023741722
#   recall@10: 0.023743561
#   ndcg@10: 0.024669172
#   map@10: 0.008033592
# Epoch 1, Step 50, LR: 0.000080, Current Loss: 0.4160, Avg Loss: 0.4191
# Diff stats — min: -4.6659, max: 7.6664, mean: 1.4718, std: 1.6766
#
# Step 49 — Test metrics:
#   precision@10: 0.023592715
#   recall@10: 0.023594555
#   ndcg@10: 0.024683183
#   map@10: 0.008076908
# Epoch 1 completed, Train Loss: 0.4192
# Epoch 2, Step 1, LR: 0.000080, Current Loss: 0.4099, Avg Loss: 0.4099
# Diff stats — min: -5.0304, max: 7.0618, mean: 1.4855, std: 1.6730
#
# Step 52 — Test metrics:
#   precision@10: 0.023576159
#   recall@10: 0.023577999
#   ndcg@10: 0.024675238
#   map@10: 0.008083826
# Epoch 2, Step 10, LR: 0.000080, Current Loss: 0.4362, Avg Loss: 0.4163
# Diff stats — min: -4.3226, max: 7.1058, mean: 1.4209, std: 1.7020
#
# Step 61 — Test metrics:
#   precision@10: 0.023841060
#   recall@10: 0.023842899
#   ndcg@10: 0.024943919
#   map@10: 0.008182283
# Epoch 2, Step 20, LR: 0.000080, Current Loss: 0.4225, Avg Loss: 0.4160
# Diff stats — min: -4.6634, max: 8.5192, mean: 1.4660, std: 1.7019
#
# Step 71 — Test metrics:
#   precision@10: 0.024089404
#   recall@10: 0.024093083
#   ndcg@10: 0.024969357
#   map@10: 0.008114481
# Epoch 2, Step 30, LR: 0.000080, Current Loss: 0.4009, Avg Loss: 0.4136
# Diff stats — min: -4.0070, max: 7.3318, mean: 1.5148, std: 1.6657
#
# Step 81 — Test metrics:
#   precision@10: 0.024288079
#   recall@10: 0.024291759
#   ndcg@10: 0.025158119
#   map@10: 0.008175707
# Epoch 2, Step 40, LR: 0.000080, Current Loss: 0.4129, Avg Loss: 0.4146
# Diff stats — min: -5.3383, max: 6.8510, mean: 1.5245, std: 1.7182
#
# Step 91 — Test metrics:
#   precision@10: 0.024321192
#   recall@10: 0.024323032
#   ndcg@10: 0.025304090
#   map@10: 0.008264047
# Epoch 2, Step 50, LR: 0.000080, Current Loss: 0.4179, Avg Loss: 0.4146
# Diff stats — min: -4.3302, max: 7.3760, mean: 1.4698, std: 1.6919
#
# Step 101 — Test metrics:
#   precision@10: 0.024188742
#   recall@10: 0.024190581
#   ndcg@10: 0.025322240
#   map@10: 0.008303821
# Epoch 2 completed, Train Loss: 0.4147
# Epoch 3, Step 1, LR: 0.000080, Current Loss: 0.4149, Avg Loss: 0.4149
# Diff stats — min: -4.5307, max: 8.0282, mean: 1.5103, std: 1.7142
#
# Step 104 — Test metrics:
#   precision@10: 0.024155629
#   recall@10: 0.024157469
#   ndcg@10: 0.025298631
#   map@10: 0.008297612
# Epoch 3, Step 10, LR: 0.000080, Current Loss: 0.4093, Avg Loss: 0.4134
# Diff stats — min: -4.5176, max: 7.0724, mean: 1.5396, std: 1.7294
#
# Step 113 — Test metrics:
#   precision@10: 0.024321192
#   recall@10: 0.024324871
#   ndcg@10: 0.025269258
#   map@10: 0.008237504
# Epoch 3, Step 20, LR: 0.000080, Current Loss: 0.4059, Avg Loss: 0.4110
# Diff stats — min: -4.1091, max: 7.1829, mean: 1.5426, std: 1.7157
#
# Step 123 — Test metrics:
#   precision@10: 0.024536424
#   recall@10: 0.024540103
#   ndcg@10: 0.025463758
#   map@10: 0.008313361
# Epoch 3, Step 30, LR: 0.000080, Current Loss: 0.4069, Avg Loss: 0.4124
# Diff stats — min: -5.0251, max: 6.9341, mean: 1.5512, std: 1.7285
#
# Step 133 — Test metrics:
#   precision@10: 0.024288079
#   recall@10: 0.024289919
#   ndcg@10: 0.025402174
#   map@10: 0.008336842
# Epoch 3, Step 40, LR: 0.000080, Current Loss: 0.4174, Avg Loss: 0.4118
# Diff stats — min: -4.0828, max: 7.0118, mean: 1.4933, std: 1.7087
#
# Step 143 — Test metrics:
#   precision@10: 0.024420530
#   recall@10: 0.024424209
#   ndcg@10: 0.025528760
#   map@10: 0.008386530
# Epoch 3, Step 50, LR: 0.000080, Current Loss: 0.4120, Avg Loss: 0.4113
# Diff stats — min: -5.5001, max: 8.5883, mean: 1.5242, std: 1.7197
#
# Step 153 — Test metrics:
#   precision@10: 0.024586093
#   recall@10: 0.024589772
#   ndcg@10: 0.025531734
#   map@10: 0.008350198
# Epoch 3 completed, Train Loss: 0.4116
# Epoch 4, Step 1, LR: 0.000080, Current Loss: 0.4097, Avg Loss: 0.4097
# Diff stats — min: -5.9203, max: 7.5870, mean: 1.5142, std: 1.7024
#
# Step 156 — Test metrics:
#   precision@10: 0.024536424
#   recall@10: 0.024540103
#   ndcg@10: 0.025519526
#   map@10: 0.008348017
# Epoch 4, Step 10, LR: 0.000080, Current Loss: 0.4036, Avg Loss: 0.4048
# Diff stats — min: -5.1802, max: 7.8488, mean: 1.5302, std: 1.6854
#
# Step 165 — Test metrics:
#   precision@10: 0.024453642
#   recall@10: 0.024457322
#   ndcg@10: 0.025523497
#   map@10: 0.008371078
# Epoch 4, Step 20, LR: 0.000080, Current Loss: 0.4016, Avg Loss: 0.4057
# Diff stats — min: -4.1288, max: 7.8827, mean: 1.5753, std: 1.7297
#
# Step 175 — Test metrics:
#   precision@10: 0.024552980
#   recall@10: 0.024556659
#   ndcg@10: 0.025740336
#   map@10: 0.008469745
# Epoch 4, Step 30, LR: 0.000080, Current Loss: 0.4029, Avg Loss: 0.4057
# Diff stats — min: -4.6421, max: 7.3717, mean: 1.5587, std: 1.7198
#
# Step 185 — Test metrics:
#   precision@10: 0.024966887
#   recall@10: 0.024970567
#   ndcg@10: 0.026037629
#   map@10: 0.008547573
# Epoch 4, Step 40, LR: 0.000080, Current Loss: 0.4048, Avg Loss: 0.4061
# Diff stats — min: -4.5709, max: 7.2274, mean: 1.5608, std: 1.7352
#
# Step 195 — Test metrics:
#   precision@10: 0.025215232
#   recall@10: 0.025218911
#   ndcg@10: 0.026176738
#   map@10: 0.008558795
# Epoch 4, Step 50, LR: 0.000080, Current Loss: 0.4091, Avg Loss: 0.4066
# Diff stats — min: -4.5859, max: 7.7411, mean: 1.5687, std: 1.7568
#
# Step 205 — Test metrics:
#   precision@10: 0.025066225
#   recall@10: 0.025069904
#   ndcg@10: 0.025898977
#   map@10: 0.008448859
# Epoch 4 completed, Train Loss: 0.4068
# Epoch 5, Step 1, LR: 0.000080, Current Loss: 0.4165, Avg Loss: 0.4165
# Diff stats — min: -5.3178, max: 7.6323, mean: 1.5385, std: 1.7542
#
# Step 208 — Test metrics:
#   precision@10: 0.025231788
#   recall@10: 0.025235467
#   ndcg@10: 0.026070136
#   map@10: 0.008506990
# Epoch 5, Step 10, LR: 0.000080, Current Loss: 0.3985, Avg Loss: 0.4025
# Diff stats — min: -4.5225, max: 7.3000, mean: 1.5615, std: 1.7088
#
# Step 217 — Test metrics:
#   precision@10: 0.025264901
#   recall@10: 0.025268580
#   ndcg@10: 0.026141682
#   map@10: 0.008540090
# Epoch 5, Step 20, LR: 0.000080, Current Loss: 0.4146, Avg Loss: 0.4042
# Diff stats — min: -4.6911, max: 6.7012, mean: 1.5268, std: 1.7239
#
# Step 227 — Test metrics:
#   precision@10: 0.025364238
#   recall@10: 0.025367918
#   ndcg@10: 0.026285782
#   map@10: 0.008589936
# Epoch 5, Step 30, LR: 0.000080, Current Loss: 0.4166, Avg Loss: 0.4039
# Diff stats — min: -5.1803, max: 6.8807, mean: 1.5140, std: 1.7213
#
# Step 237 — Test metrics:
#   precision@10: 0.025198675
#   recall@10: 0.025202355
#   ndcg@10: 0.026202487
#   map@10: 0.008599798
# Epoch 5, Step 40, LR: 0.000080, Current Loss: 0.3927, Avg Loss: 0.4026
# Diff stats — min: -5.3545, max: 8.1599, mean: 1.6103, std: 1.7321
#
# Step 247 — Test metrics:
#   precision@10: 0.025347682
#   recall@10: 0.025351361
#   ndcg@10: 0.026304111
#   map@10: 0.008621249
# Epoch 5, Step 50, LR: 0.000080, Current Loss: 0.4182, Avg Loss: 0.4026
# Diff stats — min: -4.2655, max: 8.9940, mean: 1.5321, std: 1.7577
#
# Step 257 — Test metrics:
#   precision@10: 0.025480132
#   recall@10: 0.025483812
#   ndcg@10: 0.026460415
#   map@10: 0.008686469
# Epoch 5 completed, Train Loss: 0.4030
# Epoch 6, Step 1, LR: 0.000080, Current Loss: 0.3933, Avg Loss: 0.3933
# Diff stats — min: -5.7826, max: 7.4427, mean: 1.6154, std: 1.7518
#
# Step 260 — Test metrics:
#   precision@10: 0.025380795
#   recall@10: 0.025384474
#   ndcg@10: 0.026436921
#   map@10: 0.008693328
# Epoch 6, Step 10, LR: 0.000080, Current Loss: 0.3941, Avg Loss: 0.3959
# Diff stats — min: -4.3531, max: 8.0278, mean: 1.6153, std: 1.7432
#
# Step 269 — Test metrics:
#   precision@10: 0.025529801
#   recall@10: 0.025533481
#   ndcg@10: 0.026591716
#   map@10: 0.008755085
# Epoch 6, Step 20, LR: 0.000080, Current Loss: 0.4057, Avg Loss: 0.3988
# Diff stats — min: -4.9000, max: 8.2429, mean: 1.5878, std: 1.7724
#
# Step 279 — Test metrics:
#   precision@10: 0.025877483
#   recall@10: 0.025881163
#   ndcg@10: 0.026821919
#   map@10: 0.008796884
# Epoch 6, Step 30, LR: 0.000080, Current Loss: 0.3891, Avg Loss: 0.3995
# Diff stats — min: -5.0593, max: 7.8590, mean: 1.6296, std: 1.7339
#
# Step 289 — Test metrics:
#   precision@10: 0.026092715
#   recall@10: 0.026096394
#   ndcg@10: 0.026923741
#   map@10: 0.008812330
# Epoch 6, Step 40, LR: 0.000080, Current Loss: 0.3985, Avg Loss: 0.3992
# Diff stats — min: -5.0028, max: 7.7603, mean: 1.6122, std: 1.7514
#
# Step 299 — Test metrics:
#   precision@10: 0.026125828
#   recall@10: 0.026129507
#   ndcg@10: 0.026825927
#   map@10: 0.008741978
# Epoch 6, Step 50, LR: 0.000080, Current Loss: 0.3926, Avg Loss: 0.3987
# Diff stats — min: -4.9129, max: 7.6885, mean: 1.6407, std: 1.7658
#
# Step 309 — Test metrics:
#   precision@10: 0.025976821
#   recall@10: 0.025980500
#   ndcg@10: 0.026757148
#   map@10: 0.008749462
# Epoch 6 completed, Train Loss: 0.3989
# Epoch 7, Step 1, LR: 0.000080, Current Loss: 0.4044, Avg Loss: 0.4044
# Diff stats — min: -4.6298, max: 7.1101, mean: 1.5796, std: 1.7450
#
# Step 312 — Test metrics:
#   precision@10: 0.026076159
#   recall@10: 0.026079838
#   ndcg@10: 0.026852626
#   map@10: 0.008791766
# Epoch 7, Step 10, LR: 0.000080, Current Loss: 0.3846, Avg Loss: 0.3951
# Diff stats — min: -4.2629, max: 6.8991, mean: 1.6389, std: 1.7320
#
# Step 321 — Test metrics:
#   precision@10: 0.025645695
#   recall@10: 0.025649375
#   ndcg@10: 0.026646282
#   map@10: 0.008765473
# Epoch 7, Step 20, LR: 0.000080, Current Loss: 0.3994, Avg Loss: 0.3945
# Diff stats — min: -4.4545, max: 6.9225, mean: 1.5913, std: 1.7402
#
# Step 331 — Test metrics:
#   precision@10: 0.025695364
#   recall@10: 0.025699043
#   ndcg@10: 0.026722400
#   map@10: 0.008792200
# Epoch 7, Step 30, LR: 0.000080, Current Loss: 0.3901, Avg Loss: 0.3957
# Diff stats — min: -4.7134, max: 7.6485, mean: 1.6334, std: 1.7486
#
# Step 341 — Test metrics:
#   precision@10: 0.026241722
#   recall@10: 0.026245401
#   ndcg@10: 0.027048234
#   map@10: 0.008869633
# Epoch 7, Step 40, LR: 0.000080, Current Loss: 0.3870, Avg Loss: 0.3954
# Diff stats — min: -4.4450, max: 8.2570, mean: 1.6493, std: 1.7503
#
# Step 351 — Test metrics:
#   precision@10: 0.026208609
#   recall@10: 0.026212288
#   ndcg@10: 0.027063200
#   map@10: 0.008887312
# Epoch 7, Step 50, LR: 0.000080, Current Loss: 0.4066, Avg Loss: 0.3956
# Diff stats — min: -4.7559, max: 7.2440, mean: 1.6000, std: 1.7821
#
# Step 361 — Test metrics:
#   precision@10: 0.026456954
#   recall@10: 0.026460633
#   ndcg@10: 0.027284156
#   map@10: 0.008950541
# Epoch 7 completed, Train Loss: 0.3953
# Epoch 8, Step 1, LR: 0.000080, Current Loss: 0.3995, Avg Loss: 0.3995
# Diff stats — min: -4.9290, max: 7.4709, mean: 1.6137, std: 1.7724
#
# Step 364 — Test metrics:
#   precision@10: 0.026407285
#   recall@10: 0.026410964
#   ndcg@10: 0.027297055
#   map@10: 0.008962663
# Epoch 8, Step 10, LR: 0.000080, Current Loss: 0.4015, Avg Loss: 0.3951
# Diff stats — min: -5.8517, max: 7.1167, mean: 1.6148, std: 1.7787
#
# Step 373 — Test metrics:
#   precision@10: 0.026456954
#   recall@10: 0.026460633
#   ndcg@10: 0.027351236
#   map@10: 0.008988195
# Epoch 8, Step 20, LR: 0.000080, Current Loss: 0.3981, Avg Loss: 0.3935
# Diff stats — min: -5.4002, max: 7.0542, mean: 1.6470, std: 1.7902
#
# Step 383 — Test metrics:
#   precision@10: 0.026506623
#   recall@10: 0.026510302
#   ndcg@10: 0.027376637
#   map@10: 0.008990133
# Epoch 8, Step 30, LR: 0.000080, Current Loss: 0.3954, Avg Loss: 0.3933
# Diff stats — min: -4.9004, max: 7.3237, mean: 1.6298, std: 1.7671
#
# Step 393 — Test metrics:
#   precision@10: 0.026655629
#   recall@10: 0.026659308
#   ndcg@10: 0.027544661
#   map@10: 0.009049636
# Epoch 8, Step 40, LR: 0.000080, Current Loss: 0.4056, Avg Loss: 0.3941
# Diff stats — min: -5.4201, max: 7.3368, mean: 1.6128, std: 1.7830
#
# Step 403 — Test metrics:
#   precision@10: 0.026473510
#   recall@10: 0.026477189
#   ndcg@10: 0.027362390
#   map@10: 0.008990717
# Epoch 8, Step 50, LR: 0.000080, Current Loss: 0.4066, Avg Loss: 0.3946
# Diff stats — min: -6.2124, max: 6.8716, mean: 1.6005, std: 1.7797
#
# Step 413 — Test metrics:
#   precision@10: 0.026440397
#   recall@10: 0.026444077
#   ndcg@10: 0.027285142
#   map@10: 0.008967492
# Epoch 8 completed, Train Loss: 0.3945
# Epoch 9, Step 1, LR: 0.000080, Current Loss: 0.3965, Avg Loss: 0.3965
# Diff stats — min: -5.2411, max: 7.8399, mean: 1.6453, std: 1.7880
#
# Step 416 — Test metrics:
#   precision@10: 0.026241722
#   recall@10: 0.026245401
#   ndcg@10: 0.027186718
#   map@10: 0.008952269
# Epoch 9, Step 10, LR: 0.000080, Current Loss: 0.4082, Avg Loss: 0.3921
# Diff stats — min: -4.9588, max: 7.7950, mean: 1.6028, std: 1.7918
#
# Step 425 — Test metrics:
#   precision@10: 0.026572848
#   recall@10: 0.026576527
#   ndcg@10: 0.027379843
#   map@10: 0.008970041
# Epoch 9, Step 20, LR: 0.000080, Current Loss: 0.3910, Avg Loss: 0.3921
# Diff stats — min: -5.4344, max: 8.1495, mean: 1.6665, std: 1.7908
#
# Step 435 — Test metrics:
#   precision@10: 0.026986755
#   recall@10: 0.026990434
#   ndcg@10: 0.027730319
#   map@10: 0.009094605
# Epoch 9, Step 30, LR: 0.000080, Current Loss: 0.4041, Avg Loss: 0.3933
# Diff stats — min: -5.0285, max: 7.2739, mean: 1.6464, std: 1.8138
#
# Step 445 — Test metrics:
#   precision@10: 0.027350993
#   recall@10: 0.027354673
#   ndcg@10: 0.028067232
#   map@10: 0.009180411
# Epoch 9, Step 40, LR: 0.000080, Current Loss: 0.3823, Avg Loss: 0.3912
# Diff stats — min: -5.1488, max: 7.4728, mean: 1.6825, std: 1.7592
#
# Step 455 — Test metrics:
#   precision@10: 0.027086093
#   recall@10: 0.027089772
#   ndcg@10: 0.027929220
#   map@10: 0.009180069
# Epoch 9, Step 50, LR: 0.000080, Current Loss: 0.3830, Avg Loss: 0.3898
# Diff stats — min: -4.7363, max: 8.1840, mean: 1.6678, std: 1.7587
#
# Step 465 — Test metrics:
#   precision@10: 0.026920530
#   recall@10: 0.026924209
#   ndcg@10: 0.027717891
#   map@10: 0.009077085
# Epoch 9 completed, Train Loss: 0.3896
# Epoch 10, Step 1, LR: 0.000080, Current Loss: 0.3857, Avg Loss: 0.3857
# Diff stats — min: -5.2571, max: 7.9777, mean: 1.6751, std: 1.7712
#
# Step 468 — Test metrics:
#   precision@10: 0.026986755
#   recall@10: 0.026990434
#   ndcg@10: 0.027809935
#   map@10: 0.009120302
# Epoch 10, Step 10, LR: 0.000080, Current Loss: 0.3809, Avg Loss: 0.3883
# Diff stats — min: -4.5164, max: 7.4313, mean: 1.7077, std: 1.7870
#
# Step 477 — Test metrics:
#   precision@10: 0.027301325
#   recall@10: 0.027305004
#   ndcg@10: 0.028053714
#   map@10: 0.009198524
# Epoch 10, Step 20, LR: 0.000080, Current Loss: 0.3908, Avg Loss: 0.3870
# Diff stats — min: -5.3635, max: 8.7334, mean: 1.6812, std: 1.8055
#
# Step 487 — Test metrics:
#   precision@10: 0.027317881
#   recall@10: 0.027321560
#   ndcg@10: 0.028051481
#   map@10: 0.009209082
# Epoch 10, Step 30, LR: 0.000080, Current Loss: 0.3851, Avg Loss: 0.3863
# Diff stats — min: -4.8000, max: 7.2794, mean: 1.6942, std: 1.7940
#
# Step 497 — Test metrics:
#   precision@10: 0.027350993
#   recall@10: 0.027354673
#   ndcg@10: 0.028008404
#   map@10: 0.009189399
# Epoch 10, Step 40, LR: 0.000080, Current Loss: 0.3818, Avg Loss: 0.3868
# Diff stats — min: -5.8942, max: 8.3229, mean: 1.7183, std: 1.7984
#
# Step 507 — Test metrics:
#   precision@10: 0.027235099
#   recall@10: 0.027238779
#   ndcg@10: 0.028072618
#   map@10: 0.009277955
# Epoch 10, Step 50, LR: 0.000080, Current Loss: 0.3862, Avg Loss: 0.3866
# Diff stats — min: -4.3331, max: 7.0904, mean: 1.6970, std: 1.8022
#
# Step 517 — Test metrics:
#   precision@10: 0.027284768
#   recall@10: 0.027288447
#   ndcg@10: 0.028124712
#   map@10: 0.009297934
# Epoch 10 completed, Train Loss: 0.3863
# Epoch 11, Step 1, LR: 0.000080, Current Loss: 0.3715, Avg Loss: 0.3715
# Diff stats — min: -5.0158, max: 7.4255, mean: 1.7512, std: 1.7939
#
# Step 520 — Test metrics:
#   precision@10: 0.027367550
#   recall@10: 0.027371229
#   ndcg@10: 0.028207520
#   map@10: 0.009324549
# Epoch 11, Step 10, LR: 0.000080, Current Loss: 0.3909, Avg Loss: 0.3876
# Diff stats — min: -4.7308, max: 8.3147, mean: 1.6954, std: 1.8227
#
# Step 529 — Test metrics:
#   precision@10: 0.027500000
#   recall@10: 0.027503679
#   ndcg@10: 0.028315633
#   map@10: 0.009339792
# Epoch 11, Step 20, LR: 0.000080, Current Loss: 0.3754, Avg Loss: 0.3854
# Diff stats — min: -5.0631, max: 7.8261, mean: 1.7474, std: 1.7966
#
# Step 539 — Test metrics:
#   precision@10: 0.027433775
#   recall@10: 0.027437454
#   ndcg@10: 0.028218775
#   map@10: 0.009297074
# Epoch 11, Step 30, LR: 0.000080, Current Loss: 0.3758, Avg Loss: 0.3843
# Diff stats — min: -5.9864, max: 7.6648, mean: 1.7194, std: 1.7805
#
# Step 549 — Test metrics:
#   precision@10: 0.027483444
#   recall@10: 0.027487123
#   ndcg@10: 0.028359901
#   map@10: 0.009353069
# Epoch 11, Step 40, LR: 0.000080, Current Loss: 0.3925, Avg Loss: 0.3843
# Diff stats — min: -5.7634, max: 7.5855, mean: 1.7196, std: 1.8326
#
# Step 559 — Test metrics:
#   precision@10: 0.027814570
#   recall@10: 0.027818249
#   ndcg@10: 0.028620613
#   map@10: 0.009444674
# Epoch 11, Step 50, LR: 0.000080, Current Loss: 0.3780, Avg Loss: 0.3837
# Diff stats — min: -4.5177, max: 7.8119, mean: 1.7217, std: 1.7865
#
# Step 569 — Test metrics:
#   precision@10: 0.028211921
#   recall@10: 0.028215600
#   ndcg@10: 0.028897098
#   map@10: 0.009516675
# Epoch 11 completed, Train Loss: 0.3838
# Epoch 12, Step 1, LR: 0.000080, Current Loss: 0.3771, Avg Loss: 0.3771
# Diff stats — min: -4.8320, max: 8.3590, mean: 1.7591, std: 1.8303
#
# Step 572 — Test metrics:
#   precision@10: 0.028311258
#   recall@10: 0.028314937
#   ndcg@10: 0.029013820
#   map@10: 0.009579490
# Epoch 12, Step 10, LR: 0.000080, Current Loss: 0.4015, Avg Loss: 0.3795
# Diff stats — min: -4.5079, max: 8.6156, mean: 1.6708, std: 1.8337
#
# Step 581 — Test metrics:
#   precision@10: 0.028394040
#   recall@10: 0.028397719
#   ndcg@10: 0.029002817
#   map@10: 0.009552684
# Epoch 12, Step 20, LR: 0.000080, Current Loss: 0.3813, Avg Loss: 0.3806
# Diff stats — min: -4.8488, max: 8.0724, mean: 1.7239, std: 1.8073
#
# Step 591 — Test metrics:
#   precision@10: 0.028129139
#   recall@10: 0.028132818
#   ndcg@10: 0.028895975
#   map@10: 0.009549143
# Epoch 12, Step 30, LR: 0.000080, Current Loss: 0.3900, Avg Loss: 0.3820
# Diff stats — min: -5.6497, max: 7.9117, mean: 1.7388, std: 1.8484
#
# Step 601 — Test metrics:
#   precision@10: 0.027996689
#   recall@10: 0.028000368
#   ndcg@10: 0.028739460
#   map@10: 0.009475212
# Epoch 12, Step 40, LR: 0.000080, Current Loss: 0.3779, Avg Loss: 0.3812
# Diff stats — min: -5.3604, max: 7.8159, mean: 1.7484, std: 1.8111
#
# Step 611 — Test metrics:
#   precision@10: 0.027980132
#   recall@10: 0.027983812
#   ndcg@10: 0.028714679
#   map@10: 0.009468642
# Epoch 12, Step 50, LR: 0.000080, Current Loss: 0.3985, Avg Loss: 0.3817
# Diff stats — min: -4.7094, max: 8.3898, mean: 1.6752, std: 1.8298
#
# Step 621 — Test metrics:
#   precision@10: 0.027930464
#   recall@10: 0.027934143
#   ndcg@10: 0.028711019
#   map@10: 0.009494429
# Epoch 12 completed, Train Loss: 0.3813
# Epoch 13, Step 1, LR: 0.000080, Current Loss: 0.3757, Avg Loss: 0.3757
# Diff stats — min: -4.3346, max: 7.7557, mean: 1.7364, std: 1.7964
#
# Step 624 — Test metrics:
#   precision@10: 0.027913907
#   recall@10: 0.027917586
#   ndcg@10: 0.028702793
#   map@10: 0.009502858
# Epoch 13, Step 10, LR: 0.000080, Current Loss: 0.3760, Avg Loss: 0.3793
# Diff stats — min: -6.0891, max: 8.1927, mean: 1.7823, std: 1.8389
#
# Step 633 — Test metrics:
#   precision@10: 0.027930464
#   recall@10: 0.027934143
#   ndcg@10: 0.028671747
#   map@10: 0.009494264
# Epoch 13, Step 20, LR: 0.000080, Current Loss: 0.3787, Avg Loss: 0.3783
# Diff stats — min: -4.9251, max: 7.2628, mean: 1.7689, std: 1.8414
#
# Step 643 — Test metrics:
#   precision@10: 0.028460265
#   recall@10: 0.028463944
#   ndcg@10: 0.029068811
#   map@10: 0.009595015
# Epoch 13, Step 30, LR: 0.000080, Current Loss: 0.3757, Avg Loss: 0.3785
# Diff stats — min: -5.1409, max: 8.4893, mean: 1.7338, std: 1.8069
#
# Step 653 — Test metrics:
#   precision@10: 0.028559603
#   recall@10: 0.028563282
#   ndcg@10: 0.029202958
#   map@10: 0.009658564
# Epoch 13, Step 40, LR: 0.000080, Current Loss: 0.3835, Avg Loss: 0.3783
# Diff stats — min: -5.1200, max: 8.2144, mean: 1.7770, std: 1.8611
#
# Step 663 — Test metrics:
#   precision@10: 0.028824503
#   recall@10: 0.028828182
#   ndcg@10: 0.029586560
#   map@10: 0.009792159
# Epoch 13, Step 50, LR: 0.000080, Current Loss: 0.3723, Avg Loss: 0.3776
# Diff stats — min: -5.0757, max: 8.0656, mean: 1.7955, std: 1.8393
#
# Step 673 — Test metrics:
#   precision@10: 0.028675497
#   recall@10: 0.028679176
#   ndcg@10: 0.029348908
#   map@10: 0.009685371
# Epoch 13 completed, Train Loss: 0.3773
# Epoch 14, Step 1, LR: 0.000080, Current Loss: 0.3649, Avg Loss: 0.3649
# Diff stats — min: -5.0930, max: 7.8056, mean: 1.7681, std: 1.7900
#
# Step 676 — Test metrics:
#   precision@10: 0.028675497
#   recall@10: 0.028679176
#   ndcg@10: 0.029339090
#   map@10: 0.009687132
# Epoch 14, Step 10, LR: 0.000080, Current Loss: 0.3850, Avg Loss: 0.3762
# Diff stats — min: -5.1059, max: 7.9866, mean: 1.7500, std: 1.8451
#
# Step 685 — Test metrics:
#   precision@10: 0.028112583
#   recall@10: 0.028116262
#   ndcg@10: 0.028926041
#   map@10: 0.009593593
# Epoch 14, Step 20, LR: 0.000080, Current Loss: 0.3747, Avg Loss: 0.3758
# Diff stats — min: -4.9170, max: 7.4809, mean: 1.7961, std: 1.8475
#
# Step 695 — Test metrics:
#   precision@10: 0.028245033
#   recall@10: 0.028248712
#   ndcg@10: 0.028920383
#   map@10: 0.009557257
# Epoch 14, Step 30, LR: 0.000080, Current Loss: 0.3611, Avg Loss: 0.3749
# Diff stats — min: -4.9542, max: 7.7424, mean: 1.8162, std: 1.8063
#
# Step 705 — Test metrics:
#   precision@10: 0.028377483
#   recall@10: 0.028381163
#   ndcg@10: 0.029140804
#   map@10: 0.009670219
# Epoch 14, Step 40, LR: 0.000080, Current Loss: 0.3550, Avg Loss: 0.3744
# Diff stats — min: -4.8069, max: 7.9400, mean: 1.8518, std: 1.8183
#
# Step 715 — Test metrics:
#   precision@10: 0.028890728
#   recall@10: 0.028894408
#   ndcg@10: 0.029503939
#   map@10: 0.009756410
# Epoch 14, Step 50, LR: 0.000080, Current Loss: 0.3756, Avg Loss: 0.3747
# Diff stats — min: -4.8423, max: 7.6114, mean: 1.7929, std: 1.8554
#
# Step 725 — Test metrics:
#   precision@10: 0.028841060
#   recall@10: 0.028844739
#   ndcg@10: 0.029499283
#   map@10: 0.009759629
# Epoch 14 completed, Train Loss: 0.3744
# Epoch 15, Step 1, LR: 0.000080, Current Loss: 0.3830, Avg Loss: 0.3830
# Diff stats — min: -4.8102, max: 8.9369, mean: 1.7779, std: 1.8807
#
# Step 728 — Test metrics:
#   precision@10: 0.028708609
#   recall@10: 0.028712288
#   ndcg@10: 0.029474706
#   map@10: 0.009780982
# Epoch 15, Step 10, LR: 0.000080, Current Loss: 0.3793, Avg Loss: 0.3716
# Diff stats — min: -5.2486, max: 7.7239, mean: 1.7581, std: 1.8253
#
# Step 737 — Test metrics:
#   precision@10: 0.028675497
#   recall@10: 0.028679176
#   ndcg@10: 0.029500507
#   map@10: 0.009796204
# Epoch 15, Step 20, LR: 0.000080, Current Loss: 0.3763, Avg Loss: 0.3706
# Diff stats — min: -5.2986, max: 8.0494, mean: 1.7935, std: 1.8504
#
# Step 747 — Test metrics:
#   precision@10: 0.028658940
#   recall@10: 0.028662620
#   ndcg@10: 0.029400189
#   map@10: 0.009764905
# Epoch 15, Step 30, LR: 0.000080, Current Loss: 0.3751, Avg Loss: 0.3706
# Diff stats — min: -5.5310, max: 9.7640, mean: 1.7978, std: 1.8525
#
# Step 757 — Test metrics:
#   precision@10: 0.028940397
#   recall@10: 0.028944077
#   ndcg@10: 0.029604036
#   map@10: 0.009826400
# Epoch 15, Step 40, LR: 0.000080, Current Loss: 0.3758, Avg Loss: 0.3716
# Diff stats — min: -5.7670, max: 8.5941, mean: 1.8121, std: 1.8649
#
# Step 767 — Test metrics:
#   precision@10: 0.029172185
#   recall@10: 0.029175865
#   ndcg@10: 0.029835833
#   map@10: 0.009904223
# Epoch 15, Step 50, LR: 0.000080, Current Loss: 0.3690, Avg Loss: 0.3709
# Diff stats — min: -6.0449, max: 8.7217, mean: 1.8304, std: 1.8729
#
# Step 777 — Test metrics:
#   precision@10: 0.028857616
#   recall@10: 0.028861295
#   ndcg@10: 0.029549751
#   map@10: 0.009818301
# Epoch 15 completed, Train Loss: 0.3707
# Epoch 16, Step 1, LR: 0.000080, Current Loss: 0.3775, Avg Loss: 0.3775
# Diff stats — min: -6.4613, max: 8.1630, mean: 1.7962, std: 1.8642
#
# Step 780 — Test metrics:
#   precision@10: 0.028874172
#   recall@10: 0.028877851
#   ndcg@10: 0.029535432
#   map@10: 0.009792941
# Epoch 16, Step 10, LR: 0.000080, Current Loss: 0.3735, Avg Loss: 0.3698
# Diff stats — min: -4.6970, max: 8.9173, mean: 1.8269, std: 1.8781
#
# Step 789 — Test metrics:
#   precision@10: 0.029238411
#   recall@10: 0.029242090
#   ndcg@10: 0.029777004
#   map@10: 0.009852879
# Epoch 16, Step 20, LR: 0.000080, Current Loss: 0.3724, Avg Loss: 0.3691
# Diff stats — min: -5.4201, max: 8.7817, mean: 1.8241, std: 1.8728
#
# Step 799 — Test metrics:
#   precision@10: 0.029188742
#   recall@10: 0.029192421
#   ndcg@10: 0.029775456
#   map@10: 0.009858490
# Epoch 16, Step 30, LR: 0.000080, Current Loss: 0.3677, Avg Loss: 0.3681
# Diff stats — min: -4.1161, max: 8.1883, mean: 1.8472, std: 1.8667
#
# Step 809 — Test metrics:
#   precision@10: 0.029172185
#   recall@10: 0.029175865
#   ndcg@10: 0.029903508
#   map@10: 0.009940575
# Epoch 16, Step 40, LR: 0.000080, Current Loss: 0.3803, Avg Loss: 0.3680
# Diff stats — min: -4.8098, max: 8.2070, mean: 1.8141, std: 1.8923
#
# Step 819 — Test metrics:
#   precision@10: 0.029288079
#   recall@10: 0.029291759
#   ndcg@10: 0.029844796
#   map@10: 0.009872510
# Epoch 16, Step 50, LR: 0.000080, Current Loss: 0.3545, Avg Loss: 0.3675
# Diff stats — min: -6.0193, max: 7.4111, mean: 1.8703, std: 1.8402
#
# Step 829 — Test metrics:
#   precision@10: 0.029470199
#   recall@10: 0.029473878
#   ndcg@10: 0.029944288
#   map@10: 0.009893902
# Epoch 16 completed, Train Loss: 0.3672
# Epoch 17, Step 1, LR: 0.000080, Current Loss: 0.3795, Avg Loss: 0.3795
# Diff stats — min: -4.9888, max: 8.2220, mean: 1.7704, std: 1.8485
#
# Step 832 — Test metrics:
#   precision@10: 0.029453642
#   recall@10: 0.029457322
#   ndcg@10: 0.030008217
#   map@10: 0.009932566
# Epoch 17, Step 10, LR: 0.000080, Current Loss: 0.3834, Avg Loss: 0.3703
# Diff stats — min: -4.9003, max: 8.5280, mean: 1.8322, std: 1.9218
#
# Step 841 — Test metrics:
#   precision@10: 0.029536424
#   recall@10: 0.029540103
#   ndcg@10: 0.030130092
#   map@10: 0.010000690
# Epoch 17, Step 20, LR: 0.000080, Current Loss: 0.3754, Avg Loss: 0.3696
# Diff stats — min: -5.3757, max: 8.5222, mean: 1.8089, std: 1.8687
#
# Step 851 — Test metrics:
#   precision@10: 0.029519868
#   recall@10: 0.029523547
#   ndcg@10: 0.030067099
#   map@10: 0.009973247
# Epoch 17, Step 30, LR: 0.000080, Current Loss: 0.3566, Avg Loss: 0.3663
# Diff stats — min: -5.0718, max: 10.5683, mean: 1.8821, std: 1.8722
#
# Step 861 — Test metrics:
#   precision@10: 0.029735099
#   recall@10: 0.029738779
#   ndcg@10: 0.030197615
#   map@10: 0.009985802
# Epoch 17, Step 40, LR: 0.000080, Current Loss: 0.3518, Avg Loss: 0.3661
# Diff stats — min: -4.5875, max: 8.0767, mean: 1.8559, std: 1.8190
#
# Step 871 — Test metrics:
#   precision@10: 0.030016556
#   recall@10: 0.030020235
#   ndcg@10: 0.030488068
#   map@10: 0.010098203
# Epoch 17, Step 50, LR: 0.000080, Current Loss: 0.3760, Avg Loss: 0.3658
# Diff stats — min: -5.0621, max: 8.5750, mean: 1.8355, std: 1.8936
#
# Step 881 — Test metrics:
#   precision@10: 0.029867550
#   recall@10: 0.029871229
#   ndcg@10: 0.030446204
#   map@10: 0.010118555
# Epoch 17 completed, Train Loss: 0.3657
# Epoch 18, Step 1, LR: 0.000080, Current Loss: 0.3670, Avg Loss: 0.3670
# Diff stats — min: -4.8432, max: 7.5676, mean: 1.8477, std: 1.8679
#
# Step 884 — Test metrics:
#   precision@10: 0.029900662
#   recall@10: 0.029904341
#   ndcg@10: 0.030394412
#   map@10: 0.010097951
# Epoch 18, Step 10, LR: 0.000080, Current Loss: 0.3713, Avg Loss: 0.3644
# Diff stats — min: -5.7734, max: 8.0665, mean: 1.8598, std: 1.8977
#
# Step 893 — Test metrics:
#   precision@10: 0.029751656
#   recall@10: 0.029755335
#   ndcg@10: 0.030213121
#   map@10: 0.010004251
# Epoch 18, Step 20, LR: 0.000080, Current Loss: 0.3782, Avg Loss: 0.3646
# Diff stats — min: -5.6922, max: 7.9453, mean: 1.8154, std: 1.8816
#
# Step 903 — Test metrics:
#   precision@10: 0.029867550
#   recall@10: 0.029871229
#   ndcg@10: 0.030299048
#   map@10: 0.010061254
# Epoch 18, Step 30, LR: 0.000080, Current Loss: 0.3516, Avg Loss: 0.3626
# Diff stats — min: -5.1554, max: 9.1086, mean: 1.9356, std: 1.8921
#
# Step 913 — Test metrics:
#   precision@10: 0.029917219
#   recall@10: 0.029920898
#   ndcg@10: 0.030291518
#   map@10: 0.010050650
# Epoch 18, Step 40, LR: 0.000080, Current Loss: 0.3567, Avg Loss: 0.3628
# Diff stats — min: -5.5220, max: 7.5435, mean: 1.9137, std: 1.8853
#
# Step 923 — Test metrics:
#   precision@10: 0.030165563
#   recall@10: 0.030169242
#   ndcg@10: 0.030720875
#   map@10: 0.010233406
# Epoch 18, Step 50, LR: 0.000080, Current Loss: 0.3669, Avg Loss: 0.3624
# Diff stats — min: -5.7267, max: 8.0338, mean: 1.8707, std: 1.8904
#
# Step 933 — Test metrics:
#   precision@10: 0.030380795
#   recall@10: 0.030384474
#   ndcg@10: 0.030919654
#   map@10: 0.010274653
# Epoch 18 completed, Train Loss: 0.3620
# Epoch 19, Step 1, LR: 0.000080, Current Loss: 0.3618, Avg Loss: 0.3618
# Diff stats — min: -5.5298, max: 7.5430, mean: 1.9077, std: 1.9042
#
# Step 936 — Test metrics:
#   precision@10: 0.030314570
#   recall@10: 0.030318249
#   ndcg@10: 0.030831127
#   map@10: 0.010241264
# Epoch 19, Step 10, LR: 0.000080, Current Loss: 0.3626, Avg Loss: 0.3591
# Diff stats — min: -4.9136, max: 8.2324, mean: 1.9142, std: 1.9128
#
# Step 945 — Test metrics:
#   precision@10: 0.030298013
#   recall@10: 0.030301692
#   ndcg@10: 0.030891487
#   map@10: 0.010295821
# Epoch 19, Step 20, LR: 0.000080, Current Loss: 0.3663, Avg Loss: 0.3584
# Diff stats — min: -4.9565, max: 7.7720, mean: 1.9154, std: 1.9210
#
# Step 955 — Test metrics:
#   precision@10: 0.030182119
#   recall@10: 0.030185798
#   ndcg@10: 0.030768246
#   map@10: 0.010262991
# Epoch 19, Step 30, LR: 0.000080, Current Loss: 0.3563, Avg Loss: 0.3580
# Diff stats — min: -6.1323, max: 9.0798, mean: 1.9283, std: 1.9066
#
# Step 965 — Test metrics:
#   precision@10: 0.030447020
#   recall@10: 0.030450699
#   ndcg@10: 0.030967343
#   map@10: 0.010310122
# Epoch 19, Step 40, LR: 0.000080, Current Loss: 0.3619, Avg Loss: 0.3591
# Diff stats — min: -4.6496, max: 7.8010, mean: 1.9052, std: 1.8939
#
# Step 975 — Test metrics:
#   precision@10: 0.030529801
#   recall@10: 0.030533481
#   ndcg@10: 0.030951865
#   map@10: 0.010257089
# Epoch 19, Step 50, LR: 0.000080, Current Loss: 0.3507, Avg Loss: 0.3583
# Diff stats — min: -4.9304, max: 8.4672, mean: 1.9420, std: 1.8871
#
# Step 985 — Test metrics:
#   precision@10: 0.030728477
#   recall@10: 0.030732156
#   ndcg@10: 0.031213371
#   map@10: 0.010379395
# Epoch 19 completed, Train Loss: 0.3584
# Epoch 20, Step 1, LR: 0.000080, Current Loss: 0.3652, Avg Loss: 0.3652
# Diff stats — min: -4.8933, max: 8.5454, mean: 1.8703, std: 1.8748
#
# Step 988 — Test metrics:
#   precision@10: 0.030546358
#   recall@10: 0.030550037
#   ndcg@10: 0.031066981
#   map@10: 0.010340028
# Epoch 20, Step 10, LR: 0.000080, Current Loss: 0.3617, Avg Loss: 0.3572
# Diff stats — min: -5.5062, max: 8.5581, mean: 1.9113, std: 1.9087
#
# Step 997 — Test metrics:
#   precision@10: 0.030678808
#   recall@10: 0.030682487
#   ndcg@10: 0.031129943
#   map@10: 0.010363899
# Epoch 20, Step 20, LR: 0.000080, Current Loss: 0.3862, Avg Loss: 0.3576
# Diff stats — min: -4.9662, max: 8.4917, mean: 1.8295, std: 1.9274
#
# Step 1007 — Test metrics:
#   precision@10: 0.030513245
#   recall@10: 0.030516924
#   ndcg@10: 0.031009201
#   map@10: 0.010326135
# Epoch 20, Step 30, LR: 0.000080, Current Loss: 0.3593, Avg Loss: 0.3578
# Diff stats — min: -5.2902, max: 8.9087, mean: 1.9375, std: 1.9159
#
# Step 1017 — Test metrics:
#   precision@10: 0.030430464
#   recall@10: 0.030434143
#   ndcg@10: 0.030976199
#   map@10: 0.010358354
# Epoch 20, Step 40, LR: 0.000080, Current Loss: 0.3372, Avg Loss: 0.3563
# Diff stats — min: -5.0521, max: 9.0443, mean: 1.9563, std: 1.8427
#
# Step 1027 — Test metrics:
#   precision@10: 0.030480132
#   recall@10: 0.030483812
#   ndcg@10: 0.031145680
#   map@10: 0.010417681
# Epoch 20, Step 50, LR: 0.000080, Current Loss: 0.3267, Avg Loss: 0.3552
# Diff stats — min: -4.8032, max: 8.0108, mean: 2.0375, std: 1.8709
#
# Step 1037 — Test metrics:
#   precision@10: 0.030678808
#   recall@10: 0.030682487
#   ndcg@10: 0.031248380
#   map@10: 0.010430256
# Epoch 20 completed, Train Loss: 0.3548
# Epoch 21, Step 1, LR: 0.000080, Current Loss: 0.3670, Avg Loss: 0.3670
# Diff stats — min: -4.3312, max: 8.6662, mean: 1.9288, std: 1.9435
#
# Step 1040 — Test metrics:
#   precision@10: 0.030894040
#   recall@10: 0.030897719
#   ndcg@10: 0.031349409
#   map@10: 0.010437147
# Epoch 21, Step 10, LR: 0.000080, Current Loss: 0.3471, Avg Loss: 0.3564
# Diff stats — min: -4.6908, max: 8.0969, mean: 1.9669, std: 1.9009
#
# Step 1049 — Test metrics:
#   precision@10: 0.031125828
#   recall@10: 0.031129507
#   ndcg@10: 0.031598698
#   map@10: 0.010517780
# Epoch 21, Step 20, LR: 0.000080, Current Loss: 0.3523, Avg Loss: 0.3572
# Diff stats — min: -5.9352, max: 7.9676, mean: 1.9204, std: 1.8864
#
# Step 1059 — Test metrics:
#   precision@10: 0.030778146
#   recall@10: 0.030781825
#   ndcg@10: 0.031365285
#   map@10: 0.010495903
# Epoch 21, Step 30, LR: 0.000080, Current Loss: 0.3509, Avg Loss: 0.3556
# Diff stats — min: -6.1312, max: 8.6398, mean: 1.9766, std: 1.9278
#
# Step 1069 — Test metrics:
#   precision@10: 0.030860927
#   recall@10: 0.030864606
#   ndcg@10: 0.031389011
#   map@10: 0.010479182
# Epoch 21, Step 40, LR: 0.000080, Current Loss: 0.3592, Avg Loss: 0.3555
# Diff stats — min: -5.8678, max: 9.1036, mean: 1.9447, std: 1.9266
#
# Step 1079 — Test metrics:
#   precision@10: 0.030612583
#   recall@10: 0.030616262
#   ndcg@10: 0.031235189
#   map@10: 0.010442598
# Epoch 21, Step 50, LR: 0.000080, Current Loss: 0.3370, Avg Loss: 0.3539
# Diff stats — min: -4.9220, max: 8.9945, mean: 1.9796, std: 1.8789
#
# Step 1089 — Test metrics:
#   precision@10: 0.030496689
#   recall@10: 0.030500368
#   ndcg@10: 0.031228051
#   map@10: 0.010472520
# Epoch 21 completed, Train Loss: 0.3535
# Epoch 22, Step 1, LR: 0.000080, Current Loss: 0.3623, Avg Loss: 0.3623
# Diff stats — min: -4.6496, max: 8.3606, mean: 1.9114, std: 1.9063
#
# Step 1092 — Test metrics:
#   precision@10: 0.030397351
#   recall@10: 0.030401030
#   ndcg@10: 0.031129939
#   map@10: 0.010439841
# Epoch 22, Step 10, LR: 0.000080, Current Loss: 0.3458, Avg Loss: 0.3503
# Diff stats — min: -5.2771, max: 8.2427, mean: 1.9845, std: 1.9150
#
# Step 1101 — Test metrics:
#   precision@10: 0.030645695
#   recall@10: 0.030649375
#   ndcg@10: 0.031277051
#   map@10: 0.010458401
# Epoch 22, Step 20, LR: 0.000080, Current Loss: 0.3493, Avg Loss: 0.3491
# Diff stats — min: -4.4441, max: 9.1145, mean: 1.9457, std: 1.8952
#
# Step 1111 — Test metrics:
#   precision@10: 0.030678808
#   recall@10: 0.030682487
#   ndcg@10: 0.031308676
#   map@10: 0.010489212
# Epoch 22, Step 30, LR: 0.000080, Current Loss: 0.3543, Avg Loss: 0.3484
# Diff stats — min: -4.8991, max: 7.9820, mean: 1.9391, std: 1.9094
#
# Step 1121 — Test metrics:
#   precision@10: 0.030662252
#   recall@10: 0.030665931
#   ndcg@10: 0.031252358
#   map@10: 0.010446080
# Epoch 22, Step 40, LR: 0.000080, Current Loss: 0.3529, Avg Loss: 0.3486
# Diff stats — min: -6.4365, max: 8.2776, mean: 1.9716, std: 1.9240
#
# Step 1131 — Test metrics:
#   precision@10: 0.030662252
#   recall@10: 0.030665931
#   ndcg@10: 0.031265990
#   map@10: 0.010478177
# Epoch 22, Step 50, LR: 0.000080, Current Loss: 0.3399, Avg Loss: 0.3492
# Diff stats — min: -4.6744, max: 8.0804, mean: 2.0409, std: 1.9336
#
# Step 1141 — Test metrics:
#   precision@10: 0.031059603
#   recall@10: 0.031063282
#   ndcg@10: 0.031361841
#   map@10: 0.010451076
# Epoch 22 completed, Train Loss: 0.3490
# Epoch 23, Step 1, LR: 0.000080, Current Loss: 0.3498, Avg Loss: 0.3498
# Diff stats — min: -4.3015, max: 7.9473, mean: 1.9957, std: 1.9418
#
# Step 1144 — Test metrics:
#   precision@10: 0.031142384
#   recall@10: 0.031146063
#   ndcg@10: 0.031497115
#   map@10: 0.010510488
# Epoch 23, Step 10, LR: 0.000080, Current Loss: 0.3421, Avg Loss: 0.3475
# Diff stats — min: -4.7360, max: 8.3488, mean: 2.0307, std: 1.9297
#
# Step 1153 — Test metrics:
#   precision@10: 0.030927152
#   recall@10: 0.030930831
#   ndcg@10: 0.031372467
#   map@10: 0.010461062
# Epoch 23, Step 20, LR: 0.000080, Current Loss: 0.3407, Avg Loss: 0.3491
# Diff stats — min: -4.2987, max: 8.0058, mean: 2.0123, std: 1.9147
#
# Step 1163 — Test metrics:
#   precision@10: 0.030695364
#   recall@10: 0.030699043
#   ndcg@10: 0.031350613
#   map@10: 0.010529955
# Epoch 23, Step 30, LR: 0.000080, Current Loss: 0.3461, Avg Loss: 0.3485
# Diff stats — min: -5.5769, max: 8.0534, mean: 2.0095, std: 1.9304
#
# Step 1173 — Test metrics:
#   precision@10: 0.030860927
#   recall@10: 0.030864606
#   ndcg@10: 0.031613439
#   map@10: 0.010646254
# Epoch 23, Step 40, LR: 0.000080, Current Loss: 0.3344, Avg Loss: 0.3475
# Diff stats — min: -5.0390, max: 8.8933, mean: 2.0408, std: 1.9236
#
# Step 1183 — Test metrics:
#   precision@10: 0.031109272
#   recall@10: 0.031112951
#   ndcg@10: 0.031666756
#   map@10: 0.010630436
# Epoch 23, Step 50, LR: 0.000080, Current Loss: 0.3642, Avg Loss: 0.3481
# Diff stats — min: -4.7437, max: 8.9333, mean: 1.9394, std: 1.9465
#
# Step 1193 — Test metrics:
#   precision@10: 0.031009934
#   recall@10: 0.031013613
#   ndcg@10: 0.031502831
#   map@10: 0.010552220
# Epoch 23 completed, Train Loss: 0.3488
# Epoch 24, Step 1, LR: 0.000080, Current Loss: 0.3343, Avg Loss: 0.3343
# Diff stats — min: -5.0588, max: 7.8856, mean: 2.0373, std: 1.9166
#
# Step 1196 — Test metrics:
#   precision@10: 0.030960265
#   recall@10: 0.030963944
#   ndcg@10: 0.031485590
#   map@10: 0.010551491
# Epoch 24, Step 10, LR: 0.000080, Current Loss: 0.3468, Avg Loss: 0.3473
# Diff stats — min: -4.2740, max: 9.0469, mean: 2.0037, std: 1.9430
#
# Step 1205 — Test metrics:
#   precision@10: 0.030877483
#   recall@10: 0.030881163
#   ndcg@10: 0.031515986
#   map@10: 0.010575108
# Epoch 24, Step 20, LR: 0.000080, Current Loss: 0.3358, Avg Loss: 0.3477
# Diff stats — min: -5.1747, max: 8.7843, mean: 2.0267, std: 1.8985
#
# Step 1215 — Test metrics:
#   precision@10: 0.030894040
#   recall@10: 0.030897719
#   ndcg@10: 0.031499807
#   map@10: 0.010572000
# Epoch 24, Step 30, LR: 0.000080, Current Loss: 0.3435, Avg Loss: 0.3470
# Diff stats — min: -5.9864, max: 9.4335, mean: 2.0300, std: 1.9481
#
# Step 1225 — Test metrics:
#   precision@10: 0.031043046
#   recall@10: 0.031046726
#   ndcg@10: 0.031570035
#   map@10: 0.010588366
# Epoch 24, Step 40, LR: 0.000080, Current Loss: 0.3448, Avg Loss: 0.3464
# Diff stats — min: -5.5460, max: 8.0989, mean: 1.9979, std: 1.9145
#
# Step 1235 — Test metrics:
#   precision@10: 0.031009934
#   recall@10: 0.031013613
#   ndcg@10: 0.031480603
#   map@10: 0.010544814
# Epoch 24, Step 50, LR: 0.000080, Current Loss: 0.3534, Avg Loss: 0.3465
# Diff stats — min: -5.3624, max: 8.0284, mean: 1.9867, std: 1.9363
#
# Step 1245 — Test metrics:
#   precision@10: 0.030894040
#   recall@10: 0.030897719
#   ndcg@10: 0.031514682
#   map@10: 0.010571201
# Epoch 24 completed, Train Loss: 0.3467
# Epoch 25, Step 1, LR: 0.000080, Current Loss: 0.3327, Avg Loss: 0.3327
# Diff stats — min: -5.7716, max: 9.0032, mean: 2.0354, std: 1.9080
#
# Step 1248 — Test metrics:
#   precision@10: 0.030894040
#   recall@10: 0.030897719
#   ndcg@10: 0.031485947
#   map@10: 0.010553547
# Epoch 25, Step 10, LR: 0.000080, Current Loss: 0.3493, Avg Loss: 0.3435
# Diff stats — min: -4.9098, max: 8.8585, mean: 2.0001, std: 1.9384
#
# Step 1257 — Test metrics:
#   precision@10: 0.030993377
#   recall@10: 0.030997057
#   ndcg@10: 0.031535279
#   map@10: 0.010532241
# Epoch 25, Step 20, LR: 0.000080, Current Loss: 0.3354, Avg Loss: 0.3421
# Diff stats — min: -4.7762, max: 8.1901, mean: 2.0637, std: 1.9510
#
# Step 1267 — Test metrics:
#   precision@10: 0.031208609
#   recall@10: 0.031212288
#   ndcg@10: 0.031756507
#   map@10: 0.010636379
# Epoch 25, Step 30, LR: 0.000080, Current Loss: 0.3532, Avg Loss: 0.3425
# Diff stats — min: -4.5163, max: 9.3292, mean: 2.0051, std: 1.9650
#
# Step 1277 — Test metrics:
#   precision@10: 0.031357616
#   recall@10: 0.031361295
#   ndcg@10: 0.031890534
#   map@10: 0.010706014
# Epoch 25, Step 40, LR: 0.000080, Current Loss: 0.3408, Avg Loss: 0.3437
# Diff stats — min: -6.1730, max: 8.4019, mean: 2.0649, std: 1.9622
#
# Step 1287 — Test metrics:
#   precision@10: 0.031721854
#   recall@10: 0.031725533
#   ndcg@10: 0.032279054
#   map@10: 0.010855428
# Epoch 25, Step 50, LR: 0.000080, Current Loss: 0.3332, Avg Loss: 0.3442
# Diff stats — min: -5.8739, max: 8.5637, mean: 2.0976, std: 1.9598
#
# Step 1297 — Test metrics:
#   precision@10: 0.031754967
#   recall@10: 0.031758646
#   ndcg@10: 0.032262534
#   map@10: 0.010820883
# Epoch 25 completed, Train Loss: 0.3441
# Epoch 26, Step 1, LR: 0.000080, Current Loss: 0.3389, Avg Loss: 0.3389
# Diff stats — min: -5.5776, max: 9.2988, mean: 2.0420, std: 1.9260
#
# Step 1300 — Test metrics:
#   precision@10: 0.031523179
#   recall@10: 0.031526858
#   ndcg@10: 0.032122433
#   map@10: 0.010784735
# Epoch 26, Step 10, LR: 0.000080, Current Loss: 0.3339, Avg Loss: 0.3429
# Diff stats — min: -4.7681, max: 7.9345, mean: 2.0808, std: 1.9428
#
# Step 1309 — Test metrics:
#   precision@10: 0.031374172
#   recall@10: 0.031377851
#   ndcg@10: 0.031952314
#   map@10: 0.010712656
# Epoch 26, Step 20, LR: 0.000080, Current Loss: 0.3309, Avg Loss: 0.3423
# Diff stats — min: -4.9685, max: 8.2142, mean: 2.0893, std: 1.9486
#
# Step 1319 — Test metrics:
#   precision@10: 0.031407285
#   recall@10: 0.031410964
#   ndcg@10: 0.031949461
#   map@10: 0.010734298
# Epoch 26, Step 30, LR: 0.000080, Current Loss: 0.3444, Avg Loss: 0.3408
# Diff stats — min: -6.1582, max: 9.4225, mean: 2.0347, std: 1.9542
#
# Step 1329 — Test metrics:
#   precision@10: 0.031423841
#   recall@10: 0.031427520
#   ndcg@10: 0.032002716
#   map@10: 0.010765774
# Epoch 26, Step 40, LR: 0.000080, Current Loss: 0.3308, Avg Loss: 0.3404
# Diff stats — min: -4.9465, max: 8.5720, mean: 2.0635, std: 1.9279
#
# Step 1339 — Test metrics:
#   precision@10: 0.031009934
#   recall@10: 0.031013613
#   ndcg@10: 0.031801700
#   map@10: 0.010706730
# Epoch 26, Step 50, LR: 0.000080, Current Loss: 0.3333, Avg Loss: 0.3402
# Diff stats — min: -5.1825, max: 8.3563, mean: 2.0978, std: 1.9579
#
# Step 1349 — Test metrics:
#   precision@10: 0.031407285
#   recall@10: 0.031410964
#   ndcg@10: 0.031899007
#   map@10: 0.010693268
# Epoch 26 completed, Train Loss: 0.3407
# Epoch 27, Step 1, LR: 0.000080, Current Loss: 0.3363, Avg Loss: 0.3363
# Diff stats — min: -5.3869, max: 9.7533, mean: 2.0837, std: 1.9693
#
# Step 1352 — Test metrics:
#   precision@10: 0.031241722
#   recall@10: 0.031245401
#   ndcg@10: 0.031795850
#   map@10: 0.010675372
# Epoch 27, Step 10, LR: 0.000080, Current Loss: 0.3299, Avg Loss: 0.3407
# Diff stats — min: -6.3679, max: 9.4237, mean: 2.0795, std: 1.9337
#
# Step 1361 — Test metrics:
#   precision@10: 0.031407285
#   recall@10: 0.031410964
#   ndcg@10: 0.032028802
#   map@10: 0.010775163
# Epoch 27, Step 20, LR: 0.000080, Current Loss: 0.3513, Avg Loss: 0.3414
# Diff stats — min: -5.3218, max: 8.5408, mean: 2.0422, std: 1.9884
#
# Step 1371 — Test metrics:
#   precision@10: 0.031903974
#   recall@10: 0.031907653
#   ndcg@10: 0.032249019
#   map@10: 0.010798046
# Epoch 27, Step 30, LR: 0.000080, Current Loss: 0.3412, Avg Loss: 0.3410
# Diff stats — min: -7.2444, max: 8.2599, mean: 2.0693, std: 1.9657
#
# Step 1381 — Test metrics:
#   precision@10: 0.031970199
#   recall@10: 0.031973878
#   ndcg@10: 0.032339762
#   map@10: 0.010866492
# Epoch 27, Step 40, LR: 0.000080, Current Loss: 0.3402, Avg Loss: 0.3413
# Diff stats — min: -6.0700, max: 8.8249, mean: 2.1160, std: 1.9889
#
# Step 1391 — Test metrics:
#   precision@10: 0.031523179
#   recall@10: 0.031526858
#   ndcg@10: 0.032082955
#   map@10: 0.010784137
# Epoch 27, Step 50, LR: 0.000080, Current Loss: 0.3328, Avg Loss: 0.3402
# Diff stats — min: -5.5623, max: 8.0677, mean: 2.1048, std: 1.9528
#
# Step 1401 — Test metrics:
#   precision@10: 0.031788079
#   recall@10: 0.031791759
#   ndcg@10: 0.032434604
#   map@10: 0.010950436
# Epoch 27 completed, Train Loss: 0.3399
# Epoch 28, Step 1, LR: 0.000080, Current Loss: 0.3326, Avg Loss: 0.3326
# Diff stats — min: -5.2937, max: 7.9520, mean: 2.0918, std: 1.9525
#
# Step 1404 — Test metrics:
#   precision@10: 0.031721854
#   recall@10: 0.031725533
#   ndcg@10: 0.032307297
#   map@10: 0.010913789
# Epoch 28, Step 10, LR: 0.000080, Current Loss: 0.3481, Avg Loss: 0.3348
# Diff stats — min: -4.6938, max: 9.1934, mean: 2.0616, std: 1.9970
#
# Step 1413 — Test metrics:
#   precision@10: 0.031506623
#   recall@10: 0.031510302
#   ndcg@10: 0.032104534
#   map@10: 0.010845737
# Epoch 28, Step 20, LR: 0.000080, Current Loss: 0.3429, Avg Loss: 0.3375
# Diff stats — min: -4.9540, max: 8.3880, mean: 2.0805, std: 1.9899
#
# Step 1423 — Test metrics:
#   precision@10: 0.031721854
#   recall@10: 0.031725533
#   ndcg@10: 0.032163485
#   map@10: 0.010828951
# Epoch 28, Step 30, LR: 0.000080, Current Loss: 0.3326, Avg Loss: 0.3366
# Diff stats — min: -5.3484, max: 8.6991, mean: 2.1147, std: 1.9659
#
# Step 1433 — Test metrics:
#   precision@10: 0.031804636
#   recall@10: 0.031808315
#   ndcg@10: 0.032315845
#   map@10: 0.010897666
# Epoch 28, Step 40, LR: 0.000080, Current Loss: 0.3430, Avg Loss: 0.3369
# Diff stats — min: -5.8975, max: 8.3124, mean: 2.0662, std: 1.9708
#
# Step 1443 — Test metrics:
#   precision@10: 0.031639073
#   recall@10: 0.031642752
#   ndcg@10: 0.032303938
#   map@10: 0.010931942
# Epoch 28, Step 50, LR: 0.000080, Current Loss: 0.3481, Avg Loss: 0.3374
# Diff stats — min: -4.9889, max: 8.8646, mean: 2.0877, std: 2.0037
#
# Step 1453 — Test metrics:
#   precision@10: 0.031738411
#   recall@10: 0.031742090
#   ndcg@10: 0.032375589
#   map@10: 0.010942717
# Epoch 28 completed, Train Loss: 0.3373
# Epoch 29, Step 1, LR: 0.000080, Current Loss: 0.3272, Avg Loss: 0.3272
# Diff stats — min: -5.8535, max: 8.3142, mean: 2.1286, std: 1.9615
#
# Step 1456 — Test metrics:
#   precision@10: 0.031953642
#   recall@10: 0.031957322
#   ndcg@10: 0.032587656
#   map@10: 0.011021372
# Epoch 29, Step 10, LR: 0.000080, Current Loss: 0.3497, Avg Loss: 0.3355
# Diff stats — min: -5.6927, max: 9.2736, mean: 2.0790, std: 2.0098
#
# Step 1465 — Test metrics:
#   precision@10: 0.032119205
#   recall@10: 0.032122884
#   ndcg@10: 0.032595556
#   map@10: 0.010989679
# Epoch 29, Step 20, LR: 0.000080, Current Loss: 0.3308, Avg Loss: 0.3367
# Diff stats — min: -5.5243, max: 8.4144, mean: 2.1372, std: 1.9863
#
# Step 1475 — Test metrics:
#   precision@10: 0.032102649
#   recall@10: 0.032106328
#   ndcg@10: 0.032714875
#   map@10: 0.011052133
# Epoch 29, Step 30, LR: 0.000080, Current Loss: 0.3322, Avg Loss: 0.3353
# Diff stats — min: -4.6362, max: 8.5881, mean: 2.1338, std: 1.9796
#
# Step 1485 — Test metrics:
#   precision@10: 0.032251656
#   recall@10: 0.032255335
#   ndcg@10: 0.032789246
#   map@10: 0.011067585
# Epoch 29, Step 40, LR: 0.000080, Current Loss: 0.3351, Avg Loss: 0.3349
# Diff stats — min: -6.2040, max: 9.4174, mean: 2.1487, std: 2.0192
#
# Step 1495 — Test metrics:
#   precision@10: 0.032433775
#   recall@10: 0.032437454
#   ndcg@10: 0.032898922
#   map@10: 0.011097275
# Epoch 29, Step 50, LR: 0.000080, Current Loss: 0.3468, Avg Loss: 0.3351
# Diff stats — min: -5.3061, max: 8.8225, mean: 2.0814, std: 2.0022
#
# Step 1505 — Test metrics:
#   precision@10: 0.032284768
#   recall@10: 0.032288447
#   ndcg@10: 0.032715732
#   map@10: 0.011033040
# Epoch 29 completed, Train Loss: 0.3349
# Epoch 30, Step 1, LR: 0.000080, Current Loss: 0.3302, Avg Loss: 0.3302
# Diff stats — min: -4.6112, max: 8.7275, mean: 2.1298, std: 1.9744
#
# Step 1508 — Test metrics:
#   precision@10: 0.032235099
#   recall@10: 0.032238779
#   ndcg@10: 0.032621479
#   map@10: 0.010985875
# Epoch 30, Step 10, LR: 0.000080, Current Loss: 0.3211, Avg Loss: 0.3325
# Diff stats — min: -4.0769, max: 8.6958, mean: 2.1312, std: 1.9277
#
# Step 1517 — Test metrics:
#   precision@10: 0.032201987
#   recall@10: 0.032205666
#   ndcg@10: 0.032613425
#   map@10: 0.011010854
# Epoch 30, Step 20, LR: 0.000080, Current Loss: 0.3445, Avg Loss: 0.3318
# Diff stats — min: -4.7452, max: 9.3816, mean: 2.0715, std: 1.9873
#
# Step 1527 — Test metrics:
#   precision@10: 0.032152318
#   recall@10: 0.032155997
#   ndcg@10: 0.032748866
#   map@10: 0.011091283
# Epoch 30, Step 30, LR: 0.000080, Current Loss: 0.3271, Avg Loss: 0.3308
# Diff stats — min: -4.2917, max: 8.6805, mean: 2.1293, std: 1.9695
#
# Step 1537 — Test metrics:
#   precision@10: 0.032251656
#   recall@10: 0.032255335
#   ndcg@10: 0.032757164
#   map@10: 0.011037626
# Epoch 30, Step 40, LR: 0.000080, Current Loss: 0.3461, Avg Loss: 0.3319
# Diff stats — min: -5.0811, max: 9.0830, mean: 2.0531, std: 1.9841
#
# Step 1547 — Test metrics:
#   precision@10: 0.032301325
#   recall@10: 0.032305004
#   ndcg@10: 0.032799129
# ...
#   map@10: 0.012835620
# Epoch 91, Step 10, LR: 0.000080, Current Loss: 0.2654, Avg Loss: 0.2666
# Diff stats — min: -5.4350, max: 10.4783, mean: 2.8416, std: 2.2937
#
# Step 4689 — Test metrics:
#   precision@10: 0.035016556
#   recall@10: 0.035018396
#   ndcg@10: 0.035730381
#   map@10: 0.012843484
# Epoch 91, Step 20, LR: 0.000080, Current Loss: 0.2566, Avg Loss: 0.2643
# Diff stats — min: -4.7023, max: 10.0725, mean: 2.8158, std: 2.2364
#
# Step 4699 — Test metrics:
#   precision@10: 0.034850993
#   recall@10: 0.034852833
#   ndcg@10: 0.035754673
#   map@10: 0.012897923
# Epoch 91, Step 30, LR: 0.000080, Current Loss: 0.2617, Avg Loss: 0.2643
# Diff stats — min: -5.1329, max: 10.2216, mean: 2.8027, std: 2.2352
#
# Step 4709 — Test metrics:
#   precision@10: 0.035165563
#   recall@10: 0.035167403
#   ndcg@10: 0.036028909
#   map@10: 0.012997109
# Epoch 91, Step 40, LR: 0.000080, Current Loss: 0.2656, Avg Loss: 0.2653
# Diff stats — min: -6.1211, max: 10.3859, mean: 2.8195, std: 2.2708
#
# Step 4719 — Test metrics:
#   precision@10: 0.034685430
#   recall@10: 0.034687270
#   ndcg@10: 0.035678108
#   map@10: 0.012880041
# Epoch 91, Step 50, LR: 0.000080, Current Loss: 0.2546, Avg Loss: 0.2647
# Diff stats — min: -5.5534, max: 10.3101, mean: 2.8260, std: 2.2291
#
# Step 4729 — Test metrics:
#   precision@10: 0.034701987
#   recall@10: 0.034703826
#   ndcg@10: 0.035402202
#   map@10: 0.012711723
# Epoch 91 completed, Train Loss: 0.2648
# Epoch 92, Step 1, LR: 0.000080, Current Loss: 0.2710, Avg Loss: 0.2710
# Diff stats — min: -6.4665, max: 11.5711, mean: 2.8313, std: 2.3118
#
# Step 4732 — Test metrics:
#   precision@10: 0.034701987
#   recall@10: 0.034703826
#   ndcg@10: 0.035304303
#   map@10: 0.012657548
# Epoch 92, Step 10, LR: 0.000080, Current Loss: 0.2463, Avg Loss: 0.2654
# Diff stats — min: -4.8880, max: 10.6274, mean: 2.8837, std: 2.2385
#
# Step 4741 — Test metrics:
#   precision@10: 0.034917219
#   recall@10: 0.034920898
#   ndcg@10: 0.035421498
#   map@10: 0.012661187
# Epoch 92, Step 20, LR: 0.000080, Current Loss: 0.2543, Avg Loss: 0.2658
# Diff stats — min: -5.6428, max: 11.1561, mean: 2.8616, std: 2.2721
#
# Step 4751 — Test metrics:
#   precision@10: 0.034900662
#   recall@10: 0.034902502
#   ndcg@10: 0.035604618
#   map@10: 0.012804472
# Epoch 92, Step 30, LR: 0.000080, Current Loss: 0.2518, Avg Loss: 0.2662
# Diff stats — min: -5.6636, max: 10.0555, mean: 2.8834, std: 2.2591
#
# Step 4761 — Test metrics:
#   precision@10: 0.034850993
#   recall@10: 0.034852833
#   ndcg@10: 0.035483301
#   map@10: 0.012756708
# Epoch 92, Step 40, LR: 0.000080, Current Loss: 0.2747, Avg Loss: 0.2673
# Diff stats — min: -4.8106, max: 10.6038, mean: 2.8032, std: 2.3040
#
# Step 4771 — Test metrics:
#   precision@10: 0.034933775
#   recall@10: 0.034937454
#   ndcg@10: 0.035341950
#   map@10: 0.012677468
# Epoch 92, Step 50, LR: 0.000080, Current Loss: 0.2803, Avg Loss: 0.2671
# Diff stats — min: -5.3893, max: 10.8520, mean: 2.7054, std: 2.2571
#
# Step 4781 — Test metrics:
#   precision@10: 0.034850993
#   recall@10: 0.034852833
#   ndcg@10: 0.035493248
#   map@10: 0.012789229
# Epoch 92 completed, Train Loss: 0.2666
# Epoch 93, Step 1, LR: 0.000080, Current Loss: 0.2746, Avg Loss: 0.2746
# Diff stats — min: -6.0835, max: 10.3926, mean: 2.7636, std: 2.2649
#
# Step 4784 — Test metrics:
#   precision@10: 0.034751656
#   recall@10: 0.034753495
#   ndcg@10: 0.035525035
#   map@10: 0.012802100
# Epoch 93, Step 10, LR: 0.000080, Current Loss: 0.2821, Avg Loss: 0.2690
# Diff stats — min: -6.0077, max: 10.8638, mean: 2.7606, std: 2.3022
#
# Step 4793 — Test metrics:
#   precision@10: 0.034917219
#   recall@10: 0.034919058
#   ndcg@10: 0.035863764
#   map@10: 0.012937796
# Epoch 93, Step 20, LR: 0.000080, Current Loss: 0.2547, Avg Loss: 0.2665
# Diff stats — min: -5.1000, max: 11.6184, mean: 2.8039, std: 2.1941
#
# Step 4803 — Test metrics:
#   precision@10: 0.035298013
#   recall@10: 0.035299853
#   ndcg@10: 0.036019476
#   map@10: 0.012997523
# Epoch 93, Step 30, LR: 0.000080, Current Loss: 0.2628, Avg Loss: 0.2664
# Diff stats — min: -6.1984, max: 10.3233, mean: 2.8229, std: 2.2696
#
# Step 4813 — Test metrics:
#   precision@10: 0.034933775
#   recall@10: 0.034935614
#   ndcg@10: 0.035754712
#   map@10: 0.012983632
# Epoch 93, Step 40, LR: 0.000080, Current Loss: 0.2567, Avg Loss: 0.2656
# Diff stats — min: -5.4901, max: 10.4595, mean: 2.8036, std: 2.2260
#
# Step 4823 — Test metrics:
#   precision@10: 0.034950331
#   recall@10: 0.034952171
#   ndcg@10: 0.035584718
#   map@10: 0.012865290
# Epoch 93, Step 50, LR: 0.000080, Current Loss: 0.2739, Avg Loss: 0.2655
# Diff stats — min: -4.3865, max: 9.9781, mean: 2.7698, std: 2.2717
#
# Step 4833 — Test metrics:
#   precision@10: 0.035397351
#   recall@10: 0.035399191
#   ndcg@10: 0.035944927
#   map@10: 0.012943301
# Epoch 93 completed, Train Loss: 0.2654
# Epoch 94, Step 1, LR: 0.000080, Current Loss: 0.2655, Avg Loss: 0.2655
# Diff stats — min: -4.3947, max: 10.4172, mean: 2.8197, std: 2.2785
#
# Step 4836 — Test metrics:
#   precision@10: 0.035480132
#   recall@10: 0.035481972
#   ndcg@10: 0.036089485
#   map@10: 0.012991926
# Epoch 94, Step 10, LR: 0.000080, Current Loss: 0.2719, Avg Loss: 0.2668
# Diff stats — min: -6.0183, max: 10.2892, mean: 2.7974, std: 2.2897
#
# Step 4845 — Test metrics:
#   precision@10: 0.035215232
#   recall@10: 0.035217071
#   ndcg@10: 0.035978898
#   map@10: 0.012963892
# Epoch 94, Step 20, LR: 0.000080, Current Loss: 0.2511, Avg Loss: 0.2665
# Diff stats — min: -5.6058, max: 11.3494, mean: 2.8749, std: 2.2407
#
# Step 4855 — Test metrics:
#   precision@10: 0.035115894
#   recall@10: 0.035119573
#   ndcg@10: 0.035850139
#   map@10: 0.012943420
# Epoch 94, Step 30, LR: 0.000080, Current Loss: 0.2607, Avg Loss: 0.2655
# Diff stats — min: -4.9143, max: 10.7392, mean: 2.8458, std: 2.2818
#
# Step 4865 — Test metrics:
#   precision@10: 0.035016556
#   recall@10: 0.035018396
#   ndcg@10: 0.035793256
#   map@10: 0.012959494
# Epoch 94, Step 40, LR: 0.000080, Current Loss: 0.2616, Avg Loss: 0.2653
# Diff stats — min: -5.7167, max: 10.5871, mean: 2.8239, std: 2.2601
#
# Step 4875 — Test metrics:
#   precision@10: 0.034801325
#   recall@10: 0.034803164
#   ndcg@10: 0.035589287
#   map@10: 0.012850111
# Epoch 94, Step 50, LR: 0.000080, Current Loss: 0.2501, Avg Loss: 0.2644
# Diff stats — min: -4.5974, max: 10.6725, mean: 2.8435, std: 2.2321
#
# Step 4885 — Test metrics:
#   precision@10: 0.035099338
#   recall@10: 0.035101177
#   ndcg@10: 0.035774931
#   map@10: 0.012891556
# Epoch 94 completed, Train Loss: 0.2645
# Epoch 95, Step 1, LR: 0.000080, Current Loss: 0.2558, Avg Loss: 0.2558
# Diff stats — min: -4.6135, max: 10.5472, mean: 2.8289, std: 2.2264
#
# Step 4888 — Test metrics:
#   precision@10: 0.035132450
#   recall@10: 0.035134290
#   ndcg@10: 0.035643208
#   map@10: 0.012785425
# Epoch 95, Step 10, LR: 0.000080, Current Loss: 0.2508, Avg Loss: 0.2610
# Diff stats — min: -4.8478, max: 10.6652, mean: 2.8525, std: 2.2309
#
# Step 4897 — Test metrics:
#   precision@10: 0.034966887
#   recall@10: 0.034968727
#   ndcg@10: 0.035679968
#   map@10: 0.012855369
# Epoch 95, Step 20, LR: 0.000080, Current Loss: 0.2649, Avg Loss: 0.2627
# Diff stats — min: -4.7999, max: 11.2935, mean: 2.8258, std: 2.2786
#
# Step 4907 — Test metrics:
#   precision@10: 0.035066225
#   recall@10: 0.035068065
#   ndcg@10: 0.035690063
#   map@10: 0.012864363
# Epoch 95, Step 30, LR: 0.000080, Current Loss: 0.2568, Avg Loss: 0.2614
# Diff stats — min: -5.4728, max: 11.1635, mean: 2.8286, std: 2.2708
#
# Step 4917 — Test metrics:
#   precision@10: 0.035198675
#   recall@10: 0.035200515
#   ndcg@10: 0.035746677
#   map@10: 0.012847209
# Epoch 95, Step 40, LR: 0.000080, Current Loss: 0.2703, Avg Loss: 0.2623
# Diff stats — min: -5.1691, max: 11.3328, mean: 2.8112, std: 2.2922
#
# Step 4927 — Test metrics:
#   precision@10: 0.035000000
#   recall@10: 0.035001840
#   ndcg@10: 0.035593703
#   map@10: 0.012800615
# Epoch 95, Step 50, LR: 0.000080, Current Loss: 0.2769, Avg Loss: 0.2633
# Diff stats — min: -5.7686, max: 10.6796, mean: 2.8097, std: 2.3196
#
# Step 4937 — Test metrics:
#   precision@10: 0.035033113
#   recall@10: 0.035034952
#   ndcg@10: 0.035694908
#   map@10: 0.012845593
# Epoch 95 completed, Train Loss: 0.2637
# Epoch 96, Step 1, LR: 0.000080, Current Loss: 0.2769, Avg Loss: 0.2769
# Diff stats — min: -6.5173, max: 11.1950, mean: 2.8079, std: 2.3009
#
# Step 4940 — Test metrics:
#   precision@10: 0.034966887
#   recall@10: 0.034968727
#   ndcg@10: 0.035712252
#   map@10: 0.012880525
# Epoch 96, Step 10, LR: 0.000080, Current Loss: 0.2580, Avg Loss: 0.2645
# Diff stats — min: -5.8360, max: 10.6286, mean: 2.8207, std: 2.2528
#
# Step 4949 — Test metrics:
#   precision@10: 0.035264901
#   recall@10: 0.035266740
#   ndcg@10: 0.036048240
#   map@10: 0.013011918
# Epoch 96, Step 20, LR: 0.000080, Current Loss: 0.2685, Avg Loss: 0.2633
# Diff stats — min: -5.9557, max: 11.1936, mean: 2.8293, std: 2.3002
#
# Step 4959 — Test metrics:
#   precision@10: 0.034817881
#   recall@10: 0.034819720
#   ndcg@10: 0.035890468
#   map@10: 0.012993907
# Epoch 96, Step 30, LR: 0.000080, Current Loss: 0.2605, Avg Loss: 0.2631
# Diff stats — min: -5.4183, max: 10.6739, mean: 2.8251, std: 2.2754
#
# Step 4969 — Test metrics:
#   precision@10: 0.034619205
#   recall@10: 0.034622884
#   ndcg@10: 0.035513122
#   map@10: 0.012854513
# Epoch 96, Step 40, LR: 0.000080, Current Loss: 0.2750, Avg Loss: 0.2641
# Diff stats — min: -5.1251, max: 11.2576, mean: 2.7907, std: 2.3172
#
# Step 4979 — Test metrics:
#   precision@10: 0.034552980
#   recall@10: 0.034556659
#   ndcg@10: 0.035332315
#   map@10: 0.012801167
# Epoch 96, Step 50, LR: 0.000080, Current Loss: 0.2531, Avg Loss: 0.2638
# Diff stats — min: -6.2343, max: 10.9015, mean: 2.8829, std: 2.2681
#
# Step 4989 — Test metrics:
#   precision@10: 0.034817881
#   recall@10: 0.034821560
#   ndcg@10: 0.035395749
#   map@10: 0.012814543
# Epoch 96 completed, Train Loss: 0.2637
# Epoch 97, Step 1, LR: 0.000080, Current Loss: 0.2494, Avg Loss: 0.2494
# Diff stats — min: -5.0387, max: 11.2412, mean: 2.9148, std: 2.3009
#
# Step 4992 — Test metrics:
#   precision@10: 0.034735099
#   recall@10: 0.034738779
#   ndcg@10: 0.035224303
#   map@10: 0.012715817
# Epoch 97, Step 10, LR: 0.000080, Current Loss: 0.2633, Avg Loss: 0.2597
# Diff stats — min: -5.2061, max: 10.9157, mean: 2.8630, std: 2.3042
#
# Step 5001 — Test metrics:
#   precision@10: 0.034817881
#   recall@10: 0.034819720
#   ndcg@10: 0.035503792
#   map@10: 0.012839056
# Epoch 97, Step 20, LR: 0.000080, Current Loss: 0.2617, Avg Loss: 0.2628
# Diff stats — min: -6.8440, max: 10.7223, mean: 2.8329, std: 2.2781
#
# Step 5011 — Test metrics:
#   precision@10: 0.035281457
#   recall@10: 0.035283297
#   ndcg@10: 0.035947600
#   map@10: 0.013000894
# Epoch 97, Step 30, LR: 0.000080, Current Loss: 0.2698, Avg Loss: 0.2641
# Diff stats — min: -5.8182, max: 10.5139, mean: 2.8272, std: 2.3179
#
# Step 5021 — Test metrics:
#   precision@10: 0.035430464
#   recall@10: 0.035432303
#   ndcg@10: 0.036038049
#   map@10: 0.013004949
# Epoch 97, Step 40, LR: 0.000080, Current Loss: 0.2473, Avg Loss: 0.2644
# Diff stats — min: -4.9793, max: 10.2744, mean: 2.9105, std: 2.2731
#
# Step 5031 — Test metrics:
#   precision@10: 0.035231788
#   recall@10: 0.035233628
#   ndcg@10: 0.035911100
#   map@10: 0.012967336
# Epoch 97, Step 50, LR: 0.000080, Current Loss: 0.2621, Avg Loss: 0.2638
# Diff stats — min: -4.8386, max: 11.2968, mean: 2.8257, std: 2.2795
#
# Step 5041 — Test metrics:
#   precision@10: 0.034735099
#   recall@10: 0.034736939
#   ndcg@10: 0.035375303
#   map@10: 0.012725310
# Epoch 97 completed, Train Loss: 0.2639
# Epoch 98, Step 1, LR: 0.000080, Current Loss: 0.2682, Avg Loss: 0.2682
# Diff stats — min: -5.3320, max: 10.5273, mean: 2.8318, std: 2.2897
#
# Step 5044 — Test metrics:
#   precision@10: 0.034768212
#   recall@10: 0.034770052
#   ndcg@10: 0.035509939
#   map@10: 0.012810844
# Epoch 98, Step 10, LR: 0.000080, Current Loss: 0.2729, Avg Loss: 0.2644
# Diff stats — min: -5.1948, max: 10.9648, mean: 2.8118, std: 2.3021
#
# Step 5053 — Test metrics:
#   precision@10: 0.034668874
#   recall@10: 0.034672553
#   ndcg@10: 0.035542941
#   map@10: 0.012818893
# Epoch 98, Step 20, LR: 0.000080, Current Loss: 0.2528, Avg Loss: 0.2640
# Diff stats — min: -4.3738, max: 11.0382, mean: 2.8458, std: 2.2498
#
# Step 5063 — Test metrics:
#   precision@10: 0.035132450
#   recall@10: 0.035136130
#   ndcg@10: 0.035821907
#   map@10: 0.012888390
# Epoch 98, Step 30, LR: 0.000080, Current Loss: 0.2683, Avg Loss: 0.2617
# Diff stats — min: -6.1793, max: 10.9923, mean: 2.8257, std: 2.3112
#
# Step 5073 — Test metrics:
#   precision@10: 0.035066225
#   recall@10: 0.035068065
#   ndcg@10: 0.035844716
#   map@10: 0.012960639
# Epoch 98, Step 40, LR: 0.000080, Current Loss: 0.2580, Avg Loss: 0.2616
# Diff stats — min: -6.5214, max: 10.3561, mean: 2.8553, std: 2.2630
#
# Step 5083 — Test metrics:
#   precision@10: 0.034983444
#   recall@10: 0.034985283
#   ndcg@10: 0.035644924
#   map@10: 0.012843285
# Epoch 98, Step 50, LR: 0.000080, Current Loss: 0.2710, Avg Loss: 0.2615
# Diff stats — min: -5.9923, max: 10.6632, mean: 2.8176, std: 2.3167
#
# Step 5093 — Test metrics:
#   precision@10: 0.035066225
#   recall@10: 0.035068065
#   ndcg@10: 0.035875561
#   map@10: 0.012962932
# Epoch 98 completed, Train Loss: 0.2615
# Epoch 99, Step 1, LR: 0.000080, Current Loss: 0.2854, Avg Loss: 0.2854
# Diff stats — min: -5.8570, max: 10.9187, mean: 2.7802, std: 2.3492
#
# Step 5096 — Test metrics:
#   precision@10: 0.035132450
#   recall@10: 0.035134290
#   ndcg@10: 0.035932666
#   map@10: 0.012986118
# Epoch 99, Step 10, LR: 0.000080, Current Loss: 0.2650, Avg Loss: 0.2694
# Diff stats — min: -6.0063, max: 11.1424, mean: 2.8368, std: 2.2863
#
# Step 5105 — Test metrics:
#   precision@10: 0.034817881
#   recall@10: 0.034821560
#   ndcg@10: 0.035625507
#   map@10: 0.012826954
# Epoch 99, Step 20, LR: 0.000080, Current Loss: 0.2641, Avg Loss: 0.2661
# Diff stats — min: -5.4183, max: 10.0841, mean: 2.8374, std: 2.2963
#
# Step 5115 — Test metrics:
#   precision@10: 0.034884106
#   recall@10: 0.034887785
#   ndcg@10: 0.035765832
#   map@10: 0.012923230
# Epoch 99, Step 30, LR: 0.000080, Current Loss: 0.2511, Avg Loss: 0.2641
# Diff stats — min: -6.5322, max: 10.5865, mean: 2.8683, std: 2.2727
#
# Step 5125 — Test metrics:
#   precision@10: 0.035678808
#   recall@10: 0.035682487
#   ndcg@10: 0.036276779
#   map@10: 0.013094419
# Epoch 99, Step 40, LR: 0.000080, Current Loss: 0.2686, Avg Loss: 0.2637
# Diff stats — min: -7.1206, max: 11.3259, mean: 2.8379, std: 2.3228
#
# Step 5135 — Test metrics:
#   precision@10: 0.035331126
#   recall@10: 0.035334805
#   ndcg@10: 0.036020431
#   map@10: 0.013045944
# Epoch 99, Step 50, LR: 0.000080, Current Loss: 0.2592, Avg Loss: 0.2635
# Diff stats — min: -6.1866, max: 9.6106, mean: 2.8481, std: 2.2655
#
# Step 5145 — Test metrics:
#   precision@10: 0.035198675
#   recall@10: 0.035200515
#   ndcg@10: 0.035838857
#   map@10: 0.012949582
# Epoch 99 completed, Train Loss: 0.2637
# Epoch 100, Step 1, LR: 0.000080, Current Loss: 0.2624, Avg Loss: 0.2624
# Diff stats — min: -4.6491, max: 10.4495, mean: 2.8531, std: 2.2817
#
# Step 5148 — Test metrics:
#   precision@10: 0.034950331
#   recall@10: 0.034954010
#   ndcg@10: 0.035770910
#   map@10: 0.012976609
# Epoch 100, Step 10, LR: 0.000080, Current Loss: 0.2707, Avg Loss: 0.2622
# Diff stats — min: -5.1833, max: 10.1238, mean: 2.8363, std: 2.3124
#
# Step 5157 — Test metrics:
#   precision@10: 0.034552980
#   recall@10: 0.034554820
#   ndcg@10: 0.035472597
#   map@10: 0.012872357
# Epoch 100, Step 20, LR: 0.000080, Current Loss: 0.2534, Avg Loss: 0.2612
# Diff stats — min: -5.0992, max: 10.2975, mean: 2.8741, std: 2.2749
#
# Step 5167 — Test metrics:
#   precision@10: 0.034768212
#   recall@10: 0.034770052
#   ndcg@10: 0.035738409
#   map@10: 0.013004150
# Epoch 100, Step 30, LR: 0.000080, Current Loss: 0.2642, Avg Loss: 0.2615
# Diff stats — min: -4.8437, max: 10.5876, mean: 2.8654, std: 2.3251
#
# Step 5177 — Test metrics:
#   precision@10: 0.034453642
#   recall@10: 0.034455482
#   ndcg@10: 0.035371515
#   map@10: 0.012798125
# Epoch 100, Step 40, LR: 0.000080, Current Loss: 0.2557, Avg Loss: 0.2612
# Diff stats — min: -6.9959, max: 11.0452, mean: 2.9129, std: 2.3186
#
# Step 5187 — Test metrics:
#   precision@10: 0.034768212
#   recall@10: 0.034771891
#   ndcg@10: 0.035591107
#   map@10: 0.012866755
# Epoch 100, Step 50, LR: 0.000080, Current Loss: 0.2696, Avg Loss: 0.2619
# Diff stats — min: -4.9769, max: 10.5259, mean: 2.8504, std: 2.3205
#
# Step 5197 — Test metrics:
#   precision@10: 0.034900662
#   recall@10: 0.034904341
#   ndcg@10: 0.035635753
#   map@10: 0.012886386
# Epoch 100 completed, Train Loss: 0.2618

# %%
torch.save(model, "gnn_model_mvl.model")
from IPython.display import FileLink

FileLink('gnn_model_mvl.model')
# Out:
# /kaggle/working/gnn_model_mvl.model

# %%
# del model
gc.collect()
torch.cuda.empty_cache()

# %%
log_model(
    experiment=experiment,
    model=model,
    model_name="GNN",
)

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : diffGATGraphModel-movielens
# COMET INFO:     url                   : https://www.comet.com/annanet/gnn-recommender/527798220a1140c5b8dfc2d8f2ce1335
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Diff stats (mean) vs step [1166] : (-0.2983660101890564, 2.9147939682006836)
# COMET INFO:     Diff stats (std) vs step [1166]  : (0.8144240379333496, 5.913432598114014)
# COMET INFO:     Test map@10 vs step [1166]       : (0.0017786384421318198, 0.013094419040611092)
# COMET INFO:     Test ndcg@10 vs step [1166]      : (0.005354564317200823, 0.03636796341204262)
# COMET INFO:     Test precision@10 vs step [1166] : (0.004668874172185431, 0.03586092715231788)
# COMET INFO:     Test recall@10 vs step [1166]    : (0.004668874172185431, 0.03586460632818249)
# COMET INFO:     Train BPR Loss vs step [10107]   : (0.23755714297294617, 2.6491403579711914)
# COMET INFO:     Train Loss vs epoch [194]        : (0.2615285231894746, 2.2075705844999534)
# COMET INFO:     loss [1010]                      : (0.2453610897064209, 2.6262528896331787)
# COMET INFO:   Others:
# COMET INFO:     Name : diffGATGraphModel-movielens
# COMET INFO:   Parameters:
# COMET INFO:     seed              : 42
# COMET INFO:     test_batch_size   : 2048
# COMET INFO:     test_topk         : 10
# COMET INFO:     train_batch_size  : 4096
# COMET INFO:     train_edge_type   : ('item', 'to_feedback_explicit_positive', 'explicit_positive')
# COMET INFO:     train_lr          : 8e-05
# COMET INFO:     train_num_epochs  : 100
# COMET INFO:     train_print_every : 10
# COMET INFO:     train_test_every  : 10
# COMET INFO:     types_of_feedback : ['explicit_positive', 'expliсit_negative', 'implicit_positive', 'implicit_negative']
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     model-element       : 2 (4.29 MB)
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: All assets have been sent, waiting for delivery confirmation
